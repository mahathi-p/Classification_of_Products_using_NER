# %% [markdown]
# ## Creating a Spacy NER Model for laptops
#
# The Brand, Model, Processor, RAM, OS, Disk, Dim are the entities we want to define.

# %%
##import libraries
import pandas as pd
import numpy as np
import spacy
import random
import time

# %% [markdown]
# ### 1. Data

# %%
## loading data with the columns names as entities
data = pd.read_csv("catalogue/laptop.csv",index_col=None)
data
# Out:
#       Brand      Model                                    Processor  \
# 0    Lenovo    Ideapad            Intel Core i3 Processor (7th Gen)
# 1    Lenovo    Ideapad            Intel Core i3 Processor (7th Gen)
# 2        HP  EliteBook            Intel Core i3 Processor (7th Gen)
# 3      Dell     Vostro            Intel Core i3 Processor (8th Gen)
# 4        HP      Zbook            Intel Core i5 Processor (8th Gen)
# ..      ...        ...                                          ...
# 411  Lenovo    Ideapad            Intel Core i5 Processor (6th Gen)
# 412  Lenovo    Ideapad            Intel Core i7 Processor (8th Gen)
# 413  Lenovo    Ideapad               AMD APU Quad Core A6 Processor
# 414  Lenovo     Legion  Intel Pentium Quad Core Processor (4th Gen)
# 415  Lenovo    Ideapad            Intel Core i3 Processor (7th Gen)
#
#             RAM                 OS        Disk                    Dim Category
# 0    4 GB DDR4   64 bit Windows 10    1 TB HDD  39.62 cm (15.6 inch)    Laptop
# 1    4 GB DDR4   64 bit Windows 10    1 TB HDD  39.62 cm (15.6 inch)    Laptop
# 2    8 GB DDR4   64 bit Windows 10  256 GB SSD    35.56 cm (14 inch)    Laptop
# 3    4 GB DDR4        Linux/Ubuntu    1 TB HDD    35.56 cm (14 inch)    Laptop
# 4    8 GB DDR4   64 bit Windows 10    1 TB HDD    35.56 cm (14 inch)    Laptop
# ..          ...                ...         ...                    ...      ...
# 411  4 GB DDR3   64 bit Windows 10    1 TB HDD    35.56 cm (14 inch)    Laptop
# 412  8 GB DDR4   64 bit Windows 10    1 TB HDD  39.62 cm (15.6 inch)    Laptop
# 413  4 GB DDR3   64 bit Windows 10    1 TB HDD  39.62 cm (15.6 inch)    Laptop
# 414  4 GB DDR3                   D  500 GB HDD  39.62 cm (15.6 inch)    Laptop
# 415  4 GB DDR4                   D    1 TB HDD  39.62 cm (15.6 inch)    Laptop
#
# [416 rows x 8 columns]

# %% [markdown]
# ### 2. Pre-processing
#
# The input data has to be in a particular format.
#
# Steps:
# 1. Create a phrase with jumbled entities and the annotations for each entity.
# 2. Convert into json file with the content (phrase above) and the corresponding entities.
# 3. The json file is converted into a list.

# %% [markdown]
# ####  a. Creating content for the laptops

# %%
## the entities
cols = data.columns
cols
# Out:
# Index(['Brand', 'Model', 'Processor', 'RAM', 'OS', 'Disk', 'Dim', 'Category'], dtype='object')

# %%
## number of entities
num_ent = len(data.columns)
ent_list = list(np.arange(num_ent))
ent_list
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]

# %%
# sample of an entity
data.iloc[0,2]
# Out:
# 'Intel Core i3 Processor (7th Gen)'

# %%
## jumble indices of entities to create a phrase
prod_name = [] # list of all product names
prod_ann = [] # list of all the annotations
for i in range(len(data)): # loop for each laptop
    idx_list = random.sample(ent_list,num_ent) # shuffling indices
    cont = []
    ann = []
    ann_idx = 0 # pointer for annotating 
    for j in range(num_ent): # creating the jumbled product name
        col_num = idx_list[j] # column number according jumbled column index
        val = data.iloc[i,col_num] # value of the entity 
        cont.append(val) # appending list of entities into a single list
        ann.append((ann_idx, len(val)+ ann_idx, cols[col_num])) # annotations and entity name
        ann_idx = ann_idx + len(val) + 1 # updating the annotation pointer
        
    prod_name.append( ' '.join(cont)) # complete phrase for each laptop
    prod_ann.append(ann)

# %%
## Example
## This is the content
sample_prod_name = prod_name[8]
sample_prod_name
# Out:
# '512 GB SSD 8 GB DDR4  35.56 cm (14 inch)  64 bit Windows 10 Modern Intel Core i5 Processor (10th Gen) Laptop MSI'

# %%
## entities in it with their annotations
sample_prod_ent = prod_ann[8]
sample_prod_ent
# Out:
# [(0, 10, 'Disk'),
#  (11, 21, 'RAM'),
#  (22, 41, 'Dim'),
#  (42, 59, 'OS'),
#  (60, 66, 'Model'),
#  (67, 101, 'Processor'),
#  (102, 108, 'Category'),
#  (109, 112, 'Brand')]

# %%
## take an entity in the prod 
st_id = sample_prod_ent[7][0]
end_id = sample_prod_ent[7][1]
ent = sample_prod_ent[7][2]
print(ent,':', sample_prod_name[st_id : end_id])
# Out:
# Brand : MSI

# %%
prod =[]
for i in range(len(data)):
    prod.append([prod_name[i], prod_ann[i]])

prod[4]
# Out:
# ['HP 64 bit Windows 10 Zbook 1 TB HDD Laptop 35.56 cm (14 inch)  8 GB DDR4  Intel Core i5 Processor (8th Gen)',
#  [(0, 2, 'Brand'),
#   (3, 20, 'OS'),
#   (21, 26, 'Model'),
#   (27, 35, 'Disk'),
#   (36, 42, 'Category'),
#   (43, 62, 'Dim'),
#   (63, 73, 'RAM'),
#   (74, 107, 'Processor')]]

# %%
## creating a dataframe with product names and annotations
prod_data = pd.DataFrame(prod, columns = ['ProdName','Annotations'])
prod_data.head()
# Out:
#                                             ProdName  \
# 0  4 GB DDR4  1 TB HDD Laptop 39.62 cm (15.6 inch...
# 1  Lenovo 39.62 cm (15.6 inch)  Laptop Intel Core...
# 2  256 GB SSD 64 bit Windows 10 Laptop EliteBook ...
# 3  4 GB DDR4  Linux/Ubuntu Vostro 35.56 cm (14 in...
# 4  HP 64 bit Windows 10 Zbook 1 TB HDD Laptop 35....
#
#                                          Annotations
# 0  [(0, 10, RAM), (11, 19, Disk), (20, 26, Catego...
# 1  [(0, 6, Brand), (7, 28, Dim), (29, 35, Categor...
# 2  [(0, 10, Disk), (11, 28, OS), (29, 35, Categor...
# 3  [(0, 10, RAM), (11, 23, OS), (24, 30, Model), ...
# 4  [(0, 2, Brand), (3, 20, OS), (21, 26, Model), ...

# %%
# converting into csv file
prod_data.to_csv('laptop_prodNames.csv', index= None)

# %% [markdown]
# #### b. Creating json file

# %%
# converting into json format
import csv
import json

csvfile = open('laptop_prodNames.csv', 'r')
jsonfile = open('laptop_prodNames.json', 'w')

fieldnames = ('ProdName', 'Annotations')
reader = csv.DictReader( csvfile, fieldnames)

for row in reader:
    json.dump(row, jsonfile)
    jsonfile.write('\n')

# %% [markdown]
# #### c. json to list (spacy format)

# %%
## function to convert json file into spacy traning data format
def convert_to_spacytrain(json_file):
    try:
        
        training_data = []
        lines=[]
        with open(json_file, 'r') as f:
            lines = f.readlines() # this has 416 lines
            
        for line in lines[1:400]: # loop for every product
            data = json.loads(line) # single row
            text = data['ProdName'] #this is complete phrase
            entities = data['Annotations']
            training_data.append((text, {"entities" : eval(entities)}))
            
        return training_data
    
    except Exception as e:
        
        logging.exception("Unable to process " + json_file + "\n" + "error = " + str(e))
        
        return None

# %%
train_data = convert_to_spacytrain('laptop_prodNames.json')
train_data
# Out:
# [('4 GB DDR4  1 TB HDD Laptop 39.62 cm (15.6 inch)  64 bit Windows 10 Lenovo Intel Core i3 Processor (7th Gen) Ideapad',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 19, 'Disk'),
#     (20, 26, 'Category'),
#     (27, 48, 'Dim'),
#     (49, 66, 'OS'),
#     (67, 73, 'Brand'),
#     (74, 107, 'Processor'),
#     (108, 115, 'Model')]}),
#  ('Lenovo 39.62 cm (15.6 inch)  Laptop Intel Core i3 Processor (7th Gen) 4 GB DDR4  1 TB HDD 64 bit Windows 10 Ideapad',
#   {'entities': [(0, 6, 'Brand'),
#     (7, 28, 'Dim'),
#     (29, 35, 'Category'),
#     (36, 69, 'Processor'),
#     (70, 80, 'RAM'),
#     (81, 89, 'Disk'),
#     (90, 107, 'OS'),
#     (108, 115, 'Model')]}),
#  ('256 GB SSD 64 bit Windows 10 Laptop EliteBook Intel Core i3 Processor (7th Gen) HP 8 GB DDR4  35.56 cm (14 inch) ',
#   {'entities': [(0, 10, 'Disk'),
#     (11, 28, 'OS'),
#     (29, 35, 'Category'),
#     (36, 45, 'Model'),
#     (46, 79, 'Processor'),
#     (80, 82, 'Brand'),
#     (83, 93, 'RAM'),
#     (94, 113, 'Dim')]}),
#  ('4 GB DDR4  Linux/Ubuntu Vostro 35.56 cm (14 inch)  Laptop Dell 1 TB HDD Intel Core i3 Processor (8th Gen)',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 23, 'OS'),
#     (24, 30, 'Model'),
#     (31, 50, 'Dim'),
#     (51, 57, 'Category'),
#     (58, 62, 'Brand'),
#     (63, 71, 'Disk'),
#     (72, 105, 'Processor')]}),
#  ('HP 64 bit Windows 10 Zbook 1 TB HDD Laptop 35.56 cm (14 inch)  8 GB DDR4  Intel Core i5 Processor (8th Gen)',
#   {'entities': [(0, 2, 'Brand'),
#     (3, 20, 'OS'),
#     (21, 26, 'Model'),
#     (27, 35, 'Disk'),
#     (36, 42, 'Category'),
#     (43, 62, 'Dim'),
#     (63, 73, 'RAM'),
#     (74, 107, 'Processor')]}),
#  ('8 GB DDR4  Ideapad 64 bit Windows 10 39.62 cm (15.6 inch)  Intel Core i5 Processor (8th Gen) Laptop Lenovo 1 TB HDD',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 18, 'Model'),
#     (19, 36, 'OS'),
#     (37, 58, 'Dim'),
#     (59, 92, 'Processor'),
#     (93, 99, 'Category'),
#     (100, 106, 'Brand'),
#     (107, 115, 'Disk')]}),
#  ('Intel Core i3 Processor (7th Gen) Laptop 39.62 cm (15.6 inch)  64 bit Windows 10 8 GB DDR4  1 TB HDD Ideapad Lenovo',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 40, 'Category'),
#     (41, 62, 'Dim'),
#     (63, 80, 'OS'),
#     (81, 91, 'RAM'),
#     (92, 100, 'Disk'),
#     (101, 108, 'Model'),
#     (109, 115, 'Brand')]}),
#  ('64 bit Windows 10 512 GB SSD Asus Laptop Intel Core i5 Processor (9th Gen) 8 GB DDR4  39.62 cm (15.6 inch)  Vivo',
#   {'entities': [(0, 17, 'OS'),
#     (18, 28, 'Disk'),
#     (29, 33, 'Brand'),
#     (34, 40, 'Category'),
#     (41, 74, 'Processor'),
#     (75, 85, 'RAM'),
#     (86, 107, 'Dim'),
#     (108, 112, 'Model')]}),
#  ('512 GB SSD 8 GB DDR4  35.56 cm (14 inch)  64 bit Windows 10 Modern Intel Core i5 Processor (10th Gen) Laptop MSI',
#   {'entities': [(0, 10, 'Disk'),
#     (11, 21, 'RAM'),
#     (22, 41, 'Dim'),
#     (42, 59, 'OS'),
#     (60, 66, 'Model'),
#     (67, 101, 'Processor'),
#     (102, 108, 'Category'),
#     (109, 112, 'Brand')]}),
#  ('Envy 4 GB DDR4  Intel Core i3 Processor (7th Gen) 39.62 cm (15.6 inch)  64 bit Windows 10 Laptop 1 TB HDD HP',
#   {'entities': [(0, 4, 'Model'),
#     (5, 15, 'RAM'),
#     (16, 49, 'Processor'),
#     (50, 71, 'Dim'),
#     (72, 89, 'OS'),
#     (90, 96, 'Category'),
#     (97, 105, 'Disk'),
#     (106, 108, 'Brand')]}),
#  ('Intel Celeron Dual Core Processor 1 TB HDD 4 GB DDR4  39.62 cm (15.6 inch)  Laptop Ideapad Lenovo 64 bit Windows 10',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 42, 'Disk'),
#     (43, 53, 'RAM'),
#     (54, 75, 'Dim'),
#     (76, 82, 'Category'),
#     (83, 90, 'Model'),
#     (91, 97, 'Brand'),
#     (98, 115, 'OS')]}),
#  ('64 bit Mac Intel Core i5 Processor (5th Gen) MacBook Air Apple 33.78 cm (13.3 inch)  Laptop 128 GB SSD 8 GB DDR3 ',
#   {'entities': [(0, 10, 'OS'),
#     (11, 44, 'Processor'),
#     (45, 56, 'Model'),
#     (57, 62, 'Brand'),
#     (63, 84, 'Dim'),
#     (85, 91, 'Category'),
#     (92, 102, 'Disk'),
#     (103, 113, 'RAM')]}),
#  ('39.62 cm (15.6 inch)  8 GB DDR4  Laptop 1 TB HDD ThinkPad X Series Intel Core i7 Processor (8th Gen) 64 bit Windows 10 Lenovo',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 32, 'RAM'),
#     (33, 39, 'Category'),
#     (40, 48, 'Disk'),
#     (49, 66, 'Model'),
#     (67, 100, 'Processor'),
#     (101, 118, 'OS'),
#     (119, 125, 'Brand')]}),
#  ('Laptop Pavilion 4 GB DDR4  35.56 cm (14 inch) Touchscreen  HP 64 bit Windows 10 Intel Core i3 Processor (8th Gen) 256 GB SSD',
#   {'entities': [(0, 6, 'Category'),
#     (7, 15, 'Model'),
#     (16, 26, 'RAM'),
#     (27, 58, 'Dim'),
#     (59, 61, 'Brand'),
#     (62, 79, 'OS'),
#     (80, 113, 'Processor'),
#     (114, 124, 'Disk')]}),
#  ('AMD APU Dual Core A6 Processor 4 GB DDR4  39.62 cm (15.6 inch)  1 TB HDD Lenovo Laptop Ideapad 64 bit Windows 10',
#   {'entities': [(0, 30, 'Processor'),
#     (31, 41, 'RAM'),
#     (42, 63, 'Dim'),
#     (64, 72, 'Disk'),
#     (73, 79, 'Brand'),
#     (80, 86, 'Category'),
#     (87, 94, 'Model'),
#     (95, 112, 'OS')]}),
#  ('1 TB HDD 4 GB DDR4  39.62 cm (15.6 inch)  Laptop Acer Intel Core i3 Processor (8th Gen) 64 bit Windows 10 Aspire',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 19, 'RAM'),
#     (20, 41, 'Dim'),
#     (42, 48, 'Category'),
#     (49, 53, 'Brand'),
#     (54, 87, 'Processor'),
#     (88, 105, 'OS'),
#     (106, 112, 'Model')]}),
#  ('Laptop Intel Core i7 Processor (9th Gen) 8 GB DDR4  Nitro Acer 39.62 cm (15.6 inch)  1 TB HDD|256 GB SSD 64 bit Windows 10',
#   {'entities': [(0, 6, 'Category'),
#     (7, 40, 'Processor'),
#     (41, 51, 'RAM'),
#     (52, 57, 'Model'),
#     (58, 62, 'Brand'),
#     (63, 84, 'Dim'),
#     (85, 104, 'Disk'),
#     (105, 122, 'OS')]}),
#  ('39.62 cm (15.6 inch)  HP 1 TB HDD EliteBook Laptop 4 GB DDR4  AMD Ryzen 3 Dual Core Processor 64 bit Windows 10',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 24, 'Brand'),
#     (25, 33, 'Disk'),
#     (34, 43, 'Model'),
#     (44, 50, 'Category'),
#     (51, 61, 'RAM'),
#     (62, 93, 'Processor'),
#     (94, 111, 'OS')]}),
#  ('1 TB HDD HP Laptop 64 bit Windows 10 Pavilion Intel Core i3 Processor (7th Gen) 39.62 cm (15.6 inch)  8 GB DDR4 ',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 11, 'Brand'),
#     (12, 18, 'Category'),
#     (19, 36, 'OS'),
#     (37, 45, 'Model'),
#     (46, 79, 'Processor'),
#     (80, 101, 'Dim'),
#     (102, 112, 'RAM')]}),
#  ('35.56 cm (14 inch)  Intel Core i3 Processor (7th Gen) Latitude Dell 1 TB HDD 4 GB DDR4  Linux/Ubuntu Laptop',
#   {'entities': [(0, 19, 'Dim'),
#     (20, 53, 'Processor'),
#     (54, 62, 'Model'),
#     (63, 67, 'Brand'),
#     (68, 76, 'Disk'),
#     (77, 87, 'RAM'),
#     (88, 100, 'OS'),
#     (101, 107, 'Category')]}),
#  ('Pavilion 39.62 cm (15.6 inch)  8 GB DDR4  AMD Ryzen 5 Quad Core Processor 1 TB HDD|128 GB SSD HP Laptop 64 bit Windows 10',
#   {'entities': [(0, 8, 'Model'),
#     (9, 30, 'Dim'),
#     (31, 41, 'RAM'),
#     (42, 73, 'Processor'),
#     (74, 93, 'Disk'),
#     (94, 96, 'Brand'),
#     (97, 103, 'Category'),
#     (104, 121, 'OS')]}),
#  ('1 TB HDD|128 GB SSD HP Pavilion AMD Ryzen 5 Quad Core Processor 64 bit Windows 10 8 GB DDR4  39.62 cm (15.6 inch)  Laptop',
#   {'entities': [(0, 19, 'Disk'),
#     (20, 22, 'Brand'),
#     (23, 31, 'Model'),
#     (32, 63, 'Processor'),
#     (64, 81, 'OS'),
#     (82, 92, 'RAM'),
#     (93, 114, 'Dim'),
#     (115, 121, 'Category')]}),
#  ('Laptop ROG Intel Core i5 Processor (9th Gen) 39.62 cm (15.6 inch)  Asus 64 bit Windows 10 8 GB DDR4  1 TB HDD|256 GB SSD',
#   {'entities': [(0, 6, 'Category'),
#     (7, 10, 'Model'),
#     (11, 44, 'Processor'),
#     (45, 66, 'Dim'),
#     (67, 71, 'Brand'),
#     (72, 89, 'OS'),
#     (90, 100, 'RAM'),
#     (101, 120, 'Disk')]}),
#  ('64 bit Windows 10 Laptop 256 GB SSD Notebook 35.56 cm (14 inch)  Intel Core i3 Processor (7th Gen) HP 8 GB DDR4 ',
#   {'entities': [(0, 17, 'OS'),
#     (18, 24, 'Category'),
#     (25, 35, 'Disk'),
#     (36, 44, 'Model'),
#     (45, 64, 'Dim'),
#     (65, 98, 'Processor'),
#     (99, 101, 'Brand'),
#     (102, 112, 'RAM')]}),
#  ('1 TB HDD Laptop 39.62 cm (15.6 inch)  4 GB DDR4  Ideapad Lenovo 64 bit Windows 10 Intel Core i3 Processor (7th Gen)',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 15, 'Category'),
#     (16, 37, 'Dim'),
#     (38, 48, 'RAM'),
#     (49, 56, 'Model'),
#     (57, 63, 'Brand'),
#     (64, 81, 'OS'),
#     (82, 115, 'Processor')]}),
#  ('64 bit Windows 10 Intel Core i3 Processor (7th Gen) 39.62 cm (15.6 inch)  ThinkPad T Series 1 TB HDD Laptop Lenovo 4 GB DDR4 ',
#   {'entities': [(0, 17, 'OS'),
#     (18, 51, 'Processor'),
#     (52, 73, 'Dim'),
#     (74, 91, 'Model'),
#     (92, 100, 'Disk'),
#     (101, 107, 'Category'),
#     (108, 114, 'Brand'),
#     (115, 125, 'RAM')]}),
#  ('1 TB HDD 35.56 cm (14 inch)  Dell Linux/Ubuntu Vostro Intel Core i3 Processor (8th Gen) Laptop 4 GB DDR4 ',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 28, 'Dim'),
#     (29, 33, 'Brand'),
#     (34, 46, 'OS'),
#     (47, 53, 'Model'),
#     (54, 87, 'Processor'),
#     (88, 94, 'Category'),
#     (95, 105, 'RAM')]}),
#  ('Laptop 35.56 cm (14 inch)  8 GB DDR4  64 bit Windows 10 ProBook 1 TB HDD HP Intel Core i5 Processor (8th Gen)',
#   {'entities': [(0, 6, 'Category'),
#     (7, 26, 'Dim'),
#     (27, 37, 'RAM'),
#     (38, 55, 'OS'),
#     (56, 63, 'Model'),
#     (64, 72, 'Disk'),
#     (73, 75, 'Brand'),
#     (76, 109, 'Processor')]}),
#  ('Vivo 512 GB SSD 64 bit Windows 10 Intel Core i5 Processor (9th Gen) 8 GB DDR4  Laptop Asus 39.62 cm (15.6 inch) ',
#   {'entities': [(0, 4, 'Model'),
#     (5, 15, 'Disk'),
#     (16, 33, 'OS'),
#     (34, 67, 'Processor'),
#     (68, 78, 'RAM'),
#     (79, 85, 'Category'),
#     (86, 90, 'Brand'),
#     (91, 112, 'Dim')]}),
#  ('39.62 cm (15.6 inch)  1 TB HDD 8 GB DDR4  Ideapad Laptop Lenovo 64 bit Windows 10 Intel Core i5 Processor (8th Gen)',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 30, 'Disk'),
#     (31, 41, 'RAM'),
#     (42, 49, 'Model'),
#     (50, 56, 'Category'),
#     (57, 63, 'Brand'),
#     (64, 81, 'OS'),
#     (82, 115, 'Processor')]}),
#  ('1 TB HDD Intel Core i3 Processor (7th Gen) 39.62 cm (15.6 inch)  Laptop Lenovo Ideapad 8 GB DDR4  64 bit Windows 10',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 42, 'Processor'),
#     (43, 64, 'Dim'),
#     (65, 71, 'Category'),
#     (72, 78, 'Brand'),
#     (79, 86, 'Model'),
#     (87, 97, 'RAM'),
#     (98, 115, 'OS')]}),
#  ('512 GB SSD MSI Intel Core i5 Processor (10th Gen) Laptop 64 bit Windows 10 Modern 8 GB DDR4  35.56 cm (14 inch) ',
#   {'entities': [(0, 10, 'Disk'),
#     (11, 14, 'Brand'),
#     (15, 49, 'Processor'),
#     (50, 56, 'Category'),
#     (57, 74, 'OS'),
#     (75, 81, 'Model'),
#     (82, 92, 'RAM'),
#     (93, 112, 'Dim')]}),
#  ('Pavilion 35.56 cm (14 inch) Touchscreen  256 GB SSD 4 GB DDR4  64 bit Windows 10 Laptop HP Intel Core i3 Processor (8th Gen)',
#   {'entities': [(0, 8, 'Model'),
#     (9, 40, 'Dim'),
#     (41, 51, 'Disk'),
#     (52, 62, 'RAM'),
#     (63, 80, 'OS'),
#     (81, 87, 'Category'),
#     (88, 90, 'Brand'),
#     (91, 124, 'Processor')]}),
#  ('64 bit Windows 10 Laptop 39.62 cm (15.6 inch)  Lenovo ThinkPad X Series 1 TB HDD Intel Core i7 Processor (8th Gen) 8 GB DDR4 ',
#   {'entities': [(0, 17, 'OS'),
#     (18, 24, 'Category'),
#     (25, 46, 'Dim'),
#     (47, 53, 'Brand'),
#     (54, 71, 'Model'),
#     (72, 80, 'Disk'),
#     (81, 114, 'Processor'),
#     (115, 125, 'RAM')]}),
#  ('Laptop 64 bit Windows 10 Intel Core i3 Processor (7th Gen) 39.62 cm (15.6 inch)  1 TB HDD Pavilion 4 GB DDR4  HP',
#   {'entities': [(0, 6, 'Category'),
#     (7, 24, 'OS'),
#     (25, 58, 'Processor'),
#     (59, 80, 'Dim'),
#     (81, 89, 'Disk'),
#     (90, 98, 'Model'),
#     (99, 109, 'RAM'),
#     (110, 112, 'Brand')]}),
#  ('Laptop 64 bit Windows 10 4 GB DDR4  39.62 cm (15.6 inch)  Intel Celeron Dual Core Processor 1 TB HDD Ideapad Lenovo',
#   {'entities': [(0, 6, 'Category'),
#     (7, 24, 'OS'),
#     (25, 35, 'RAM'),
#     (36, 57, 'Dim'),
#     (58, 91, 'Processor'),
#     (92, 100, 'Disk'),
#     (101, 108, 'Model'),
#     (109, 115, 'Brand')]}),
#  ('33.78 cm (13.3 inch)  128 GB SSD 8 GB DDR3  64 bit Mac Apple Intel Core i5 Processor (5th Gen) Laptop MacBook Air',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 32, 'Disk'),
#     (33, 43, 'RAM'),
#     (44, 54, 'OS'),
#     (55, 60, 'Brand'),
#     (61, 94, 'Processor'),
#     (95, 101, 'Category'),
#     (102, 113, 'Model')]}),
#  ('Ideapad Lenovo 4 GB DDR4  39.62 cm (15.6 inch)  64 bit Windows 10 1 TB HDD Laptop AMD APU Dual Core A6 Processor',
#   {'entities': [(0, 7, 'Model'),
#     (8, 14, 'Brand'),
#     (15, 25, 'RAM'),
#     (26, 47, 'Dim'),
#     (48, 65, 'OS'),
#     (66, 74, 'Disk'),
#     (75, 81, 'Category'),
#     (82, 112, 'Processor')]}),
#  ('1 TB HDD|256 GB SSD 39.62 cm (15.6 inch)  Laptop Intel Core i7 Processor (9th Gen) 64 bit Windows 10 Nitro 8 GB DDR4  Acer',
#   {'entities': [(0, 19, 'Disk'),
#     (20, 41, 'Dim'),
#     (42, 48, 'Category'),
#     (49, 82, 'Processor'),
#     (83, 100, 'OS'),
#     (101, 106, 'Model'),
#     (107, 117, 'RAM'),
#     (118, 122, 'Brand')]}),
#  ('1 TB HDD Envy 64 bit Windows 10 Intel Core i3 Processor (7th Gen) 8 GB DDR4  HP Laptop 39.62 cm (15.6 inch) ',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 13, 'Model'),
#     (14, 31, 'OS'),
#     (32, 65, 'Processor'),
#     (66, 76, 'RAM'),
#     (77, 79, 'Brand'),
#     (80, 86, 'Category'),
#     (87, 108, 'Dim')]}),
#  ('4 GB DDR4  1 TB HDD Laptop Acer Aspire 39.62 cm (15.6 inch)  Intel Core i3 Processor (8th Gen) 64 bit Windows 10',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 19, 'Disk'),
#     (20, 26, 'Category'),
#     (27, 31, 'Brand'),
#     (32, 38, 'Model'),
#     (39, 60, 'Dim'),
#     (61, 94, 'Processor'),
#     (95, 112, 'OS')]}),
#  ('ProBook Laptop HP 4 GB DDR4  1 TB HDD 39.62 cm (15.6 inch)  AMD Ryzen 3 Dual Core Processor 64 bit Windows 10',
#   {'entities': [(0, 7, 'Model'),
#     (8, 14, 'Category'),
#     (15, 17, 'Brand'),
#     (18, 28, 'RAM'),
#     (29, 37, 'Disk'),
#     (38, 59, 'Dim'),
#     (60, 91, 'Processor'),
#     (92, 109, 'OS')]}),
#  ('39.62 cm (15.6 inch)  HP AMD Ryzen 5 Quad Core Processor 64 bit Windows 10 Pavilion 1 TB HDD|128 GB SSD 8 GB DDR4  Laptop',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 24, 'Brand'),
#     (25, 56, 'Processor'),
#     (57, 74, 'OS'),
#     (75, 83, 'Model'),
#     (84, 103, 'Disk'),
#     (104, 114, 'RAM'),
#     (115, 121, 'Category')]}),
#  ('64 bit Windows 10 39.62 cm (15.6 inch)  8 GB DDR4  1 TB HDD|128 GB SSD Laptop AMD Ryzen 5 Quad Core Processor HP Pavilion',
#   {'entities': [(0, 17, 'OS'),
#     (18, 39, 'Dim'),
#     (40, 50, 'RAM'),
#     (51, 70, 'Disk'),
#     (71, 77, 'Category'),
#     (78, 109, 'Processor'),
#     (110, 112, 'Brand'),
#     (113, 121, 'Model')]}),
#  ('Laptop Inspiron Linux/Ubuntu Dell Intel Core i3 Processor (7th Gen) 4 GB DDR4  35.56 cm (14 inch)  1 TB HDD',
#   {'entities': [(0, 6, 'Category'),
#     (7, 15, 'Model'),
#     (16, 28, 'OS'),
#     (29, 33, 'Brand'),
#     (34, 67, 'Processor'),
#     (68, 78, 'RAM'),
#     (79, 98, 'Dim'),
#     (99, 107, 'Disk')]}),
#  ('Intel Core i5 Processor (9th Gen) 64 bit Windows 10 8 GB DDR4  Asus ROG Laptop 39.62 cm (15.6 inch)  1 TB HDD|256 GB SSD',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 51, 'OS'),
#     (52, 62, 'RAM'),
#     (63, 67, 'Brand'),
#     (68, 71, 'Model'),
#     (72, 78, 'Category'),
#     (79, 100, 'Dim'),
#     (101, 120, 'Disk')]}),
#  ('HP Laptop 39.62 cm (15.6 inch)  AMD Ryzen 3 Dual Core Processor 1 TB HDD|256 GB SSD 64 bit Windows 10 4 GB DDR4  Envy',
#   {'entities': [(0, 2, 'Brand'),
#     (3, 9, 'Category'),
#     (10, 31, 'Dim'),
#     (32, 63, 'Processor'),
#     (64, 83, 'Disk'),
#     (84, 101, 'OS'),
#     (102, 112, 'RAM'),
#     (113, 117, 'Model')]}),
#  ('64 bit Windows 10 Lenovo 39.62 cm (15.6 inch)  Intel Core i5 Processor (8th Gen) Ideapad 4 GB DDR4  1 TB HDD Laptop',
#   {'entities': [(0, 17, 'OS'),
#     (18, 24, 'Brand'),
#     (25, 46, 'Dim'),
#     (47, 80, 'Processor'),
#     (81, 88, 'Model'),
#     (89, 99, 'RAM'),
#     (100, 108, 'Disk'),
#     (109, 115, 'Category')]}),
#  ('Intel Core i7 Processor (8th Gen) Vivo 35.56 cm (14 inch)  8 GB DDR4  1 TB HDD|256 GB SSD Laptop 64 bit Windows 10 Asus',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 38, 'Model'),
#     (39, 58, 'Dim'),
#     (59, 69, 'RAM'),
#     (70, 89, 'Disk'),
#     (90, 96, 'Category'),
#     (97, 114, 'OS'),
#     (115, 119, 'Brand')]}),
#  ('Acer Nitro 39.62 cm (15.6 inch)  Laptop 64 bit Windows 10 8 GB DDR4  1 TB HDD|256 GB SSD AMD Ryzen 5 Quad Core Processor',
#   {'entities': [(0, 4, 'Brand'),
#     (5, 10, 'Model'),
#     (11, 32, 'Dim'),
#     (33, 39, 'Category'),
#     (40, 57, 'OS'),
#     (58, 68, 'RAM'),
#     (69, 88, 'Disk'),
#     (89, 120, 'Processor')]}),
#  ('64 bit Windows 10 2 TB HDD|256 GB SSD Laptop Predator Intel Core i7 Processor (9th Gen) 16 GB DDR4  Acer 43.94 cm (17.3 inch) ',
#   {'entities': [(0, 17, 'OS'),
#     (18, 37, 'Disk'),
#     (38, 44, 'Category'),
#     (45, 53, 'Model'),
#     (54, 87, 'Processor'),
#     (88, 99, 'RAM'),
#     (100, 104, 'Brand'),
#     (105, 126, 'Dim')]}),
#  ('16 GB DDR4  39.62 cm (15.6 inch)  64 bit Windows 10 1 TB SSD Modern Intel Core i7 Processor (9th Gen) Laptop MSI',
#   {'entities': [(0, 11, 'RAM'),
#     (12, 33, 'Dim'),
#     (34, 51, 'OS'),
#     (52, 60, 'Disk'),
#     (61, 67, 'Model'),
#     (68, 101, 'Processor'),
#     (102, 108, 'Category'),
#     (109, 112, 'Brand')]}),
#  ('35.56 cm (14 inch)  8 GB DDR4  Asus Vivo 512 GB SSD Intel Core i5 Processor (8th Gen) Laptop 64 bit Windows 10',
#   {'entities': [(0, 19, 'Dim'),
#     (20, 30, 'RAM'),
#     (31, 35, 'Brand'),
#     (36, 40, 'Model'),
#     (41, 51, 'Disk'),
#     (52, 85, 'Processor'),
#     (86, 92, 'Category'),
#     (93, 110, 'OS')]}),
#  ('TUF Gaming 1 TB HDD Asus 64 bit Windows 10 Laptop AMD Ryzen 5 Quad Core Processor 39.62 cm (15.6 inch)  8 GB DDR4 ',
#   {'entities': [(0, 10, 'Model'),
#     (11, 19, 'Disk'),
#     (20, 24, 'Brand'),
#     (25, 42, 'OS'),
#     (43, 49, 'Category'),
#     (50, 81, 'Processor'),
#     (82, 103, 'Dim'),
#     (104, 114, 'RAM')]}),
#  ('64 bit Windows 10 Intel Core i5 Processor (9th Gen) Laptop 1 TB HDD|256 GB SSD Predator Acer 16 GB DDR4  43.94 cm (17.3 inch) ',
#   {'entities': [(0, 17, 'OS'),
#     (18, 51, 'Processor'),
#     (52, 58, 'Category'),
#     (59, 78, 'Disk'),
#     (79, 87, 'Model'),
#     (88, 92, 'Brand'),
#     (93, 104, 'RAM'),
#     (105, 126, 'Dim')]}),
#  ('64 bit Windows 10 Vivo 1 TB HDD|256 GB SSD 8 GB DDR4  Intel Core i5 Processor (8th Gen) 35.56 cm (14 inch)  Laptop Asus',
#   {'entities': [(0, 17, 'OS'),
#     (18, 22, 'Model'),
#     (23, 42, 'Disk'),
#     (43, 53, 'RAM'),
#     (54, 87, 'Processor'),
#     (88, 107, 'Dim'),
#     (108, 114, 'Category'),
#     (115, 119, 'Brand')]}),
#  ('Laptop 39.62 cm (15.6 inch)  Lenovo Ideapad 8 GB DDR4  1 TB HDD AMD Ryzen 5 Quad Core Processor 64 bit Windows 10',
#   {'entities': [(0, 6, 'Category'),
#     (7, 28, 'Dim'),
#     (29, 35, 'Brand'),
#     (36, 43, 'Model'),
#     (44, 54, 'RAM'),
#     (55, 63, 'Disk'),
#     (64, 95, 'Processor'),
#     (96, 113, 'OS')]}),
#  ('Avita 64 bit Windows 10 Laptop 256 GB SSD Liber 8 GB DDR4  35.56 cm (14 inch)  Intel Core i5 Processor (8th Gen)',
#   {'entities': [(0, 5, 'Brand'),
#     (6, 23, 'OS'),
#     (24, 30, 'Category'),
#     (31, 41, 'Disk'),
#     (42, 47, 'Model'),
#     (48, 58, 'RAM'),
#     (59, 78, 'Dim'),
#     (79, 112, 'Processor')]}),
#  ('HP 64 bit Windows 10 Laptop 35.56 cm (14 inch)  Intel Core i5 Processor (8th Gen) Pavilion 512 GB SSD 8 GB DDR4 ',
#   {'entities': [(0, 2, 'Brand'),
#     (3, 20, 'OS'),
#     (21, 27, 'Category'),
#     (28, 47, 'Dim'),
#     (48, 81, 'Processor'),
#     (82, 90, 'Model'),
#     (91, 101, 'Disk'),
#     (102, 112, 'RAM')]}),
#  ('Laptop 64 bit Windows 10 4 GB DDR4  1 TB HDD 38.1 cm (15 inch)  Notebook HP Intel Core i3 Processor (8th Gen)',
#   {'entities': [(0, 6, 'Category'),
#     (7, 24, 'OS'),
#     (25, 35, 'RAM'),
#     (36, 44, 'Disk'),
#     (45, 63, 'Dim'),
#     (64, 72, 'Model'),
#     (73, 75, 'Brand'),
#     (76, 109, 'Processor')]}),
#  ('512 GB SSD 33.78 cm (13.3 inch) Touchscreen  64 bit Windows 10 Laptop 8 GB DDR4  Lenovo Intel Core i7 Processor (8th Gen) Yoga',
#   {'entities': [(0, 10, 'Disk'),
#     (11, 44, 'Dim'),
#     (45, 62, 'OS'),
#     (63, 69, 'Category'),
#     (70, 80, 'RAM'),
#     (81, 87, 'Brand'),
#     (88, 121, 'Processor'),
#     (122, 126, 'Model')]}),
#  ('8 GB DDR4  512 GB SSD Laptop 64 bit Windows 10 Aspire Intel Core i5 Processor (8th Gen) Acer 35.56 cm (14 inch) ',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 21, 'Disk'),
#     (22, 28, 'Category'),
#     (29, 46, 'OS'),
#     (47, 53, 'Model'),
#     (54, 87, 'Processor'),
#     (88, 92, 'Brand'),
#     (93, 112, 'Dim')]}),
#  ('8 GB DDR4  64 bit Windows 10 Acer 1 TB HDD Laptop 39.62 cm (15.6 inch)  Intel Core i5 Processor (9th Gen) Nitro',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 28, 'OS'),
#     (29, 33, 'Brand'),
#     (34, 42, 'Disk'),
#     (43, 49, 'Category'),
#     (50, 71, 'Dim'),
#     (72, 105, 'Processor'),
#     (106, 111, 'Model')]}),
#  ('Ideapad Lenovo Laptop D AMD APU Dual Core A6 Processor 39.62 cm (15.6 inch)  1 TB HDD 4 GB DDR4 ',
#   {'entities': [(0, 7, 'Model'),
#     (8, 14, 'Brand'),
#     (15, 21, 'Category'),
#     (22, 23, 'OS'),
#     (24, 54, 'Processor'),
#     (55, 76, 'Dim'),
#     (77, 85, 'Disk'),
#     (86, 96, 'RAM')]}),
#  ('35.56 cm (14 inch) Touchscreen  4 GB DDR4  256 GB SSD Intel Core i3 Processor (10th Gen) HP Pavilion Laptop 64 bit Windows 10',
#   {'entities': [(0, 31, 'Dim'),
#     (32, 42, 'RAM'),
#     (43, 53, 'Disk'),
#     (54, 88, 'Processor'),
#     (89, 91, 'Brand'),
#     (92, 100, 'Model'),
#     (101, 107, 'Category'),
#     (108, 125, 'OS')]}),
#  ('Intel Core i3 Processor (7th Gen) Zbook 39.62 cm (15.6 inch)  64 bit Windows 10 1 TB HDD HP 4 GB DDR4  Laptop',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 39, 'Model'),
#     (40, 61, 'Dim'),
#     (62, 79, 'OS'),
#     (80, 88, 'Disk'),
#     (89, 91, 'Brand'),
#     (92, 102, 'RAM'),
#     (103, 109, 'Category')]}),
#  ('64 bit Windows 10 35.56 cm (14 inch)  8 GB DDR4  Asus AMD Ryzen 5 Quad Core Processor (2nd Gen) Laptop Vivo 512 GB SSD',
#   {'entities': [(0, 17, 'OS'),
#     (18, 37, 'Dim'),
#     (38, 48, 'RAM'),
#     (49, 53, 'Brand'),
#     (54, 95, 'Processor'),
#     (96, 102, 'Category'),
#     (103, 107, 'Model'),
#     (108, 118, 'Disk')]}),
#  ('Intel Core i3 Processor (7th Gen) Ideapad 1 TB HDD Laptop 39.62 cm (15.6 inch)  4 GB DDR4  D Lenovo',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 41, 'Model'),
#     (42, 50, 'Disk'),
#     (51, 57, 'Category'),
#     (58, 79, 'Dim'),
#     (80, 90, 'RAM'),
#     (91, 92, 'OS'),
#     (93, 99, 'Brand')]}),
#  ('4 GB DDR4  Lenovo D Laptop 39.62 cm (15.6 inch)  Ideapad 1 TB HDD Intel Core i3 Processor (7th Gen)',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 17, 'Brand'),
#     (18, 19, 'OS'),
#     (20, 26, 'Category'),
#     (27, 48, 'Dim'),
#     (49, 56, 'Model'),
#     (57, 65, 'Disk'),
#     (66, 99, 'Processor')]}),
#  ('1 TB HDD 64 bit Windows 10 8 GB DDR4  Laptop Intel Core i5 Processor (8th Gen) 39.62 cm (15.6 inch)  ProBook HP',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 26, 'OS'),
#     (27, 37, 'RAM'),
#     (38, 44, 'Category'),
#     (45, 78, 'Processor'),
#     (79, 100, 'Dim'),
#     (101, 108, 'Model'),
#     (109, 111, 'Brand')]}),
#  ('Laptop 256 GB SSD 39.62 cm (15.6 inch)  Asus Intel Core i3 Processor (8th Gen) 64 bit Windows 10 4 GB DDR4  Vivo',
#   {'entities': [(0, 6, 'Category'),
#     (7, 17, 'Disk'),
#     (18, 39, 'Dim'),
#     (40, 44, 'Brand'),
#     (45, 78, 'Processor'),
#     (79, 96, 'OS'),
#     (97, 107, 'RAM'),
#     (108, 112, 'Model')]}),
#  ('Ideapad Laptop 1 TB HDD 35.56 cm (14 inch)  Intel Core i3 Processor (6th Gen) 4 GB DDR4  Lenovo D',
#   {'entities': [(0, 7, 'Model'),
#     (8, 14, 'Category'),
#     (15, 23, 'Disk'),
#     (24, 43, 'Dim'),
#     (44, 77, 'Processor'),
#     (78, 88, 'RAM'),
#     (89, 95, 'Brand'),
#     (96, 97, 'OS')]}),
#  ('128 GB SSD 33.78 cm (13.3 inch)  Laptop MacBook Pro Mac 8 GB DDR3  Intel Core i5 Processor (8th Gen) Apple',
#   {'entities': [(0, 10, 'Disk'),
#     (11, 32, 'Dim'),
#     (33, 39, 'Category'),
#     (40, 51, 'Model'),
#     (52, 55, 'OS'),
#     (56, 66, 'RAM'),
#     (67, 100, 'Processor'),
#     (101, 106, 'Brand')]}),
#  ('43.94 cm (17.3 inch)  1 TB HDD|1 TB SSD Intel Core i7 Processor (9th Gen) MSI 64 bit Windows 10 Gaming 16 GB DDR4  Laptop',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 39, 'Disk'),
#     (40, 73, 'Processor'),
#     (74, 77, 'Brand'),
#     (78, 95, 'OS'),
#     (96, 102, 'Model'),
#     (103, 114, 'RAM'),
#     (115, 121, 'Category')]}),
#  ('Ideapad 64 bit Windows 10 39.62 cm (15.6 inch)  1 TB HDD Laptop 4 GB DDR4  Lenovo Intel Core i3 Processor (7th Gen)',
#   {'entities': [(0, 7, 'Model'),
#     (8, 25, 'OS'),
#     (26, 47, 'Dim'),
#     (48, 56, 'Disk'),
#     (57, 63, 'Category'),
#     (64, 74, 'RAM'),
#     (75, 81, 'Brand'),
#     (82, 115, 'Processor')]}),
#  ('Intel Core i5 Processor (8th Gen) 8 GB DDR4  Laptop Pavilion 35.56 cm (14 inch)  HP 1 TB HDD|256 GB SSD 64 bit Windows 10',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 44, 'RAM'),
#     (45, 51, 'Category'),
#     (52, 60, 'Model'),
#     (61, 80, 'Dim'),
#     (81, 83, 'Brand'),
#     (84, 103, 'Disk'),
#     (104, 121, 'OS')]}),
#  ('64 bit Windows 10 8 GB DDR3  ZenBook Asus Laptop 256 GB SSD 35.56 cm (14 inch)  Intel Core i5 Processor (8th Gen)',
#   {'entities': [(0, 17, 'OS'),
#     (18, 28, 'RAM'),
#     (29, 36, 'Model'),
#     (37, 41, 'Brand'),
#     (42, 48, 'Category'),
#     (49, 59, 'Disk'),
#     (60, 79, 'Dim'),
#     (80, 113, 'Processor')]}),
#  ('8 GB DDR4  1 TB HDD 39.62 cm (15.6 inch)  Ideapad D Lenovo Intel Core i5 Processor (8th Gen) Laptop',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 19, 'Disk'),
#     (20, 41, 'Dim'),
#     (42, 49, 'Model'),
#     (50, 51, 'OS'),
#     (52, 58, 'Brand'),
#     (59, 92, 'Processor'),
#     (93, 99, 'Category')]}),
#  ('4 GB DDR4  64 bit Windows 10 39.62 cm (15.6 inch)  HP Intel Core i5 Processor (8th Gen) ProBook 1 TB HDD Laptop',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 28, 'OS'),
#     (29, 50, 'Dim'),
#     (51, 53, 'Brand'),
#     (54, 87, 'Processor'),
#     (88, 95, 'Model'),
#     (96, 104, 'Disk'),
#     (105, 111, 'Category')]}),
#  ('64 bit Windows 10 G 39.62 cm (15.6 inch)  Intel Core i5 Processor (8th Gen) 8 GB DDR4  1 TB HDD|128 GB SSD Dell Laptop',
#   {'entities': [(0, 17, 'OS'),
#     (18, 19, 'Model'),
#     (20, 41, 'Dim'),
#     (42, 75, 'Processor'),
#     (76, 86, 'RAM'),
#     (87, 106, 'Disk'),
#     (107, 111, 'Brand'),
#     (112, 118, 'Category')]}),
#  ('Envy HP 64 bit Windows 10 8 GB DDR4  33.78 cm (13.3 inch) Touchscreen  Laptop Intel Core i5 Processor (10th Gen) 512 GB SSD',
#   {'entities': [(0, 4, 'Model'),
#     (5, 7, 'Brand'),
#     (8, 25, 'OS'),
#     (26, 36, 'RAM'),
#     (37, 70, 'Dim'),
#     (71, 77, 'Category'),
#     (78, 112, 'Processor'),
#     (113, 123, 'Disk')]}),
#  ('1 TB HDD|256 GB SSD Intel Core i7 Processor (9th Gen) 43.94 cm (17.3 inch)  16 GB DDR4  Laptop 64 bit Windows 10 TravelMate Acer',
#   {'entities': [(0, 19, 'Disk'),
#     (20, 53, 'Processor'),
#     (54, 75, 'Dim'),
#     (76, 87, 'RAM'),
#     (88, 94, 'Category'),
#     (95, 112, 'OS'),
#     (113, 123, 'Model'),
#     (124, 128, 'Brand')]}),
#  ('Laptop 64 bit Windows 10 8 GB DDR4  Asus 1 TB HDD|256 GB SSD Vivo Intel Core i5 Processor (8th Gen) 35.56 cm (14 inch) ',
#   {'entities': [(0, 6, 'Category'),
#     (7, 24, 'OS'),
#     (25, 35, 'RAM'),
#     (36, 40, 'Brand'),
#     (41, 60, 'Disk'),
#     (61, 65, 'Model'),
#     (66, 99, 'Processor'),
#     (100, 119, 'Dim')]}),
#  ('64 bit Windows 10 Intel Core i3 Processor (7th Gen) Lenovo 4 GB DDR4  1 TB HDD Ideapad 39.62 cm (15.6 inch)  Laptop',
#   {'entities': [(0, 17, 'OS'),
#     (18, 51, 'Processor'),
#     (52, 58, 'Brand'),
#     (59, 69, 'RAM'),
#     (70, 78, 'Disk'),
#     (79, 86, 'Model'),
#     (87, 108, 'Dim'),
#     (109, 115, 'Category')]}),
#  ('Asus 16 GB DDR4  Vivo 512 GB SSD 64 bit Windows 10 Laptop Intel Core i7 Processor (9th Gen) 39.62 cm (15.6 inch) ',
#   {'entities': [(0, 4, 'Brand'),
#     (5, 16, 'RAM'),
#     (17, 21, 'Model'),
#     (22, 32, 'Disk'),
#     (33, 50, 'OS'),
#     (51, 57, 'Category'),
#     (58, 91, 'Processor'),
#     (92, 113, 'Dim')]}),
#  ('4 GB DDR4  Zbook Intel Core i3 Processor (7th Gen) HP 1 TB HDD 39.62 cm (15.6 inch)  Laptop 64 bit Windows 10',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 16, 'Model'),
#     (17, 50, 'Processor'),
#     (51, 53, 'Brand'),
#     (54, 62, 'Disk'),
#     (63, 84, 'Dim'),
#     (85, 91, 'Category'),
#     (92, 109, 'OS')]}),
#  ('Lenovo 8 GB DDR4  64 bit Windows 10 Intel Core i5 Processor (10th Gen) Laptop Ideapad 512 GB SSD 39.62 cm (15.6 inch) ',
#   {'entities': [(0, 6, 'Brand'),
#     (7, 17, 'RAM'),
#     (18, 35, 'OS'),
#     (36, 70, 'Processor'),
#     (71, 77, 'Category'),
#     (78, 85, 'Model'),
#     (86, 96, 'Disk'),
#     (97, 118, 'Dim')]}),
#  ('Lenovo 1 TB HDD 4 GB DDR4  Ideapad 64 bit Windows 10 Laptop AMD APU Dual Core A6 Processor 35.56 cm (14 inch) ',
#   {'entities': [(0, 6, 'Brand'),
#     (7, 15, 'Disk'),
#     (16, 26, 'RAM'),
#     (27, 34, 'Model'),
#     (35, 52, 'OS'),
#     (53, 59, 'Category'),
#     (60, 90, 'Processor'),
#     (91, 110, 'Dim')]}),
#  ('8 GB DDR4  HP Pavilion 39.62 cm (15.6 inch)  Intel Core i5 Processor (8th Gen) 1 TB HDD Laptop 64 bit Windows 10',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 13, 'Brand'),
#     (14, 22, 'Model'),
#     (23, 44, 'Dim'),
#     (45, 78, 'Processor'),
#     (79, 87, 'Disk'),
#     (88, 94, 'Category'),
#     (95, 112, 'OS')]}),
#  ('4 GB DDR4  1 TB HDD Zbook 35.56 cm (14 inch)  D Laptop AMD APU Dual Core A6 Processor HP',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 19, 'Disk'),
#     (20, 25, 'Model'),
#     (26, 45, 'Dim'),
#     (46, 47, 'OS'),
#     (48, 54, 'Category'),
#     (55, 85, 'Processor'),
#     (86, 88, 'Brand')]}),
#  ('35.56 cm (14 inch)  8 GB DDR3  Intel Core i5 Processor (7th Gen) 64 bit Windows 10 Avita Liber Laptop 256 GB SSD',
#   {'entities': [(0, 19, 'Dim'),
#     (20, 30, 'RAM'),
#     (31, 64, 'Processor'),
#     (65, 82, 'OS'),
#     (83, 88, 'Brand'),
#     (89, 94, 'Model'),
#     (95, 101, 'Category'),
#     (102, 112, 'Disk')]}),
#  ('39.62 cm (15.6 inch)  8 GB DDR4  Nitro Laptop Acer 64 bit Windows 10 1 TB HDD AMD Ryzen 5 Quad Core Processor',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 32, 'RAM'),
#     (33, 38, 'Model'),
#     (39, 45, 'Category'),
#     (46, 50, 'Brand'),
#     (51, 68, 'OS'),
#     (69, 77, 'Disk'),
#     (78, 109, 'Processor')]}),
#  ('Ideapad 512 GB SSD 64 bit Windows 10 8 GB DDR4  Laptop 39.62 cm (15.6 inch)  Lenovo AMD Ryzen 5 Quad Core Processor',
#   {'entities': [(0, 7, 'Model'),
#     (8, 18, 'Disk'),
#     (19, 36, 'OS'),
#     (37, 47, 'RAM'),
#     (48, 54, 'Category'),
#     (55, 76, 'Dim'),
#     (77, 83, 'Brand'),
#     (84, 115, 'Processor')]}),
#  ('64 bit Windows 10 Laptop Intel Core i7 Processor (9th Gen) Acer 1 TB HDD|256 GB SSD Predator 16 GB DDR4  39.62 cm (15.6 inch) ',
#   {'entities': [(0, 17, 'OS'),
#     (18, 24, 'Category'),
#     (25, 58, 'Processor'),
#     (59, 63, 'Brand'),
#     (64, 83, 'Disk'),
#     (84, 92, 'Model'),
#     (93, 104, 'RAM'),
#     (105, 126, 'Dim')]}),
#  ('64 bit Windows 10 Laptop Aspire 16 GB DDR4  Acer 43.94 cm (17.3 inch)  2 TB HDD|256 GB SSD Intel Core i7 Processor (9th Gen)',
#   {'entities': [(0, 17, 'OS'),
#     (18, 24, 'Category'),
#     (25, 31, 'Model'),
#     (32, 43, 'RAM'),
#     (44, 48, 'Brand'),
#     (49, 70, 'Dim'),
#     (71, 90, 'Disk'),
#     (91, 124, 'Processor')]}),
#  ('Laptop Asus 8 GB DDR4  35.56 cm (14 inch)  Vivo 512 GB SSD AMD APU Quad Core A12 Processor 64 bit Windows 10',
#   {'entities': [(0, 6, 'Category'),
#     (7, 11, 'Brand'),
#     (12, 22, 'RAM'),
#     (23, 42, 'Dim'),
#     (43, 47, 'Model'),
#     (48, 58, 'Disk'),
#     (59, 90, 'Processor'),
#     (91, 108, 'OS')]}),
#  ('64 bit Windows 10 Asus Laptop 8 GB DDR4  35.56 cm (14 inch)  AMD Ryzen 5 Quad Core Processor (2nd Gen) 512 GB SSD Vivo',
#   {'entities': [(0, 17, 'OS'),
#     (18, 22, 'Brand'),
#     (23, 29, 'Category'),
#     (30, 40, 'RAM'),
#     (41, 60, 'Dim'),
#     (61, 102, 'Processor'),
#     (103, 113, 'Disk'),
#     (114, 118, 'Model')]}),
#  ('4 GB DDR4  Laptop 64 bit Windows 10 Asus 256 GB SSD 35.56 cm (14 inch)  Intel Core i3 Processor (7th Gen) Vivo',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 17, 'Category'),
#     (18, 35, 'OS'),
#     (36, 40, 'Brand'),
#     (41, 51, 'Disk'),
#     (52, 71, 'Dim'),
#     (72, 105, 'Processor'),
#     (106, 110, 'Model')]}),
#  ('64 bit Windows 10 512 GB SSD Asus 35.56 cm (14 inch)  8 GB DDR4  Laptop Intel Core i5 Processor (8th Gen) Vivo',
#   {'entities': [(0, 17, 'OS'),
#     (18, 28, 'Disk'),
#     (29, 33, 'Brand'),
#     (34, 53, 'Dim'),
#     (54, 64, 'RAM'),
#     (65, 71, 'Category'),
#     (72, 105, 'Processor'),
#     (106, 110, 'Model')]}),
#  ('1 TB HDD|256 GB SSD Pavilion 64 bit Windows 10 Intel Core i5 Processor (9th Gen) 39.62 cm (15.6 inch)  8 GB DDR4  HP Laptop',
#   {'entities': [(0, 19, 'Disk'),
#     (20, 28, 'Model'),
#     (29, 46, 'OS'),
#     (47, 80, 'Processor'),
#     (81, 102, 'Dim'),
#     (103, 113, 'RAM'),
#     (114, 116, 'Brand'),
#     (117, 123, 'Category')]}),
#  ('64 bit Windows 10 Intel Core i7 Processor (9th Gen) Laptop 512 GB SSD 39.62 cm (15.6 inch)  16 GB DDR4  Inspiron Dell',
#   {'entities': [(0, 17, 'OS'),
#     (18, 51, 'Processor'),
#     (52, 58, 'Category'),
#     (59, 69, 'Disk'),
#     (70, 91, 'Dim'),
#     (92, 103, 'RAM'),
#     (104, 112, 'Model'),
#     (113, 117, 'Brand')]}),
#  ('Intel Core i3 Processor (8th Gen) 1 TB HDD 64 bit Windows 10 Laptop Ideapad 39.62 cm (15.6 inch)  Lenovo 4 GB DDR4 ',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 42, 'Disk'),
#     (43, 60, 'OS'),
#     (61, 67, 'Category'),
#     (68, 75, 'Model'),
#     (76, 97, 'Dim'),
#     (98, 104, 'Brand'),
#     (105, 115, 'RAM')]}),
#  ('8 GB DDR3  33.78 cm (13.3 inch)  256 GB SSD Laptop MacBook Pro Apple Mac Intel Core i5 Processor (8th Gen)',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 32, 'Dim'),
#     (33, 43, 'Disk'),
#     (44, 50, 'Category'),
#     (51, 62, 'Model'),
#     (63, 68, 'Brand'),
#     (69, 72, 'OS'),
#     (73, 106, 'Processor')]}),
#  ('Intel Core i5 Processor (8th Gen) Asus 256 GB SSD ZenBook 64 bit Windows 10 33.78 cm (13.3 inch)  Laptop 8 GB DDR3 ',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 38, 'Brand'),
#     (39, 49, 'Disk'),
#     (50, 57, 'Model'),
#     (58, 75, 'OS'),
#     (76, 97, 'Dim'),
#     (98, 104, 'Category'),
#     (105, 115, 'RAM')]}),
#  ('4 GB DDR4  39.62 cm (15.6 inch)  Ideapad 1 TB HDD 64 bit Windows 10 Lenovo Laptop Intel Core i5 Processor (8th Gen)',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 32, 'Dim'),
#     (33, 40, 'Model'),
#     (41, 49, 'Disk'),
#     (50, 67, 'OS'),
#     (68, 74, 'Brand'),
#     (75, 81, 'Category'),
#     (82, 115, 'Processor')]}),
#  ('HP 4 GB DDR4  Laptop 35.56 cm (14 inch)  Intel Core i3 Processor (7th Gen) 1 TB HDD Zbook D',
#   {'entities': [(0, 2, 'Brand'),
#     (3, 13, 'RAM'),
#     (14, 20, 'Category'),
#     (21, 40, 'Dim'),
#     (41, 74, 'Processor'),
#     (75, 83, 'Disk'),
#     (84, 89, 'Model'),
#     (90, 91, 'OS')]}),
#  ('33.78 cm (13.3 inch) Touchscreen  Intel Core i5 Processor (10th Gen) 8 GB DDR4  64 bit Windows 10 256 GB SSD Laptop HP Envy',
#   {'entities': [(0, 33, 'Dim'),
#     (34, 68, 'Processor'),
#     (69, 79, 'RAM'),
#     (80, 97, 'OS'),
#     (98, 108, 'Disk'),
#     (109, 115, 'Category'),
#     (116, 118, 'Brand'),
#     (119, 123, 'Model')]}),
#  ('Pavilion HP 512 GB SSD 8 GB DDR4  64 bit Windows 10 35.56 cm (14 inch)  Laptop Intel Core i5 Processor (10th Gen)',
#   {'entities': [(0, 8, 'Model'),
#     (9, 11, 'Brand'),
#     (12, 22, 'Disk'),
#     (23, 33, 'RAM'),
#     (34, 51, 'OS'),
#     (52, 71, 'Dim'),
#     (72, 78, 'Category'),
#     (79, 113, 'Processor')]}),
#  ('Laptop Asus ZenBook 32 GB DDR4  64 bit Windows 10 Intel Core i9 Processor (9th Gen) 1 TB SSD 39.62 cm (15.6 inch) Touchscreen ',
#   {'entities': [(0, 6, 'Category'),
#     (7, 11, 'Brand'),
#     (12, 19, 'Model'),
#     (20, 31, 'RAM'),
#     (32, 49, 'OS'),
#     (50, 83, 'Processor'),
#     (84, 92, 'Disk'),
#     (93, 126, 'Dim')]}),
#  ('Pavilion 64 bit Windows 10 Intel Core i5 Processor (8th Gen) 8 GB DDR4  1 TB HDD|8 GB SSD Laptop 35.56 cm (14 inch) Touchscreen  HP',
#   {'entities': [(0, 8, 'Model'),
#     (9, 26, 'OS'),
#     (27, 60, 'Processor'),
#     (61, 71, 'RAM'),
#     (72, 89, 'Disk'),
#     (90, 96, 'Category'),
#     (97, 128, 'Dim'),
#     (129, 131, 'Brand')]}),
#  ('Acer Nitro 39.62 cm (15.6 inch)  1 TB HDD|256 GB SSD 8 GB DDR4  64 bit Windows 10 Intel Core i5 Processor (9th Gen) Laptop',
#   {'entities': [(0, 4, 'Brand'),
#     (5, 10, 'Model'),
#     (11, 32, 'Dim'),
#     (33, 52, 'Disk'),
#     (53, 63, 'RAM'),
#     (64, 81, 'OS'),
#     (82, 115, 'Processor'),
#     (116, 122, 'Category')]}),
#  ('Lenovo 1 TB HDD Ideapad 4 GB DDR4  Intel Core i3 Processor (7th Gen) Laptop D 39.62 cm (15.6 inch) ',
#   {'entities': [(0, 6, 'Brand'),
#     (7, 15, 'Disk'),
#     (16, 23, 'Model'),
#     (24, 34, 'RAM'),
#     (35, 68, 'Processor'),
#     (69, 75, 'Category'),
#     (76, 77, 'OS'),
#     (78, 99, 'Dim')]}),
#  ('Laptop 1 TB HDD Intel Core i3 Processor (7th Gen) 64 bit Windows 10 4 GB DDR4  HP 35.56 cm (14 inch)  EliteBook',
#   {'entities': [(0, 6, 'Category'),
#     (7, 15, 'Disk'),
#     (16, 49, 'Processor'),
#     (50, 67, 'OS'),
#     (68, 78, 'RAM'),
#     (79, 81, 'Brand'),
#     (82, 101, 'Dim'),
#     (102, 111, 'Model')]}),
#  ('Asus AMD Ryzen 5 Quad Core Processor 39.62 cm (15.6 inch)  TUF Gaming 64 bit Windows 10 Laptop 1 TB HDD 4 GB DDR4 ',
#   {'entities': [(0, 4, 'Brand'),
#     (5, 36, 'Processor'),
#     (37, 58, 'Dim'),
#     (59, 69, 'Model'),
#     (70, 87, 'OS'),
#     (88, 94, 'Category'),
#     (95, 103, 'Disk'),
#     (104, 114, 'RAM')]}),
#  ('1 TB HDD 39.62 cm (15.6 inch)  Laptop 64 bit Windows 10 8 GB DDR4  Intel Core i3 Processor (8th Gen) HP Pavilion',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 30, 'Dim'),
#     (31, 37, 'Category'),
#     (38, 55, 'OS'),
#     (56, 66, 'RAM'),
#     (67, 100, 'Processor'),
#     (101, 103, 'Brand'),
#     (104, 112, 'Model')]}),
#  ('35.56 cm (14 inch)  1 TB HDD|256 GB SSD 8 GB DDR4  Intel Core i5 Processor (8th Gen) Vivo Laptop 64 bit Windows 10 Asus',
#   {'entities': [(0, 19, 'Dim'),
#     (20, 39, 'Disk'),
#     (40, 50, 'RAM'),
#     (51, 84, 'Processor'),
#     (85, 89, 'Model'),
#     (90, 96, 'Category'),
#     (97, 114, 'OS'),
#     (115, 119, 'Brand')]}),
#  ('33.78 cm (13.3 inch)  512 GB SSD Laptop Apple MacBook Pro Intel Core i5 Processor (8th Gen) 8 GB DDR3  Mac',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 32, 'Disk'),
#     (33, 39, 'Category'),
#     (40, 45, 'Brand'),
#     (46, 57, 'Model'),
#     (58, 91, 'Processor'),
#     (92, 102, 'RAM'),
#     (103, 106, 'OS')]}),
#  ('Intel Core i5 Processor (8th Gen) Laptop Vivo 512 GB SSD Asus 8 GB DDR4  64 bit Windows 10 35.56 cm (14 inch) ',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 40, 'Category'),
#     (41, 45, 'Model'),
#     (46, 56, 'Disk'),
#     (57, 61, 'Brand'),
#     (62, 72, 'RAM'),
#     (73, 90, 'OS'),
#     (91, 110, 'Dim')]}),
#  ('Lenovo 64 bit Windows 10 4 GB DDR4  1 TB HDD Intel Core i3 Processor (10th Gen) Laptop Ideapad 35.56 cm (14 inch) ',
#   {'entities': [(0, 6, 'Brand'),
#     (7, 24, 'OS'),
#     (25, 35, 'RAM'),
#     (36, 44, 'Disk'),
#     (45, 79, 'Processor'),
#     (80, 86, 'Category'),
#     (87, 94, 'Model'),
#     (95, 114, 'Dim')]}),
#  ('500 GB HDD Laptop 4 GB DDR4  AMD APU Dual Core A9 Processor 39.62 cm (15.6 inch)  HP 64 bit Windows 10 ProBook',
#   {'entities': [(0, 10, 'Disk'),
#     (11, 17, 'Category'),
#     (18, 28, 'RAM'),
#     (29, 59, 'Processor'),
#     (60, 81, 'Dim'),
#     (82, 84, 'Brand'),
#     (85, 102, 'OS'),
#     (103, 110, 'Model')]}),
#  ('Intel Core i3 Processor (8th Gen) Pavilion 64 bit Windows 10 35.56 cm (14 inch) Touchscreen  HP Laptop 4 GB DDR4  256 GB SSD',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 42, 'Model'),
#     (43, 60, 'OS'),
#     (61, 92, 'Dim'),
#     (93, 95, 'Brand'),
#     (96, 102, 'Category'),
#     (103, 113, 'RAM'),
#     (114, 124, 'Disk')]}),
#  ('256 GB SSD Laptop 64 bit Windows 10 Intel Core i5 Processor (8th Gen) Avita 35.56 cm (14 inch)  Liber 8 GB DDR4 ',
#   {'entities': [(0, 10, 'Disk'),
#     (11, 17, 'Category'),
#     (18, 35, 'OS'),
#     (36, 69, 'Processor'),
#     (70, 75, 'Brand'),
#     (76, 95, 'Dim'),
#     (96, 101, 'Model'),
#     (102, 112, 'RAM')]}),
#  ('8 GB DDR4  39.62 cm (15.6 inch)  1 TB HDD|128 GB SSD 64 bit Windows 10 Laptop HP AMD Ryzen 7 Quad Core Processor Pavilion',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 32, 'Dim'),
#     (33, 52, 'Disk'),
#     (53, 70, 'OS'),
#     (71, 77, 'Category'),
#     (78, 80, 'Brand'),
#     (81, 112, 'Processor'),
#     (113, 121, 'Model')]}),
#  ('8 GB DDR3  64 bit Windows 10 Microsoft 34.29 cm (13.5 inch) Touchscreen  Intel Core i7 Processor (7th Gen) Laptop Surface 256 GB SSD',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 28, 'OS'),
#     (29, 38, 'Brand'),
#     (39, 72, 'Dim'),
#     (73, 106, 'Processor'),
#     (107, 113, 'Category'),
#     (114, 121, 'Model'),
#     (122, 132, 'Disk')]}),
#  ('ZenBook 256 GB SSD 8 GB DDR3  64 bit Windows 10 35.56 cm (14 inch)  Intel Core i5 Processor (8th Gen) Asus Laptop',
#   {'entities': [(0, 7, 'Model'),
#     (8, 18, 'Disk'),
#     (19, 29, 'RAM'),
#     (30, 47, 'OS'),
#     (48, 67, 'Dim'),
#     (68, 101, 'Processor'),
#     (102, 106, 'Brand'),
#     (107, 113, 'Category')]}),
#  ('Gaming 1 TB SSD 32 GB DDR4  Laptop 64 bit Windows 10 Intel Core i7 Processor (9th Gen) MSI 39.62 cm (15.6 inch) ',
#   {'entities': [(0, 6, 'Model'),
#     (7, 15, 'Disk'),
#     (16, 27, 'RAM'),
#     (28, 34, 'Category'),
#     (35, 52, 'OS'),
#     (53, 86, 'Processor'),
#     (87, 90, 'Brand'),
#     (91, 112, 'Dim')]}),
#  ('Intel Core i5 Processor (8th Gen) 8 GB DDR4  Laptop 64 bit Windows 10 256 GB SSD Avita Liber 35.56 cm (14 inch) ',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 44, 'RAM'),
#     (45, 51, 'Category'),
#     (52, 69, 'OS'),
#     (70, 80, 'Disk'),
#     (81, 86, 'Brand'),
#     (87, 92, 'Model'),
#     (93, 112, 'Dim')]}),
#  ('Acer 1 TB HDD 8 GB DDR4  39.62 cm (15.6 inch)  Intel Core i7 Processor (8th Gen) 64 bit Windows 10 Nitro Laptop',
#   {'entities': [(0, 4, 'Brand'),
#     (5, 13, 'Disk'),
#     (14, 24, 'RAM'),
#     (25, 46, 'Dim'),
#     (47, 80, 'Processor'),
#     (81, 98, 'OS'),
#     (99, 104, 'Model'),
#     (105, 111, 'Category')]}),
#  ('8 GB DDR4  1 TB HDD|256 GB SSD Intel Core i5 Processor (8th Gen) Asus 64 bit Windows 10 35.56 cm (14 inch)  Vivo Laptop',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 30, 'Disk'),
#     (31, 64, 'Processor'),
#     (65, 69, 'Brand'),
#     (70, 87, 'OS'),
#     (88, 107, 'Dim'),
#     (108, 112, 'Model'),
#     (113, 119, 'Category')]}),
#  ('Asus Vivo 64 bit Windows 10 256 GB SSD 35.56 cm (14 inch)  4 GB DDR4  Laptop Intel Core i3 Processor (7th Gen)',
#   {'entities': [(0, 4, 'Brand'),
#     (5, 9, 'Model'),
#     (10, 27, 'OS'),
#     (28, 38, 'Disk'),
#     (39, 58, 'Dim'),
#     (59, 69, 'RAM'),
#     (70, 76, 'Category'),
#     (77, 110, 'Processor')]}),
#  ('64 bit Windows 10 39.62 cm (15.6 inch)  Legion 8 GB DDR4  Laptop Intel Core i7 Processor (8th Gen) Lenovo 1 TB HDD|128 GB SSD',
#   {'entities': [(0, 17, 'OS'),
#     (18, 39, 'Dim'),
#     (40, 46, 'Model'),
#     (47, 57, 'RAM'),
#     (58, 64, 'Category'),
#     (65, 98, 'Processor'),
#     (99, 105, 'Brand'),
#     (106, 125, 'Disk')]}),
#  ('512 GB SSD Yoga 8 GB DDR4  Lenovo Laptop 33.78 cm (13.3 inch) Touchscreen  Intel Core i5 Processor (8th Gen) 64 bit Windows 10',
#   {'entities': [(0, 10, 'Disk'),
#     (11, 15, 'Model'),
#     (16, 26, 'RAM'),
#     (27, 33, 'Brand'),
#     (34, 40, 'Category'),
#     (41, 74, 'Dim'),
#     (75, 108, 'Processor'),
#     (109, 126, 'OS')]}),
#  ('8 GB DDR4  Pavilion HP Intel Core i7 Processor (9th Gen) 64 bit Windows 10 39.62 cm (15.6 inch)  Laptop 1 TB HDD|256 GB SSD',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 19, 'Model'),
#     (20, 22, 'Brand'),
#     (23, 56, 'Processor'),
#     (57, 74, 'OS'),
#     (75, 96, 'Dim'),
#     (97, 103, 'Category'),
#     (104, 123, 'Disk')]}),
#  ('4 GB DDR4  64 bit Windows 10 Intel Core i3 Processor (10th Gen) 256 GB SSD HP Pavilion Laptop 35.56 cm (14 inch) Touchscreen ',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 28, 'OS'),
#     (29, 63, 'Processor'),
#     (64, 74, 'Disk'),
#     (75, 77, 'Brand'),
#     (78, 86, 'Model'),
#     (87, 93, 'Category'),
#     (94, 125, 'Dim')]}),
#  ('HP Intel Core i3 Processor (7th Gen) Pavilion Laptop 4 GB DDR4  39.62 cm (15.6 inch)  1 TB HDD 64 bit D',
#   {'entities': [(0, 2, 'Brand'),
#     (3, 36, 'Processor'),
#     (37, 45, 'Model'),
#     (46, 52, 'Category'),
#     (53, 63, 'RAM'),
#     (64, 85, 'Dim'),
#     (86, 94, 'Disk'),
#     (95, 103, 'OS')]}),
#  ('Laptop Intel Core i5 Processor (8th Gen) Dell 64 bit Windows 10 39.62 cm (15.6 inch)  Inspiron 1 TB HDD|512 GB SSD 8 GB DDR4 ',
#   {'entities': [(0, 6, 'Category'),
#     (7, 40, 'Processor'),
#     (41, 45, 'Brand'),
#     (46, 63, 'OS'),
#     (64, 85, 'Dim'),
#     (86, 94, 'Model'),
#     (95, 114, 'Disk'),
#     (115, 125, 'RAM')]}),
#  ('MacBook Air 128 GB SSD Apple 8 GB DDR3  Laptop Mac Intel Core i5 Processor (8th Gen) 33.78 cm (13.3 inch) ',
#   {'entities': [(0, 11, 'Model'),
#     (12, 22, 'Disk'),
#     (23, 28, 'Brand'),
#     (29, 39, 'RAM'),
#     (40, 46, 'Category'),
#     (47, 50, 'OS'),
#     (51, 84, 'Processor'),
#     (85, 106, 'Dim')]}),
#  ('Intel Core i5 Processor (7th Gen) 64 bit Mac MacBook Pro 33.78 cm (13.3 inch)  Laptop 128 GB SSD Apple 8 GB DDR3 ',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 44, 'OS'),
#     (45, 56, 'Model'),
#     (57, 78, 'Dim'),
#     (79, 85, 'Category'),
#     (86, 96, 'Disk'),
#     (97, 102, 'Brand'),
#     (103, 113, 'RAM')]}),
#  ('35.56 cm (14 inch)  Intel Core i5 Processor (8th Gen) Laptop Liber 64 bit Windows 10 8 GB DDR4  256 GB SSD Avita',
#   {'entities': [(0, 19, 'Dim'),
#     (20, 53, 'Processor'),
#     (54, 60, 'Category'),
#     (61, 66, 'Model'),
#     (67, 84, 'OS'),
#     (85, 95, 'RAM'),
#     (96, 106, 'Disk'),
#     (107, 112, 'Brand')]}),
#  ('Microsoft 31.24 cm (12.3 inch) Touchscreen  8 GB DDR3  SurfacePro Laptop 64 bit Windows 10 256 GB SSD Intel Core i5 Processor (8th Gen)',
#   {'entities': [(0, 9, 'Brand'),
#     (10, 43, 'Dim'),
#     (44, 54, 'RAM'),
#     (55, 65, 'Model'),
#     (66, 72, 'Category'),
#     (73, 90, 'OS'),
#     (91, 101, 'Disk'),
#     (102, 135, 'Processor')]}),
#  ('64 bit Windows 10 Acer Laptop 16 GB DDR4  2 TB HDD|256 GB SSD Predator Intel Core i7 Processor (7th Gen) 43.94 cm (17.3 inch) ',
#   {'entities': [(0, 17, 'OS'),
#     (18, 22, 'Brand'),
#     (23, 29, 'Category'),
#     (30, 41, 'RAM'),
#     (42, 61, 'Disk'),
#     (62, 70, 'Model'),
#     (71, 104, 'Processor'),
#     (105, 126, 'Dim')]}),
#  ('Ideapad 4 GB DDR4  Laptop 1 TB HDD Lenovo 64 bit Windows 10 39.62 cm (15.6 inch)  Intel Core i3 Processor (7th Gen)',
#   {'entities': [(0, 7, 'Model'),
#     (8, 18, 'RAM'),
#     (19, 25, 'Category'),
#     (26, 34, 'Disk'),
#     (35, 41, 'Brand'),
#     (42, 59, 'OS'),
#     (60, 81, 'Dim'),
#     (82, 115, 'Processor')]}),
#  ('Laptop Modern MSI 8 GB DDR4  512 GB SSD 35.56 cm (14 inch)  64 bit Windows 10 Intel Core i7 Processor (10th Gen)',
#   {'entities': [(0, 6, 'Category'),
#     (7, 13, 'Model'),
#     (14, 17, 'Brand'),
#     (18, 28, 'RAM'),
#     (29, 39, 'Disk'),
#     (40, 59, 'Dim'),
#     (60, 77, 'OS'),
#     (78, 112, 'Processor')]}),
#  ('8 GB DDR4  512 GB SSD Lenovo 64 bit Windows 10 Yoga 35.56 cm (14 inch) Touchscreen  Laptop Intel Core i5 Processor (8th Gen)',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 21, 'Disk'),
#     (22, 28, 'Brand'),
#     (29, 46, 'OS'),
#     (47, 51, 'Model'),
#     (52, 83, 'Dim'),
#     (84, 90, 'Category'),
#     (91, 124, 'Processor')]}),
#  ('Intel Core i3 Processor (7th Gen) 39.62 cm (15.6 inch)  TUF Gaming Asus Laptop 1 TB HDD 64 bit Endl 4 GB DDR4 ',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 55, 'Dim'),
#     (56, 66, 'Model'),
#     (67, 71, 'Brand'),
#     (72, 78, 'Category'),
#     (79, 87, 'Disk'),
#     (88, 99, 'OS'),
#     (100, 110, 'RAM')]}),
#  ('8 GB DDR4  Intel Core i5 Processor (8th Gen) 33.78 cm (13.3 inch)  Aspire 64 bit Windows 10 Laptop Acer 256 GB SSD',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 44, 'Processor'),
#     (45, 66, 'Dim'),
#     (67, 73, 'Model'),
#     (74, 91, 'OS'),
#     (92, 98, 'Category'),
#     (99, 103, 'Brand'),
#     (104, 114, 'Disk')]}),
#  ('HP 4 GB DDR4  64 bit Windows 10 Laptop 39.62 cm (15.6 inch)  Intel Core i3 Processor (8th Gen) 1 TB HDD EliteBook',
#   {'entities': [(0, 2, 'Brand'),
#     (3, 13, 'RAM'),
#     (14, 31, 'OS'),
#     (32, 38, 'Category'),
#     (39, 60, 'Dim'),
#     (61, 94, 'Processor'),
#     (95, 103, 'Disk'),
#     (104, 113, 'Model')]}),
#  ('Ideapad 64 bit Windows 10 512 GB SSD Intel Core i7 Processor (8th Gen) 33.78 cm (13.3 inch)  Lenovo Laptop 8 GB DDR4 ',
#   {'entities': [(0, 7, 'Model'),
#     (8, 25, 'OS'),
#     (26, 36, 'Disk'),
#     (37, 70, 'Processor'),
#     (71, 92, 'Dim'),
#     (93, 99, 'Brand'),
#     (100, 106, 'Category'),
#     (107, 117, 'RAM')]}),
#  ('Intel Core i5 Processor (8th Gen) Mac 8 GB DDR3  Laptop 33.78 cm (13.3 inch)  Apple 128 GB SSD MacBook Pro',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 37, 'OS'),
#     (38, 48, 'RAM'),
#     (49, 55, 'Category'),
#     (56, 77, 'Dim'),
#     (78, 83, 'Brand'),
#     (84, 94, 'Disk'),
#     (95, 106, 'Model')]}),
#  ('Intel Core i7 Processor (9th Gen) 32 GB DDR4  Laptop Asus 1 TB SSD 64 bit Windows 10 39.62 cm (15.6 inch) Touchscreen  ZenBook',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 45, 'RAM'),
#     (46, 52, 'Category'),
#     (53, 57, 'Brand'),
#     (58, 66, 'Disk'),
#     (67, 84, 'OS'),
#     (85, 118, 'Dim'),
#     (119, 126, 'Model')]}),
# ...
#     (58, 68, 'Disk'),
#     (69, 103, 'Processor'),
#     (104, 121, 'OS'),
#     (122, 124, 'Brand')]}),
#  ('8 GB DDR3  XPS Dell 64 bit Windows 10 Intel Core i5 Processor (7th Gen) 256 GB SSD 33.78 cm (13.3 inch)  Laptop',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 14, 'Model'),
#     (15, 19, 'Brand'),
#     (20, 37, 'OS'),
#     (38, 71, 'Processor'),
#     (72, 82, 'Disk'),
#     (83, 104, 'Dim'),
#     (105, 111, 'Category')]}),
#  ('39.62 cm (15.6 inch)  Laptop Ideapad 64 bit Windows 10 Intel Core i3 Processor (7th Gen) 1 TB HDD Lenovo 4 GB DDR4 ',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 28, 'Category'),
#     (29, 36, 'Model'),
#     (37, 54, 'OS'),
#     (55, 88, 'Processor'),
#     (89, 97, 'Disk'),
#     (98, 104, 'Brand'),
#     (105, 115, 'RAM')]}),
#  ('64 bit Windows 10 1 TB HDD Intel Core i5 Processor (8th Gen) Laptop Asus Vivo 8 GB DDR4  39.62 cm (15.6 inch) ',
#   {'entities': [(0, 17, 'OS'),
#     (18, 26, 'Disk'),
#     (27, 60, 'Processor'),
#     (61, 67, 'Category'),
#     (68, 72, 'Brand'),
#     (73, 77, 'Model'),
#     (78, 88, 'RAM'),
#     (89, 110, 'Dim')]}),
#  ('Intel Core i5 Processor (5th Gen) 128 GB SSD MacBook Air 8 GB  Laptop Apple Mac 33.78 cm (13.3 inch) ',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 44, 'Disk'),
#     (45, 56, 'Model'),
#     (57, 62, 'RAM'),
#     (63, 69, 'Category'),
#     (70, 75, 'Brand'),
#     (76, 79, 'OS'),
#     (80, 101, 'Dim')]}),
#  ('4 GB DDR4  64 bit Windows 10 Laptop AMD Ryzen 3 Quad Core Processor 39.62 cm (15.6 inch)  1 TB HDD Inspiron Dell',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 28, 'OS'),
#     (29, 35, 'Category'),
#     (36, 67, 'Processor'),
#     (68, 89, 'Dim'),
#     (90, 98, 'Disk'),
#     (99, 107, 'Model'),
#     (108, 112, 'Brand')]}),
#  ('Laptop Intel Core i5 Processor (8th Gen) 39.62 cm (15.6 inch)  8 GB DDR4  1 TB HDD D Lenovo Ideapad',
#   {'entities': [(0, 6, 'Category'),
#     (7, 40, 'Processor'),
#     (41, 62, 'Dim'),
#     (63, 73, 'RAM'),
#     (74, 82, 'Disk'),
#     (83, 84, 'OS'),
#     (85, 91, 'Brand'),
#     (92, 99, 'Model')]}),
#  ('Pavilion HP Intel Core i7 Processor (9th Gen) 1 TB HDD|512 GB SSD Laptop 39.62 cm (15.6 inch)  64 bit Windows 10 12 GB DDR4 ',
#   {'entities': [(0, 8, 'Model'),
#     (9, 11, 'Brand'),
#     (12, 45, 'Processor'),
#     (46, 65, 'Disk'),
#     (66, 72, 'Category'),
#     (73, 94, 'Dim'),
#     (95, 112, 'OS'),
#     (113, 124, 'RAM')]}),
#  ('Ideapad 1 TB HDD 64 bit Windows 10 8 GB DDR4  Laptop 39.62 cm (15.6 inch)  Lenovo Intel Core i5 Processor (8th Gen)',
#   {'entities': [(0, 7, 'Model'),
#     (8, 16, 'Disk'),
#     (17, 34, 'OS'),
#     (35, 45, 'RAM'),
#     (46, 52, 'Category'),
#     (53, 74, 'Dim'),
#     (75, 81, 'Brand'),
#     (82, 115, 'Processor')]}),
#  ('64 bit Windows 10 Dell Intel Core i5 Processor (8th Gen) 8 GB DDR4  39.62 cm (15.6 inch)  2 TB HDD Inspiron Laptop',
#   {'entities': [(0, 17, 'OS'),
#     (18, 22, 'Brand'),
#     (23, 56, 'Processor'),
#     (57, 67, 'RAM'),
#     (68, 89, 'Dim'),
#     (90, 98, 'Disk'),
#     (99, 107, 'Model'),
#     (108, 114, 'Category')]}),
#  ('39.62 cm (15.6 inch)  Pavilion Intel Core i7 Processor (9th Gen) Laptop 12 GB DDR4  64 bit Windows 10 HP 1 TB HDD|512 GB SSD',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 30, 'Model'),
#     (31, 64, 'Processor'),
#     (65, 71, 'Category'),
#     (72, 83, 'RAM'),
#     (84, 101, 'OS'),
#     (102, 104, 'Brand'),
#     (105, 124, 'Disk')]}),
#  ('4 GB DDR4  Intel Core i3 Processor (7th Gen) Laptop Ideapad 39.62 cm (15.6 inch)  64 bit Windows 10 1 TB HDD Lenovo',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 44, 'Processor'),
#     (45, 51, 'Category'),
#     (52, 59, 'Model'),
#     (60, 81, 'Dim'),
#     (82, 99, 'OS'),
#     (100, 108, 'Disk'),
#     (109, 115, 'Brand')]}),
#  ('4 GB DDR4  1 TB HDD 64 bit Windows 10 39.62 cm (15.6 inch)  Laptop Intel Core i3 Processor (8th Gen) Dell Inspiron',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 19, 'Disk'),
#     (20, 37, 'OS'),
#     (38, 59, 'Dim'),
#     (60, 66, 'Category'),
#     (67, 100, 'Processor'),
#     (101, 105, 'Brand'),
#     (106, 114, 'Model')]}),
#  ('Intel Core i7 Processor (8th Gen) Pavilion 8 GB DDR4  64 bit Windows 10 512 GB SSD 35.56 cm (14 inch)  HP Laptop',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 42, 'Model'),
#     (43, 53, 'RAM'),
#     (54, 71, 'OS'),
#     (72, 82, 'Disk'),
#     (83, 102, 'Dim'),
#     (103, 105, 'Brand'),
#     (106, 112, 'Category')]}),
#  ('Aspire 8 GB DDR4  Laptop 1 TB HDD Acer 64 bit Windows 10 39.62 cm (15.6 inch)  Intel Core i5 Processor (7th Gen)',
#   {'entities': [(0, 6, 'Model'),
#     (7, 17, 'RAM'),
#     (18, 24, 'Category'),
#     (25, 33, 'Disk'),
#     (34, 38, 'Brand'),
#     (39, 56, 'OS'),
#     (57, 78, 'Dim'),
#     (79, 112, 'Processor')]}),
#  ('64 bit Windows 10 2 TB HDD|128 GB SSD 8 GB DDR4  Dell Intel Core i7 Processor (8th Gen) 39.62 cm (15.6 inch)  Inspiron Laptop',
#   {'entities': [(0, 17, 'OS'),
#     (18, 37, 'Disk'),
#     (38, 48, 'RAM'),
#     (49, 53, 'Brand'),
#     (54, 87, 'Processor'),
#     (88, 109, 'Dim'),
#     (110, 118, 'Model'),
#     (119, 125, 'Category')]}),
#  ('Asus 64 bit Windows 10 33.78 cm (13.3 inch)  Intel Core i5 Processor (8th Gen) ZenBook 8 GB DDR3  Laptop 512 GB SSD',
#   {'entities': [(0, 4, 'Brand'),
#     (5, 22, 'OS'),
#     (23, 44, 'Dim'),
#     (45, 78, 'Processor'),
#     (79, 86, 'Model'),
#     (87, 97, 'RAM'),
#     (98, 104, 'Category'),
#     (105, 115, 'Disk')]}),
#  ('Laptop Intel Core i5 Processor (8th Gen) 8 GB DDR4  HP Pavilion 64 bit Windows 10 39.62 cm (15.6 inch)  1 TB HDD|256 GB SSD',
#   {'entities': [(0, 6, 'Category'),
#     (7, 40, 'Processor'),
#     (41, 51, 'RAM'),
#     (52, 54, 'Brand'),
#     (55, 63, 'Model'),
#     (64, 81, 'OS'),
#     (82, 103, 'Dim'),
#     (104, 123, 'Disk')]}),
#  ('Pavilion 1 TB HDD Intel Core i3 Processor (7th Gen) HP 8 GB DDR4  39.62 cm (15.6 inch)  Laptop 64 bit Windows 10',
#   {'entities': [(0, 8, 'Model'),
#     (9, 17, 'Disk'),
#     (18, 51, 'Processor'),
#     (52, 54, 'Brand'),
#     (55, 65, 'RAM'),
#     (66, 87, 'Dim'),
#     (88, 94, 'Category'),
#     (95, 112, 'OS')]}),
#  ('39.62 cm (15.6 inch)  Lenovo 1 TB HDD 4 GB DDR3  Ideapad Laptop Intel Pentium Quad Core Processor D',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 28, 'Brand'),
#     (29, 37, 'Disk'),
#     (38, 48, 'RAM'),
#     (49, 56, 'Model'),
#     (57, 63, 'Category'),
#     (64, 97, 'Processor'),
#     (98, 99, 'OS')]}),
#  ('1 TB HDD Intel Core i3 Processor (7th Gen) Envy HP 39.62 cm (15.6 inch)  4 GB DDR4  Laptop D',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 42, 'Processor'),
#     (43, 47, 'Model'),
#     (48, 50, 'Brand'),
#     (51, 72, 'Dim'),
#     (73, 83, 'RAM'),
#     (84, 90, 'Category'),
#     (91, 92, 'OS')]}),
#  ('Ideapad 2 TB HDD Laptop 8 GB DDR4  Lenovo 39.62 cm (15.6 inch)  Intel Core i5 Processor (8th Gen) 64 bit Windows 10',
#   {'entities': [(0, 7, 'Model'),
#     (8, 16, 'Disk'),
#     (17, 23, 'Category'),
#     (24, 34, 'RAM'),
#     (35, 41, 'Brand'),
#     (42, 63, 'Dim'),
#     (64, 97, 'Processor'),
#     (98, 115, 'OS')]}),
#  ('ThinkPad X Series Intel Core i3 Processor (7th Gen) 500 GB HDD 4 GB DDR4  64 bit Windows 10 Lenovo Laptop 35.56 cm (14 inch) ',
#   {'entities': [(0, 17, 'Model'),
#     (18, 51, 'Processor'),
#     (52, 62, 'Disk'),
#     (63, 73, 'RAM'),
#     (74, 91, 'OS'),
#     (92, 98, 'Brand'),
#     (99, 105, 'Category'),
#     (106, 125, 'Dim')]}),
#  ('8 GB DDR4  Intel Core i7 Processor (7th Gen) Orion Laptop AGB 1 TB HDD|512 GB SSD 35.56 cm (14 inch)  64 bit Windows 10',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 44, 'Processor'),
#     (45, 50, 'Model'),
#     (51, 57, 'Category'),
#     (58, 61, 'Brand'),
#     (62, 81, 'Disk'),
#     (82, 101, 'Dim'),
#     (102, 119, 'OS')]}),
#  ('64 bit Windows 10 4 GB DDR4  1 TB HDD Lenovo 35.56 cm (14 inch)  Laptop Intel Core i3 Processor (7th Gen) Ideapad',
#   {'entities': [(0, 17, 'OS'),
#     (18, 28, 'RAM'),
#     (29, 37, 'Disk'),
#     (38, 44, 'Brand'),
#     (45, 64, 'Dim'),
#     (65, 71, 'Category'),
#     (72, 105, 'Processor'),
#     (106, 113, 'Model')]}),
#  ('Pavilion HP Laptop 1 TB HDD 4 GB DDR4  39.62 cm (15.6 inch)  Intel Core i5 Processor (7th Gen) D',
#   {'entities': [(0, 8, 'Model'),
#     (9, 11, 'Brand'),
#     (12, 18, 'Category'),
#     (19, 27, 'Disk'),
#     (28, 38, 'RAM'),
#     (39, 60, 'Dim'),
#     (61, 94, 'Processor'),
#     (95, 96, 'OS')]}),
#  ('Laptop HP 39.62 cm (15.6 inch)  64 bit Windows 10 4 GB DDR4  Intel Core i5 Processor (7th Gen) 1 TB HDD Zbook',
#   {'entities': [(0, 6, 'Category'),
#     (7, 9, 'Brand'),
#     (10, 31, 'Dim'),
#     (32, 49, 'OS'),
#     (50, 60, 'RAM'),
#     (61, 94, 'Processor'),
#     (95, 103, 'Disk'),
#     (104, 109, 'Model')]}),
#  ('35.56 cm (14 inch)  4 GB DDR4  Envy 64 bit Windows 10 1 TB HDD Intel Core i3 Processor (7th Gen) Laptop HP',
#   {'entities': [(0, 19, 'Dim'),
#     (20, 30, 'RAM'),
#     (31, 35, 'Model'),
#     (36, 53, 'OS'),
#     (54, 62, 'Disk'),
#     (63, 96, 'Processor'),
#     (97, 103, 'Category'),
#     (104, 106, 'Brand')]}),
#  ('Intel Core i5 Processor (8th Gen) Ideapad 39.62 cm (15.6 inch)  Laptop Lenovo 8 GB DDR4  64 bit Windows 10 1 TB HDD',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 41, 'Model'),
#     (42, 63, 'Dim'),
#     (64, 70, 'Category'),
#     (71, 77, 'Brand'),
#     (78, 88, 'RAM'),
#     (89, 106, 'OS'),
#     (107, 115, 'Disk')]}),
#  ('4 GB DDR4  Dell Intel Core i5 Processor (8th Gen) 39.62 cm (15.6 inch)  Laptop Inspiron 64 bit Windows 10 2 TB HDD',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 15, 'Brand'),
#     (16, 49, 'Processor'),
#     (50, 71, 'Dim'),
#     (72, 78, 'Category'),
#     (79, 87, 'Model'),
#     (88, 105, 'OS'),
#     (106, 114, 'Disk')]}),
#  ('HP 4 GB DDR4  Laptop 35.56 cm (14 inch) Touchscreen  64 bit Windows 10 Pavilion Intel Core i3 Processor (8th Gen) 1 TB HDD|8 GB SSD',
#   {'entities': [(0, 2, 'Brand'),
#     (3, 13, 'RAM'),
#     (14, 20, 'Category'),
#     (21, 52, 'Dim'),
#     (53, 70, 'OS'),
#     (71, 79, 'Model'),
#     (80, 113, 'Processor'),
#     (114, 131, 'Disk')]}),
#  ('16 GB DDR3  ZenBook Intel Core i7 Processor (10th Gen) 35.56 cm (14 inch)  1 TB SSD 64 bit Windows 10 Asus Laptop',
#   {'entities': [(0, 11, 'RAM'),
#     (12, 19, 'Model'),
#     (20, 54, 'Processor'),
#     (55, 74, 'Dim'),
#     (75, 83, 'Disk'),
#     (84, 101, 'OS'),
#     (102, 106, 'Brand'),
#     (107, 113, 'Category')]}),
#  ('8 GB DDR4  HP 64 bit Windows 10 39.62 cm (15.6 inch)  Pavilion Intel Core i5 Processor (8th Gen) Laptop 1 TB HDD',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 13, 'Brand'),
#     (14, 31, 'OS'),
#     (32, 53, 'Dim'),
#     (54, 62, 'Model'),
#     (63, 96, 'Processor'),
#     (97, 103, 'Category'),
#     (104, 112, 'Disk')]}),
#  ('39.62 cm (15.6 inch)  Laptop 1 TB HDD 64 bit Windows 10 8 GB DDR4  Asus Vivo Intel Core i3 Processor (7th Gen)',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 28, 'Category'),
#     (29, 37, 'Disk'),
#     (38, 55, 'OS'),
#     (56, 66, 'RAM'),
#     (67, 71, 'Brand'),
#     (72, 76, 'Model'),
#     (77, 110, 'Processor')]}),
#  ('1 TB HDD Intel Core i3 Processor (7th Gen) Laptop 64 bit Windows 10 HP Envy 4 GB DDR4  35.56 cm (14 inch) ',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 42, 'Processor'),
#     (43, 49, 'Category'),
#     (50, 67, 'OS'),
#     (68, 70, 'Brand'),
#     (71, 75, 'Model'),
#     (76, 86, 'RAM'),
#     (87, 106, 'Dim')]}),
#  ('1 TB HDD Laptop 39.62 cm (15.6 inch)  HP Intel Core i5 Processor (8th Gen) 8 GB DDR4  Pavilion D',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 15, 'Category'),
#     (16, 37, 'Dim'),
#     (38, 40, 'Brand'),
#     (41, 74, 'Processor'),
#     (75, 85, 'RAM'),
#     (86, 94, 'Model'),
#     (95, 96, 'OS')]}),
#  ('8 GB DDR3  Microsoft Intel Core i5 Processor (8th Gen) SurfacePro 31.24 cm (12.3 inch) Touchscreen  128 GB SSD 64 bit Windows 10 Laptop',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 20, 'Brand'),
#     (21, 54, 'Processor'),
#     (55, 65, 'Model'),
#     (66, 99, 'Dim'),
#     (100, 110, 'Disk'),
#     (111, 128, 'OS'),
#     (129, 135, 'Category')]}),
#  ('4 GB DDR4  Asus 39.62 cm (15.6 inch)  Intel Core i3 Processor (7th Gen) 64 bit Windows 10 Vivo 1 TB HDD Laptop',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 15, 'Brand'),
#     (16, 37, 'Dim'),
#     (38, 71, 'Processor'),
#     (72, 89, 'OS'),
#     (90, 94, 'Model'),
#     (95, 103, 'Disk'),
#     (104, 110, 'Category')]}),
#  ('8 GB DDR3  64 bit Windows 10 XPS Intel Core i5 Processor (8th Gen) Dell Laptop 256 GB SSD 33.02 cm (13 inch) ',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 28, 'OS'),
#     (29, 32, 'Model'),
#     (33, 66, 'Processor'),
#     (67, 71, 'Brand'),
#     (72, 78, 'Category'),
#     (79, 89, 'Disk'),
#     (90, 109, 'Dim')]}),
#  ('8 GB DDR4  Intel Core i5 Processor (8th Gen) 64 bit Windows 10 Asus Laptop 39.62 cm (15.6 inch)  ZenBook 1 TB HDD',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 44, 'Processor'),
#     (45, 62, 'OS'),
#     (63, 67, 'Brand'),
#     (68, 74, 'Category'),
#     (75, 96, 'Dim'),
#     (97, 104, 'Model'),
#     (105, 113, 'Disk')]}),
#  ('AMD Ryzen 5 Quad Core Processor 64 bit Windows 10 8 GB DDR4  Vivo Asus Laptop 1 TB HDD 39.62 cm (15.6 inch) ',
#   {'entities': [(0, 31, 'Processor'),
#     (32, 49, 'OS'),
#     (50, 60, 'RAM'),
#     (61, 65, 'Model'),
#     (66, 70, 'Brand'),
#     (71, 77, 'Category'),
#     (78, 86, 'Disk'),
#     (87, 108, 'Dim')]}),
#  ('39.62 cm (15.6 inch)  8 GB DDR4  Ideapad Intel Core i5 Processor (8th Gen) Lenovo 512 GB SSD Laptop 64 bit Windows 10',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 32, 'RAM'),
#     (33, 40, 'Model'),
#     (41, 74, 'Processor'),
#     (75, 81, 'Brand'),
#     (82, 92, 'Disk'),
#     (93, 99, 'Category'),
#     (100, 117, 'OS')]}),
#  ('64 bit Windows 10 Laptop Ideapad 1 TB HDD Lenovo 4 GB DDR4  Intel Core i3 Processor (7th Gen) 39.62 cm (15.6 inch) ',
#   {'entities': [(0, 17, 'OS'),
#     (18, 24, 'Category'),
#     (25, 32, 'Model'),
#     (33, 41, 'Disk'),
#     (42, 48, 'Brand'),
#     (49, 59, 'RAM'),
#     (60, 93, 'Processor'),
#     (94, 115, 'Dim')]}),
#  ('EliteBook Laptop HP 512 GB SSD 64 bit Windows 10 16 GB DDR4  39.62 cm (15.6 inch) Touchscreen  Intel Core i7 Processor (10th Gen)',
#   {'entities': [(0, 9, 'Model'),
#     (10, 16, 'Category'),
#     (17, 19, 'Brand'),
#     (20, 30, 'Disk'),
#     (31, 48, 'OS'),
#     (49, 60, 'RAM'),
#     (61, 94, 'Dim'),
#     (95, 129, 'Processor')]}),
#  ('1 TB HDD 35.56 cm (14 inch)  Laptop 64 bit Linux/Ubuntu 8 GB DDR4  Dell XPS Intel Core i3 Processor (8th Gen)',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 28, 'Dim'),
#     (29, 35, 'Category'),
#     (36, 55, 'OS'),
#     (56, 66, 'RAM'),
#     (67, 71, 'Brand'),
#     (72, 75, 'Model'),
#     (76, 109, 'Processor')]}),
#  ('16 GB DDR4  33.78 cm (13.3 inch) Touchscreen  Laptop 512 GB SSD 64 bit Windows 10 Intel Core i7 Processor (8th Gen) HP EliteBook',
#   {'entities': [(0, 11, 'RAM'),
#     (12, 45, 'Dim'),
#     (46, 52, 'Category'),
#     (53, 63, 'Disk'),
#     (64, 81, 'OS'),
#     (82, 115, 'Processor'),
#     (116, 118, 'Brand'),
#     (119, 128, 'Model')]}),
#  ('Laptop Intel Core i3 Processor (7th Gen) 1 TB HDD 35.56 cm (14 inch)  Ideapad 64 bit D 4 GB DDR4  Lenovo',
#   {'entities': [(0, 6, 'Category'),
#     (7, 40, 'Processor'),
#     (41, 49, 'Disk'),
#     (50, 69, 'Dim'),
#     (70, 77, 'Model'),
#     (78, 86, 'OS'),
#     (87, 97, 'RAM'),
#     (98, 104, 'Brand')]}),
#  ('Intel Core i5 Processor (8th Gen) Laptop 8 GB DDR4  256 GB SSD 64 bit Windows 10 33.78 cm (13.3 inch) Touchscreen  HP ProBook',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 40, 'Category'),
#     (41, 51, 'RAM'),
#     (52, 62, 'Disk'),
#     (63, 80, 'OS'),
#     (81, 114, 'Dim'),
#     (115, 117, 'Brand'),
#     (118, 125, 'Model')]}),
#  ('AMD APU Dual Core A4 Processor Aspire 64 bit Windows 10 39.62 cm (15.6 inch)  4 GB DDR4  Acer Laptop 1 TB HDD',
#   {'entities': [(0, 30, 'Processor'),
#     (31, 37, 'Model'),
#     (38, 55, 'OS'),
#     (56, 77, 'Dim'),
#     (78, 88, 'RAM'),
#     (89, 93, 'Brand'),
#     (94, 100, 'Category'),
#     (101, 109, 'Disk')]}),
#  ('35.56 cm (14 inch)  Laptop Vostro 1 TB HDD 64 bit Windows 10 Dell 4 GB DDR4  Intel Core i3 Processor (8th Gen)',
#   {'entities': [(0, 19, 'Dim'),
#     (20, 26, 'Category'),
#     (27, 33, 'Model'),
#     (34, 42, 'Disk'),
#     (43, 60, 'OS'),
#     (61, 65, 'Brand'),
#     (66, 76, 'RAM'),
#     (77, 110, 'Processor')]}),
#  ('Acer AMD APU Dual Core A4 Processor (7th Gen) 64 bit Windows 10 Laptop 4 GB DDR4  Aspire 1 TB HDD 39.62 cm (15.6 inch) ',
#   {'entities': [(0, 4, 'Brand'),
#     (5, 45, 'Processor'),
#     (46, 63, 'OS'),
#     (64, 70, 'Category'),
#     (71, 81, 'RAM'),
#     (82, 88, 'Model'),
#     (89, 97, 'Disk'),
#     (98, 119, 'Dim')]})]

# %% [markdown]
# ### 3. Training NER model

# %%
def train_spacy(data,iterations):
    
    TRAIN_DATA = data
    nlp = spacy.blank('en')  # create blank Language class
    
    # create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
    if 'ner' not in nlp.pipe_names:
        ner = nlp.create_pipe('ner')
        nlp.add_pipe(ner, last=True)
       

    # add labels
    for _, annotations in TRAIN_DATA:
         for ent in annotations.get('entities'):
                ner.add_label(ent[2])

    # get names of other pipes to disable them during training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
    
    with nlp.disable_pipes(*other_pipes):  # only train NER
        optimizer = nlp.begin_training()
        for itn in range(iterations):
            print("Starting iteration " + str(itn))
            random.shuffle(TRAIN_DATA)
            losses = {}
            for text, annotations in TRAIN_DATA:
                #print(text, annotations)
                nlp.update(
                    [text],  # batch of texts
                    [annotations],  # batch of annotations
                    drop=0.2,  # dropout - make it harder to memorise data
                    sgd=optimizer,  # callable to update weights
                    losses=losses)
                
            if (losses['ner'] <100):
                    break
            print(losses)
    return nlp

# %%
# can plot losses and choose best model

# %%
# %%time
prdnlp = train_spacy(train_data,10)
# Out:
# Starting iteration 0
# {'ner': 1616.534688581056}
# Starting iteration 1
# {'ner': 296.74486782755986}
# Starting iteration 2
# {'ner': 227.66339603823027}
# Starting iteration 3
# {'ner': 388.8967474150053}
# Starting iteration 4
# {'ner': 253.16708756021092}
# Starting iteration 5
# {'ner': 169.10252932106346}
# Starting iteration 6
# {'ner': 245.55921900603008}
# Starting iteration 7
# {'ner': 260.9601010909793}
# Starting iteration 8
# {'ner': 425.2567879593142}
# Starting iteration 9
# CPU times: user 12min 54s, sys: 10.7 s, total: 13min 4s
# Wall time: 3min 18s

# %%
prdnlp_1 = train_spacy(train_data,20)
# Out:
# Starting iteration 0
# {'ner': 1976.1569668445497}
# Starting iteration 1
# {'ner': 497.76540309684856}
# Starting iteration 2
# {'ner': 188.1025777314755}
# Starting iteration 3
# {'ner': 161.8841822449491}
# Starting iteration 4

# %% [markdown]
# ### 4. Testing the model

# %%
test_text = input("Enter your testing text: ")
doc = prdnlp(test_text)

for ent in doc.ents:

    print('Entity: ',ent.text)
    print('Details: ',ent.start_char, ent.end_char, ent.label_)
# Out:
# Enter your testing text: I have a Lenovo Ideapad laptop
# Entity:  I
# Details:  0 1 Model
# Entity:  have
# Details:  2 6 Brand
# Entity:  Lenovo
# Details:  9 15 Brand
# Entity:  Ideapad
# Details:  16 23 Model
# Entity:  laptop
# Details:  24 30 Category

# %%
test_text = input("Enter your testing text: ")
doc = prdnlp_1(test_text)

for ent in doc.ents:

    print('Entity: ',ent.text)
    print('Details: ',ent.start_char, ent.end_char, ent.label_)
# Out:
# Enter your testing text: 256 GB SSD and Intel Core i7 Processor (8th Gen) HP?
# Entity:  256 GB SSD
# Details:  0 10 Disk
# Entity:  Intel Core i7 Processor (8th Gen)
# Details:  15 48 Processor
# Entity:  HP
# Details:  49 51 Brand
# Entity:  ?
# Details:  51 52 Brand
