# %% [markdown]
# ## Creating a Spacy NER Model for laptops
#
# The Brand, Model, Processor, RAM, OS, Disk, Dim are the entities we want to define.

# %%
##import libraries
import pandas as pd
import numpy as np
import spacy
import random
import time

# %% [markdown]
# ### 1. Data

# %%
## loading data with the columns names as entities
data = pd.read_csv("laptop.csv",index_col=None)
data
# Out:
#       Brand      Model                                    Processor  \
# 0    Lenovo    Ideapad            Intel Core i3 Processor (7th Gen)
# 1    Lenovo    Ideapad            Intel Core i3 Processor (7th Gen)
# 2        HP  EliteBook            Intel Core i3 Processor (7th Gen)
# 3      Dell     Vostro            Intel Core i3 Processor (8th Gen)
# 4        HP      Zbook            Intel Core i5 Processor (8th Gen)
# ..      ...        ...                                          ...
# 411  Lenovo    Ideapad            Intel Core i5 Processor (6th Gen)
# 412  Lenovo    Ideapad            Intel Core i7 Processor (8th Gen)
# 413  Lenovo    Ideapad               AMD APU Quad Core A6 Processor
# 414  Lenovo     Legion  Intel Pentium Quad Core Processor (4th Gen)
# 415  Lenovo    Ideapad            Intel Core i3 Processor (7th Gen)
#
#             RAM                 OS        Disk                    Dim Category
# 0    4 GB DDR4   64 bit Windows 10    1 TB HDD  39.62 cm (15.6 inch)    Laptop
# 1    4 GB DDR4   64 bit Windows 10    1 TB HDD  39.62 cm (15.6 inch)    Laptop
# 2    8 GB DDR4   64 bit Windows 10  256 GB SSD    35.56 cm (14 inch)    Laptop
# 3    4 GB DDR4        Linux/Ubuntu    1 TB HDD    35.56 cm (14 inch)    Laptop
# 4    8 GB DDR4   64 bit Windows 10    1 TB HDD    35.56 cm (14 inch)    Laptop
# ..          ...                ...         ...                    ...      ...
# 411  4 GB DDR3   64 bit Windows 10    1 TB HDD    35.56 cm (14 inch)    Laptop
# 412  8 GB DDR4   64 bit Windows 10    1 TB HDD  39.62 cm (15.6 inch)    Laptop
# 413  4 GB DDR3   64 bit Windows 10    1 TB HDD  39.62 cm (15.6 inch)    Laptop
# 414  4 GB DDR3                   D  500 GB HDD  39.62 cm (15.6 inch)    Laptop
# 415  4 GB DDR4                   D    1 TB HDD  39.62 cm (15.6 inch)    Laptop
#
# [416 rows x 8 columns]

# %% [markdown]
# ### 2. Pre-processing
#
# The input data has to be in a particular format.
#
# Steps:
# 1. Create a phrase with jumbled entities and the annotations for each entity.
# 2. Convert into json file with the content (phrase above) and the corresponding entities.
# 3. The json file is converted into a list.

# %% [markdown]
# ####  a. Creating content for the laptops

# %%
## the entities
cols = data.columns
cols
# Out:
# Index(['Brand', 'Model', 'Processor', 'RAM', 'OS', 'Disk', 'Dim', 'Category'], dtype='object')

# %%
## number of entities
num_ent = len(data.columns)
ent_list = list(np.arange(num_ent))
ent_list
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]

# %%
# sample of an entity
data.iloc[0,2]
# Out:
# 'Intel Core i3 Processor (7th Gen)'

# %%
## jumble indices of entities to create a phrase
prod_name = [] # list of all product names
prod_ann = [] # list of all the annotations
for i in range(len(data)): # loop for each laptop
    idx_list = random.sample(ent_list,num_ent) # shuffling indices
    cont = []
    ann = []
    ann_idx = 0 # pointer for annotating 
    for j in range(num_ent): # creating the jumbled product name
        col_num = idx_list[j] # column number according jumbled column index
        val = data.iloc[i,col_num] # value of the entity 
        cont.append(val) # appending list of entities into a single list
        ann.append((ann_idx, len(val)+ ann_idx, cols[col_num])) # annotations and entity name
        ann_idx = ann_idx + len(val) + 1 # updating the annotation pointer
        
    prod_name.append( ' '.join(cont)) # complete phrase for each laptop
    prod_ann.append(ann)

# %%
## Example
## This is the content
sample_prod_name = prod_name[8]
sample_prod_name
# Out:
# 'Laptop Modern 35.56 cm (14 inch)  8 GB DDR4  MSI 64 bit Windows 10 512 GB SSD Intel Core i5 Processor (10th Gen)'

# %%
## entities in it with their annotations
sample_prod_ent = prod_ann[8]
sample_prod_ent
# Out:
# [(0, 6, 'Category'),
#  (7, 13, 'Model'),
#  (14, 33, 'Dim'),
#  (34, 44, 'RAM'),
#  (45, 48, 'Brand'),
#  (49, 66, 'OS'),
#  (67, 77, 'Disk'),
#  (78, 112, 'Processor')]

# %%
## take an entity in the prod 
st_id = sample_prod_ent[7][0]
end_id = sample_prod_ent[7][1]
ent = sample_prod_ent[7][2]
print(ent,':', sample_prod_name[st_id : end_id])
# Out:
# Processor : Intel Core i5 Processor (10th Gen)

# %%
prod =[]
for i in range(len(data)):
    prod.append([prod_name[i], prod_ann[i]])

prod[4]
# Out:
# ['Laptop Zbook 64 bit Windows 10 1 TB HDD 35.56 cm (14 inch)  8 GB DDR4  Intel Core i5 Processor (8th Gen) HP',
#  [(0, 6, 'Category'),
#   (7, 12, 'Model'),
#   (13, 30, 'OS'),
#   (31, 39, 'Disk'),
#   (40, 59, 'Dim'),
#   (60, 70, 'RAM'),
#   (71, 104, 'Processor'),
#   (105, 107, 'Brand')]]

# %%
## creating a dataframe with product names and annotations
prod_data = pd.DataFrame(prod, columns = ['ProdName','Annotations'])
prod_data.head()
# Out:
#                                             ProdName  \
# 0  1 TB HDD Ideapad Laptop Intel Core i3 Processo...
# 1  1 TB HDD Lenovo 64 bit Windows 10 4 GB DDR4  L...
# 2  HP 8 GB DDR4  Intel Core i3 Processor (7th Gen...
# 3  Dell Linux/Ubuntu Intel Core i3 Processor (8th...
# 4  Laptop Zbook 64 bit Windows 10 1 TB HDD 35.56 ...
#
#                                          Annotations
# 0  [(0, 8, Disk), (9, 16, Model), (17, 23, Catego...
# 1  [(0, 8, Disk), (9, 15, Brand), (16, 33, OS), (...
# 2  [(0, 2, Brand), (3, 13, RAM), (14, 47, Process...
# 3  [(0, 4, Brand), (5, 17, OS), (18, 51, Processo...
# 4  [(0, 6, Category), (7, 12, Model), (13, 30, OS...

# %%
# converting into csv file
prod_data.to_csv('laptop_prodNames.csv', index= None)

# %% [markdown]
# #### b. Creating json file

# %%
# converting into json format
import csv
import json

csvfile = open('laptop_prodNames.csv', 'r')
jsonfile = open('laptop_prodNames.json', 'w')

fieldnames = ('ProdName', 'Annotations')
reader = csv.DictReader( csvfile, fieldnames)

for row in reader:
    json.dump(row, jsonfile)
    jsonfile.write('\n')

# %% [markdown]
# #### c. json to list (spacy format)

# %%
## function to convert json file into spacy traning data format
def convert_to_spacytrain(json_file):
    try:
        
        training_data = []
        lines=[]
        with open(json_file, 'r') as f:
            lines = f.readlines() # this has 416 lines
            
        for line in lines[1:400]: # loop for every product
            data = json.loads(line) # single row
            text = data['ProdName'] #this is complete phrase
            entities = data['Annotations']
            training_data.append((text, {"entities" : eval(entities)}))
            
        return training_data
    
    except Exception as e:
        
        logging.exception("Unable to process " + json_file + "\n" + "error = " + str(e))
        
        return None

# %%
train_data = convert_to_spacytrain('laptop_prodNames.json')
train_data
# Out:
# [('1 TB HDD Ideapad Laptop Intel Core i3 Processor (7th Gen) 4 GB DDR4  64 bit Windows 10 39.62 cm (15.6 inch)  Lenovo',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 16, 'Model'),
#     (17, 23, 'Category'),
#     (24, 57, 'Processor'),
#     (58, 68, 'RAM'),
#     (69, 86, 'OS'),
#     (87, 108, 'Dim'),
#     (109, 115, 'Brand')]}),
#  ('1 TB HDD Lenovo 64 bit Windows 10 4 GB DDR4  Laptop 39.62 cm (15.6 inch)  Ideapad Intel Core i3 Processor (7th Gen)',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 15, 'Brand'),
#     (16, 33, 'OS'),
#     (34, 44, 'RAM'),
#     (45, 51, 'Category'),
#     (52, 73, 'Dim'),
#     (74, 81, 'Model'),
#     (82, 115, 'Processor')]}),
#  ('HP 8 GB DDR4  Intel Core i3 Processor (7th Gen) 256 GB SSD Laptop EliteBook 64 bit Windows 10 35.56 cm (14 inch) ',
#   {'entities': [(0, 2, 'Brand'),
#     (3, 13, 'RAM'),
#     (14, 47, 'Processor'),
#     (48, 58, 'Disk'),
#     (59, 65, 'Category'),
#     (66, 75, 'Model'),
#     (76, 93, 'OS'),
#     (94, 113, 'Dim')]}),
#  ('Dell Linux/Ubuntu Intel Core i3 Processor (8th Gen) Vostro 1 TB HDD 35.56 cm (14 inch)  4 GB DDR4  Laptop',
#   {'entities': [(0, 4, 'Brand'),
#     (5, 17, 'OS'),
#     (18, 51, 'Processor'),
#     (52, 58, 'Model'),
#     (59, 67, 'Disk'),
#     (68, 87, 'Dim'),
#     (88, 98, 'RAM'),
#     (99, 105, 'Category')]}),
#  ('Laptop Zbook 64 bit Windows 10 1 TB HDD 35.56 cm (14 inch)  8 GB DDR4  Intel Core i5 Processor (8th Gen) HP',
#   {'entities': [(0, 6, 'Category'),
#     (7, 12, 'Model'),
#     (13, 30, 'OS'),
#     (31, 39, 'Disk'),
#     (40, 59, 'Dim'),
#     (60, 70, 'RAM'),
#     (71, 104, 'Processor'),
#     (105, 107, 'Brand')]}),
#  ('39.62 cm (15.6 inch)  Ideapad Laptop 1 TB HDD 8 GB DDR4  Intel Core i5 Processor (8th Gen) Lenovo 64 bit Windows 10',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 29, 'Model'),
#     (30, 36, 'Category'),
#     (37, 45, 'Disk'),
#     (46, 56, 'RAM'),
#     (57, 90, 'Processor'),
#     (91, 97, 'Brand'),
#     (98, 115, 'OS')]}),
#  ('Ideapad Lenovo 64 bit Windows 10 Intel Core i3 Processor (7th Gen) 1 TB HDD 8 GB DDR4  39.62 cm (15.6 inch)  Laptop',
#   {'entities': [(0, 7, 'Model'),
#     (8, 14, 'Brand'),
#     (15, 32, 'OS'),
#     (33, 66, 'Processor'),
#     (67, 75, 'Disk'),
#     (76, 86, 'RAM'),
#     (87, 108, 'Dim'),
#     (109, 115, 'Category')]}),
#  ('Laptop 39.62 cm (15.6 inch)  Asus Vivo 512 GB SSD Intel Core i5 Processor (9th Gen) 8 GB DDR4  64 bit Windows 10',
#   {'entities': [(0, 6, 'Category'),
#     (7, 28, 'Dim'),
#     (29, 33, 'Brand'),
#     (34, 38, 'Model'),
#     (39, 49, 'Disk'),
#     (50, 83, 'Processor'),
#     (84, 94, 'RAM'),
#     (95, 112, 'OS')]}),
#  ('Laptop Modern 35.56 cm (14 inch)  8 GB DDR4  MSI 64 bit Windows 10 512 GB SSD Intel Core i5 Processor (10th Gen)',
#   {'entities': [(0, 6, 'Category'),
#     (7, 13, 'Model'),
#     (14, 33, 'Dim'),
#     (34, 44, 'RAM'),
#     (45, 48, 'Brand'),
#     (49, 66, 'OS'),
#     (67, 77, 'Disk'),
#     (78, 112, 'Processor')]}),
#  ('HP 64 bit Windows 10 Intel Core i3 Processor (7th Gen) 4 GB DDR4  39.62 cm (15.6 inch)  Envy 1 TB HDD Laptop',
#   {'entities': [(0, 2, 'Brand'),
#     (3, 20, 'OS'),
#     (21, 54, 'Processor'),
#     (55, 65, 'RAM'),
#     (66, 87, 'Dim'),
#     (88, 92, 'Model'),
#     (93, 101, 'Disk'),
#     (102, 108, 'Category')]}),
#  ('Intel Celeron Dual Core Processor 4 GB DDR4  64 bit Windows 10 Laptop Ideapad Lenovo 39.62 cm (15.6 inch)  1 TB HDD',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 44, 'RAM'),
#     (45, 62, 'OS'),
#     (63, 69, 'Category'),
#     (70, 77, 'Model'),
#     (78, 84, 'Brand'),
#     (85, 106, 'Dim'),
#     (107, 115, 'Disk')]}),
#  ('Apple Intel Core i5 Processor (5th Gen) 64 bit Mac 33.78 cm (13.3 inch)  Laptop 8 GB DDR3  MacBook Air 128 GB SSD',
#   {'entities': [(0, 5, 'Brand'),
#     (6, 39, 'Processor'),
#     (40, 50, 'OS'),
#     (51, 72, 'Dim'),
#     (73, 79, 'Category'),
#     (80, 90, 'RAM'),
#     (91, 102, 'Model'),
#     (103, 113, 'Disk')]}),
#  ('1 TB HDD ThinkPad X Series Laptop 39.62 cm (15.6 inch)  Intel Core i7 Processor (8th Gen) Lenovo 8 GB DDR4  64 bit Windows 10',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 26, 'Model'),
#     (27, 33, 'Category'),
#     (34, 55, 'Dim'),
#     (56, 89, 'Processor'),
#     (90, 96, 'Brand'),
#     (97, 107, 'RAM'),
#     (108, 125, 'OS')]}),
#  ('HP 256 GB SSD 4 GB DDR4  Pavilion Intel Core i3 Processor (8th Gen) 35.56 cm (14 inch) Touchscreen  64 bit Windows 10 Laptop',
#   {'entities': [(0, 2, 'Brand'),
#     (3, 13, 'Disk'),
#     (14, 24, 'RAM'),
#     (25, 33, 'Model'),
#     (34, 67, 'Processor'),
#     (68, 99, 'Dim'),
#     (100, 117, 'OS'),
#     (118, 124, 'Category')]}),
#  ('39.62 cm (15.6 inch)  4 GB DDR4  1 TB HDD AMD APU Dual Core A6 Processor Laptop 64 bit Windows 10 Lenovo Ideapad',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 32, 'RAM'),
#     (33, 41, 'Disk'),
#     (42, 72, 'Processor'),
#     (73, 79, 'Category'),
#     (80, 97, 'OS'),
#     (98, 104, 'Brand'),
#     (105, 112, 'Model')]}),
#  ('1 TB HDD Aspire Acer 4 GB DDR4  Laptop 39.62 cm (15.6 inch)  Intel Core i3 Processor (8th Gen) 64 bit Windows 10',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 15, 'Model'),
#     (16, 20, 'Brand'),
#     (21, 31, 'RAM'),
#     (32, 38, 'Category'),
#     (39, 60, 'Dim'),
#     (61, 94, 'Processor'),
#     (95, 112, 'OS')]}),
#  ('64 bit Windows 10 39.62 cm (15.6 inch)  8 GB DDR4  Laptop Acer Intel Core i7 Processor (9th Gen) Nitro 1 TB HDD|256 GB SSD',
#   {'entities': [(0, 17, 'OS'),
#     (18, 39, 'Dim'),
#     (40, 50, 'RAM'),
#     (51, 57, 'Category'),
#     (58, 62, 'Brand'),
#     (63, 96, 'Processor'),
#     (97, 102, 'Model'),
#     (103, 122, 'Disk')]}),
#  ('HP AMD Ryzen 3 Dual Core Processor Laptop EliteBook 64 bit Windows 10 39.62 cm (15.6 inch)  4 GB DDR4  1 TB HDD',
#   {'entities': [(0, 2, 'Brand'),
#     (3, 34, 'Processor'),
#     (35, 41, 'Category'),
#     (42, 51, 'Model'),
#     (52, 69, 'OS'),
#     (70, 91, 'Dim'),
#     (92, 102, 'RAM'),
#     (103, 111, 'Disk')]}),
#  ('1 TB HDD Pavilion 8 GB DDR4  Laptop Intel Core i3 Processor (7th Gen) 64 bit Windows 10 39.62 cm (15.6 inch)  HP',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 17, 'Model'),
#     (18, 28, 'RAM'),
#     (29, 35, 'Category'),
#     (36, 69, 'Processor'),
#     (70, 87, 'OS'),
#     (88, 109, 'Dim'),
#     (110, 112, 'Brand')]}),
#  ('4 GB DDR4  1 TB HDD Linux/Ubuntu Dell Latitude Laptop Intel Core i3 Processor (7th Gen) 35.56 cm (14 inch) ',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 19, 'Disk'),
#     (20, 32, 'OS'),
#     (33, 37, 'Brand'),
#     (38, 46, 'Model'),
#     (47, 53, 'Category'),
#     (54, 87, 'Processor'),
#     (88, 107, 'Dim')]}),
#  ('Laptop HP AMD Ryzen 5 Quad Core Processor 39.62 cm (15.6 inch)  Pavilion 8 GB DDR4  1 TB HDD|128 GB SSD 64 bit Windows 10',
#   {'entities': [(0, 6, 'Category'),
#     (7, 9, 'Brand'),
#     (10, 41, 'Processor'),
#     (42, 63, 'Dim'),
#     (64, 72, 'Model'),
#     (73, 83, 'RAM'),
#     (84, 103, 'Disk'),
#     (104, 121, 'OS')]}),
#  ('AMD Ryzen 5 Quad Core Processor Laptop HP Pavilion 1 TB HDD|128 GB SSD 64 bit Windows 10 39.62 cm (15.6 inch)  8 GB DDR4 ',
#   {'entities': [(0, 31, 'Processor'),
#     (32, 38, 'Category'),
#     (39, 41, 'Brand'),
#     (42, 50, 'Model'),
#     (51, 70, 'Disk'),
#     (71, 88, 'OS'),
#     (89, 110, 'Dim'),
#     (111, 121, 'RAM')]}),
#  ('Asus 64 bit Windows 10 Laptop ROG 1 TB HDD|256 GB SSD Intel Core i5 Processor (9th Gen) 39.62 cm (15.6 inch)  8 GB DDR4 ',
#   {'entities': [(0, 4, 'Brand'),
#     (5, 22, 'OS'),
#     (23, 29, 'Category'),
#     (30, 33, 'Model'),
#     (34, 53, 'Disk'),
#     (54, 87, 'Processor'),
#     (88, 109, 'Dim'),
#     (110, 120, 'RAM')]}),
#  ('Laptop 35.56 cm (14 inch)  HP 256 GB SSD Notebook 64 bit Windows 10 Intel Core i3 Processor (7th Gen) 8 GB DDR4 ',
#   {'entities': [(0, 6, 'Category'),
#     (7, 26, 'Dim'),
#     (27, 29, 'Brand'),
#     (30, 40, 'Disk'),
#     (41, 49, 'Model'),
#     (50, 67, 'OS'),
#     (68, 101, 'Processor'),
#     (102, 112, 'RAM')]}),
#  ('Intel Core i3 Processor (7th Gen) 1 TB HDD Laptop 4 GB DDR4  39.62 cm (15.6 inch)  Lenovo 64 bit Windows 10 Ideapad',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 42, 'Disk'),
#     (43, 49, 'Category'),
#     (50, 60, 'RAM'),
#     (61, 82, 'Dim'),
#     (83, 89, 'Brand'),
#     (90, 107, 'OS'),
#     (108, 115, 'Model')]}),
#  ('39.62 cm (15.6 inch)  1 TB HDD Laptop ThinkPad T Series Lenovo Intel Core i3 Processor (7th Gen) 4 GB DDR4  64 bit Windows 10',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 30, 'Disk'),
#     (31, 37, 'Category'),
#     (38, 55, 'Model'),
#     (56, 62, 'Brand'),
#     (63, 96, 'Processor'),
#     (97, 107, 'RAM'),
#     (108, 125, 'OS')]}),
#  ('Intel Core i3 Processor (8th Gen) Vostro 4 GB DDR4  Dell Linux/Ubuntu 1 TB HDD 35.56 cm (14 inch)  Laptop',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 40, 'Model'),
#     (41, 51, 'RAM'),
#     (52, 56, 'Brand'),
#     (57, 69, 'OS'),
#     (70, 78, 'Disk'),
#     (79, 98, 'Dim'),
#     (99, 105, 'Category')]}),
#  ('64 bit Windows 10 Intel Core i5 Processor (8th Gen) Laptop 35.56 cm (14 inch)  ProBook 1 TB HDD HP 8 GB DDR4 ',
#   {'entities': [(0, 17, 'OS'),
#     (18, 51, 'Processor'),
#     (52, 58, 'Category'),
#     (59, 78, 'Dim'),
#     (79, 86, 'Model'),
#     (87, 95, 'Disk'),
#     (96, 98, 'Brand'),
#     (99, 109, 'RAM')]}),
#  ('Intel Core i5 Processor (9th Gen) Laptop Asus 39.62 cm (15.6 inch)  8 GB DDR4  64 bit Windows 10 Vivo 512 GB SSD',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 40, 'Category'),
#     (41, 45, 'Brand'),
#     (46, 67, 'Dim'),
#     (68, 78, 'RAM'),
#     (79, 96, 'OS'),
#     (97, 101, 'Model'),
#     (102, 112, 'Disk')]}),
#  ('8 GB DDR4  39.62 cm (15.6 inch)  Laptop 1 TB HDD 64 bit Windows 10 Lenovo Ideapad Intel Core i5 Processor (8th Gen)',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 32, 'Dim'),
#     (33, 39, 'Category'),
#     (40, 48, 'Disk'),
#     (49, 66, 'OS'),
#     (67, 73, 'Brand'),
#     (74, 81, 'Model'),
#     (82, 115, 'Processor')]}),
#  ('64 bit Windows 10 Intel Core i3 Processor (7th Gen) Lenovo 39.62 cm (15.6 inch)  8 GB DDR4  Laptop 1 TB HDD Ideapad',
#   {'entities': [(0, 17, 'OS'),
#     (18, 51, 'Processor'),
#     (52, 58, 'Brand'),
#     (59, 80, 'Dim'),
#     (81, 91, 'RAM'),
#     (92, 98, 'Category'),
#     (99, 107, 'Disk'),
#     (108, 115, 'Model')]}),
#  ('64 bit Windows 10 512 GB SSD Laptop 35.56 cm (14 inch)  MSI 8 GB DDR4  Modern Intel Core i5 Processor (10th Gen)',
#   {'entities': [(0, 17, 'OS'),
#     (18, 28, 'Disk'),
#     (29, 35, 'Category'),
#     (36, 55, 'Dim'),
#     (56, 59, 'Brand'),
#     (60, 70, 'RAM'),
#     (71, 77, 'Model'),
#     (78, 112, 'Processor')]}),
#  ('Intel Core i3 Processor (8th Gen) 256 GB SSD Laptop 64 bit Windows 10 35.56 cm (14 inch) Touchscreen  HP 4 GB DDR4  Pavilion',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 44, 'Disk'),
#     (45, 51, 'Category'),
#     (52, 69, 'OS'),
#     (70, 101, 'Dim'),
#     (102, 104, 'Brand'),
#     (105, 115, 'RAM'),
#     (116, 124, 'Model')]}),
#  ('1 TB HDD ThinkPad X Series 64 bit Windows 10 Laptop 8 GB DDR4  39.62 cm (15.6 inch)  Lenovo Intel Core i7 Processor (8th Gen)',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 26, 'Model'),
#     (27, 44, 'OS'),
#     (45, 51, 'Category'),
#     (52, 62, 'RAM'),
#     (63, 84, 'Dim'),
#     (85, 91, 'Brand'),
#     (92, 125, 'Processor')]}),
#  ('39.62 cm (15.6 inch)  Intel Core i3 Processor (7th Gen) Laptop 64 bit Windows 10 Pavilion 4 GB DDR4  HP 1 TB HDD',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 55, 'Processor'),
#     (56, 62, 'Category'),
#     (63, 80, 'OS'),
#     (81, 89, 'Model'),
#     (90, 100, 'RAM'),
#     (101, 103, 'Brand'),
#     (104, 112, 'Disk')]}),
#  ('Lenovo Intel Celeron Dual Core Processor 39.62 cm (15.6 inch)  Ideapad 1 TB HDD 4 GB DDR4  Laptop 64 bit Windows 10',
#   {'entities': [(0, 6, 'Brand'),
#     (7, 40, 'Processor'),
#     (41, 62, 'Dim'),
#     (63, 70, 'Model'),
#     (71, 79, 'Disk'),
#     (80, 90, 'RAM'),
#     (91, 97, 'Category'),
#     (98, 115, 'OS')]}),
#  ('128 GB SSD 33.78 cm (13.3 inch)  MacBook Air Laptop Apple 64 bit Mac Intel Core i5 Processor (5th Gen) 8 GB DDR3 ',
#   {'entities': [(0, 10, 'Disk'),
#     (11, 32, 'Dim'),
#     (33, 44, 'Model'),
#     (45, 51, 'Category'),
#     (52, 57, 'Brand'),
#     (58, 68, 'OS'),
#     (69, 102, 'Processor'),
#     (103, 113, 'RAM')]}),
#  ('39.62 cm (15.6 inch)  Laptop AMD APU Dual Core A6 Processor Ideapad 1 TB HDD 4 GB DDR4  64 bit Windows 10 Lenovo',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 28, 'Category'),
#     (29, 59, 'Processor'),
#     (60, 67, 'Model'),
#     (68, 76, 'Disk'),
#     (77, 87, 'RAM'),
#     (88, 105, 'OS'),
#     (106, 112, 'Brand')]}),
#  ('39.62 cm (15.6 inch)  Intel Core i7 Processor (9th Gen) Nitro Acer 8 GB DDR4  1 TB HDD|256 GB SSD 64 bit Windows 10 Laptop',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 55, 'Processor'),
#     (56, 61, 'Model'),
#     (62, 66, 'Brand'),
#     (67, 77, 'RAM'),
#     (78, 97, 'Disk'),
#     (98, 115, 'OS'),
#     (116, 122, 'Category')]}),
#  ('Envy 8 GB DDR4  1 TB HDD 39.62 cm (15.6 inch)  HP Laptop Intel Core i3 Processor (7th Gen) 64 bit Windows 10',
#   {'entities': [(0, 4, 'Model'),
#     (5, 15, 'RAM'),
#     (16, 24, 'Disk'),
#     (25, 46, 'Dim'),
#     (47, 49, 'Brand'),
#     (50, 56, 'Category'),
#     (57, 90, 'Processor'),
#     (91, 108, 'OS')]}),
#  ('1 TB HDD Aspire Intel Core i3 Processor (8th Gen) 39.62 cm (15.6 inch)  64 bit Windows 10 4 GB DDR4  Laptop Acer',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 15, 'Model'),
#     (16, 49, 'Processor'),
#     (50, 71, 'Dim'),
#     (72, 89, 'OS'),
#     (90, 100, 'RAM'),
#     (101, 107, 'Category'),
#     (108, 112, 'Brand')]}),
#  ('4 GB DDR4  1 TB HDD HP AMD Ryzen 3 Dual Core Processor 64 bit Windows 10 Laptop 39.62 cm (15.6 inch)  ProBook',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 19, 'Disk'),
#     (20, 22, 'Brand'),
#     (23, 54, 'Processor'),
#     (55, 72, 'OS'),
#     (73, 79, 'Category'),
#     (80, 101, 'Dim'),
#     (102, 109, 'Model')]}),
#  ('HP Laptop AMD Ryzen 5 Quad Core Processor 1 TB HDD|128 GB SSD Pavilion 39.62 cm (15.6 inch)  64 bit Windows 10 8 GB DDR4 ',
#   {'entities': [(0, 2, 'Brand'),
#     (3, 9, 'Category'),
#     (10, 41, 'Processor'),
#     (42, 61, 'Disk'),
#     (62, 70, 'Model'),
#     (71, 92, 'Dim'),
#     (93, 110, 'OS'),
#     (111, 121, 'RAM')]}),
#  ('1 TB HDD|128 GB SSD Laptop AMD Ryzen 5 Quad Core Processor 64 bit Windows 10 Pavilion 8 GB DDR4  39.62 cm (15.6 inch)  HP',
#   {'entities': [(0, 19, 'Disk'),
#     (20, 26, 'Category'),
#     (27, 58, 'Processor'),
#     (59, 76, 'OS'),
#     (77, 85, 'Model'),
#     (86, 96, 'RAM'),
#     (97, 118, 'Dim'),
#     (119, 121, 'Brand')]}),
#  ('Intel Core i3 Processor (7th Gen) Inspiron Dell 4 GB DDR4  Laptop 1 TB HDD 35.56 cm (14 inch)  Linux/Ubuntu',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 42, 'Model'),
#     (43, 47, 'Brand'),
#     (48, 58, 'RAM'),
#     (59, 65, 'Category'),
#     (66, 74, 'Disk'),
#     (75, 94, 'Dim'),
#     (95, 107, 'OS')]}),
#  ('39.62 cm (15.6 inch)  Asus 64 bit Windows 10 1 TB HDD|256 GB SSD Laptop ROG Intel Core i5 Processor (9th Gen) 8 GB DDR4 ',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 26, 'Brand'),
#     (27, 44, 'OS'),
#     (45, 64, 'Disk'),
#     (65, 71, 'Category'),
#     (72, 75, 'Model'),
#     (76, 109, 'Processor'),
#     (110, 120, 'RAM')]}),
#  ('AMD Ryzen 3 Dual Core Processor 1 TB HDD|256 GB SSD 4 GB DDR4  Laptop 39.62 cm (15.6 inch)  HP Envy 64 bit Windows 10',
#   {'entities': [(0, 31, 'Processor'),
#     (32, 51, 'Disk'),
#     (52, 62, 'RAM'),
#     (63, 69, 'Category'),
#     (70, 91, 'Dim'),
#     (92, 94, 'Brand'),
#     (95, 99, 'Model'),
#     (100, 117, 'OS')]}),
#  ('1 TB HDD 39.62 cm (15.6 inch)  Ideapad Laptop 4 GB DDR4  Intel Core i5 Processor (8th Gen) 64 bit Windows 10 Lenovo',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 30, 'Dim'),
#     (31, 38, 'Model'),
#     (39, 45, 'Category'),
#     (46, 56, 'RAM'),
#     (57, 90, 'Processor'),
#     (91, 108, 'OS'),
#     (109, 115, 'Brand')]}),
#  ('Vivo 35.56 cm (14 inch)  1 TB HDD|256 GB SSD Laptop Intel Core i7 Processor (8th Gen) 64 bit Windows 10 Asus 8 GB DDR4 ',
#   {'entities': [(0, 4, 'Model'),
#     (5, 24, 'Dim'),
#     (25, 44, 'Disk'),
#     (45, 51, 'Category'),
#     (52, 85, 'Processor'),
#     (86, 103, 'OS'),
#     (104, 108, 'Brand'),
#     (109, 119, 'RAM')]}),
#  ('Laptop 64 bit Windows 10 39.62 cm (15.6 inch)  1 TB HDD|256 GB SSD Nitro AMD Ryzen 5 Quad Core Processor 8 GB DDR4  Acer',
#   {'entities': [(0, 6, 'Category'),
#     (7, 24, 'OS'),
#     (25, 46, 'Dim'),
#     (47, 66, 'Disk'),
#     (67, 72, 'Model'),
#     (73, 104, 'Processor'),
#     (105, 115, 'RAM'),
#     (116, 120, 'Brand')]}),
#  ('16 GB DDR4  Acer 64 bit Windows 10 2 TB HDD|256 GB SSD 43.94 cm (17.3 inch)  Laptop Predator Intel Core i7 Processor (9th Gen)',
#   {'entities': [(0, 11, 'RAM'),
#     (12, 16, 'Brand'),
#     (17, 34, 'OS'),
#     (35, 54, 'Disk'),
#     (55, 76, 'Dim'),
#     (77, 83, 'Category'),
#     (84, 92, 'Model'),
#     (93, 126, 'Processor')]}),
#  ('Intel Core i7 Processor (9th Gen) 64 bit Windows 10 Laptop 1 TB SSD 39.62 cm (15.6 inch)  16 GB DDR4  MSI Modern',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 51, 'OS'),
#     (52, 58, 'Category'),
#     (59, 67, 'Disk'),
#     (68, 89, 'Dim'),
#     (90, 101, 'RAM'),
#     (102, 105, 'Brand'),
#     (106, 112, 'Model')]}),
#  ('Vivo 64 bit Windows 10 Asus Laptop 8 GB DDR4  512 GB SSD Intel Core i5 Processor (8th Gen) 35.56 cm (14 inch) ',
#   {'entities': [(0, 4, 'Model'),
#     (5, 22, 'OS'),
#     (23, 27, 'Brand'),
#     (28, 34, 'Category'),
#     (35, 45, 'RAM'),
#     (46, 56, 'Disk'),
#     (57, 90, 'Processor'),
#     (91, 110, 'Dim')]}),
#  ('Asus 1 TB HDD Laptop 39.62 cm (15.6 inch)  TUF Gaming AMD Ryzen 5 Quad Core Processor 8 GB DDR4  64 bit Windows 10',
#   {'entities': [(0, 4, 'Brand'),
#     (5, 13, 'Disk'),
#     (14, 20, 'Category'),
#     (21, 42, 'Dim'),
#     (43, 53, 'Model'),
#     (54, 85, 'Processor'),
#     (86, 96, 'RAM'),
#     (97, 114, 'OS')]}),
#  ('43.94 cm (17.3 inch)  Intel Core i5 Processor (9th Gen) 64 bit Windows 10 Predator Acer 1 TB HDD|256 GB SSD 16 GB DDR4  Laptop',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 55, 'Processor'),
#     (56, 73, 'OS'),
#     (74, 82, 'Model'),
#     (83, 87, 'Brand'),
#     (88, 107, 'Disk'),
#     (108, 119, 'RAM'),
#     (120, 126, 'Category')]}),
#  ('Intel Core i5 Processor (8th Gen) 64 bit Windows 10 Vivo Asus 1 TB HDD|256 GB SSD 8 GB DDR4  Laptop 35.56 cm (14 inch) ',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 51, 'OS'),
#     (52, 56, 'Model'),
#     (57, 61, 'Brand'),
#     (62, 81, 'Disk'),
#     (82, 92, 'RAM'),
#     (93, 99, 'Category'),
#     (100, 119, 'Dim')]}),
#  ('AMD Ryzen 5 Quad Core Processor Ideapad Lenovo 39.62 cm (15.6 inch)  1 TB HDD Laptop 8 GB DDR4  64 bit Windows 10',
#   {'entities': [(0, 31, 'Processor'),
#     (32, 39, 'Model'),
#     (40, 46, 'Brand'),
#     (47, 68, 'Dim'),
#     (69, 77, 'Disk'),
#     (78, 84, 'Category'),
#     (85, 95, 'RAM'),
#     (96, 113, 'OS')]}),
#  ('Liber 8 GB DDR4  Laptop 64 bit Windows 10 35.56 cm (14 inch)  Avita 256 GB SSD Intel Core i5 Processor (8th Gen)',
#   {'entities': [(0, 5, 'Model'),
#     (6, 16, 'RAM'),
#     (17, 23, 'Category'),
#     (24, 41, 'OS'),
#     (42, 61, 'Dim'),
#     (62, 67, 'Brand'),
#     (68, 78, 'Disk'),
#     (79, 112, 'Processor')]}),
#  ('35.56 cm (14 inch)  Intel Core i5 Processor (8th Gen) 64 bit Windows 10 8 GB DDR4  Laptop HP Pavilion 512 GB SSD',
#   {'entities': [(0, 19, 'Dim'),
#     (20, 53, 'Processor'),
#     (54, 71, 'OS'),
#     (72, 82, 'RAM'),
#     (83, 89, 'Category'),
#     (90, 92, 'Brand'),
#     (93, 101, 'Model'),
#     (102, 112, 'Disk')]}),
#  ('38.1 cm (15 inch)  64 bit Windows 10 Notebook 1 TB HDD Laptop HP Intel Core i3 Processor (8th Gen) 4 GB DDR4 ',
#   {'entities': [(0, 18, 'Dim'),
#     (19, 36, 'OS'),
#     (37, 45, 'Model'),
#     (46, 54, 'Disk'),
#     (55, 61, 'Category'),
#     (62, 64, 'Brand'),
#     (65, 98, 'Processor'),
#     (99, 109, 'RAM')]}),
#  ('512 GB SSD 8 GB DDR4  Yoga Intel Core i7 Processor (8th Gen) Laptop 33.78 cm (13.3 inch) Touchscreen  Lenovo 64 bit Windows 10',
#   {'entities': [(0, 10, 'Disk'),
#     (11, 21, 'RAM'),
#     (22, 26, 'Model'),
#     (27, 60, 'Processor'),
#     (61, 67, 'Category'),
#     (68, 101, 'Dim'),
#     (102, 108, 'Brand'),
#     (109, 126, 'OS')]}),
#  ('Laptop Intel Core i5 Processor (8th Gen) 64 bit Windows 10 8 GB DDR4  512 GB SSD 35.56 cm (14 inch)  Aspire Acer',
#   {'entities': [(0, 6, 'Category'),
#     (7, 40, 'Processor'),
#     (41, 58, 'OS'),
#     (59, 69, 'RAM'),
#     (70, 80, 'Disk'),
#     (81, 100, 'Dim'),
#     (101, 107, 'Model'),
#     (108, 112, 'Brand')]}),
#  ('1 TB HDD 8 GB DDR4  Nitro Laptop Acer 64 bit Windows 10 39.62 cm (15.6 inch)  Intel Core i5 Processor (9th Gen)',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 19, 'RAM'),
#     (20, 25, 'Model'),
#     (26, 32, 'Category'),
#     (33, 37, 'Brand'),
#     (38, 55, 'OS'),
#     (56, 77, 'Dim'),
#     (78, 111, 'Processor')]}),
#  ('1 TB HDD D 4 GB DDR4  39.62 cm (15.6 inch)  Lenovo Ideapad AMD APU Dual Core A6 Processor Laptop',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 10, 'OS'),
#     (11, 21, 'RAM'),
#     (22, 43, 'Dim'),
#     (44, 50, 'Brand'),
#     (51, 58, 'Model'),
#     (59, 89, 'Processor'),
#     (90, 96, 'Category')]}),
#  ('4 GB DDR4  Intel Core i3 Processor (10th Gen) 35.56 cm (14 inch) Touchscreen  Laptop Pavilion HP 64 bit Windows 10 256 GB SSD',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 45, 'Processor'),
#     (46, 77, 'Dim'),
#     (78, 84, 'Category'),
#     (85, 93, 'Model'),
#     (94, 96, 'Brand'),
#     (97, 114, 'OS'),
#     (115, 125, 'Disk')]}),
#  ('1 TB HDD 64 bit Windows 10 Laptop Intel Core i3 Processor (7th Gen) Zbook 39.62 cm (15.6 inch)  4 GB DDR4  HP',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 26, 'OS'),
#     (27, 33, 'Category'),
#     (34, 67, 'Processor'),
#     (68, 73, 'Model'),
#     (74, 95, 'Dim'),
#     (96, 106, 'RAM'),
#     (107, 109, 'Brand')]}),
#  ('512 GB SSD Asus Vivo AMD Ryzen 5 Quad Core Processor (2nd Gen) 64 bit Windows 10 Laptop 35.56 cm (14 inch)  8 GB DDR4 ',
#   {'entities': [(0, 10, 'Disk'),
#     (11, 15, 'Brand'),
#     (16, 20, 'Model'),
#     (21, 62, 'Processor'),
#     (63, 80, 'OS'),
#     (81, 87, 'Category'),
#     (88, 107, 'Dim'),
#     (108, 118, 'RAM')]}),
#  ('Intel Core i3 Processor (7th Gen) D 1 TB HDD Ideapad Laptop Lenovo 4 GB DDR4  39.62 cm (15.6 inch) ',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 35, 'OS'),
#     (36, 44, 'Disk'),
#     (45, 52, 'Model'),
#     (53, 59, 'Category'),
#     (60, 66, 'Brand'),
#     (67, 77, 'RAM'),
#     (78, 99, 'Dim')]}),
#  ('Intel Core i3 Processor (7th Gen) Laptop 39.62 cm (15.6 inch)  Lenovo 4 GB DDR4  1 TB HDD Ideapad D',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 40, 'Category'),
#     (41, 62, 'Dim'),
#     (63, 69, 'Brand'),
#     (70, 80, 'RAM'),
#     (81, 89, 'Disk'),
#     (90, 97, 'Model'),
#     (98, 99, 'OS')]}),
#  ('64 bit Windows 10 39.62 cm (15.6 inch)  Laptop Intel Core i5 Processor (8th Gen) HP 8 GB DDR4  ProBook 1 TB HDD',
#   {'entities': [(0, 17, 'OS'),
#     (18, 39, 'Dim'),
#     (40, 46, 'Category'),
#     (47, 80, 'Processor'),
#     (81, 83, 'Brand'),
#     (84, 94, 'RAM'),
#     (95, 102, 'Model'),
#     (103, 111, 'Disk')]}),
#  ('4 GB DDR4  Asus 39.62 cm (15.6 inch)  64 bit Windows 10 Laptop Vivo 256 GB SSD Intel Core i3 Processor (8th Gen)',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 15, 'Brand'),
#     (16, 37, 'Dim'),
#     (38, 55, 'OS'),
#     (56, 62, 'Category'),
#     (63, 67, 'Model'),
#     (68, 78, 'Disk'),
#     (79, 112, 'Processor')]}),
#  ('1 TB HDD Ideapad 35.56 cm (14 inch)  D Intel Core i3 Processor (6th Gen) Laptop Lenovo 4 GB DDR4 ',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 16, 'Model'),
#     (17, 36, 'Dim'),
#     (37, 38, 'OS'),
#     (39, 72, 'Processor'),
#     (73, 79, 'Category'),
#     (80, 86, 'Brand'),
#     (87, 97, 'RAM')]}),
#  ('Apple Intel Core i5 Processor (8th Gen) MacBook Pro Mac 128 GB SSD 8 GB DDR3  Laptop 33.78 cm (13.3 inch) ',
#   {'entities': [(0, 5, 'Brand'),
#     (6, 39, 'Processor'),
#     (40, 51, 'Model'),
#     (52, 55, 'OS'),
#     (56, 66, 'Disk'),
#     (67, 77, 'RAM'),
#     (78, 84, 'Category'),
#     (85, 106, 'Dim')]}),
#  ('Intel Core i7 Processor (9th Gen) 43.94 cm (17.3 inch)  Gaming 64 bit Windows 10 16 GB DDR4  Laptop 1 TB HDD|1 TB SSD MSI',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 55, 'Dim'),
#     (56, 62, 'Model'),
#     (63, 80, 'OS'),
#     (81, 92, 'RAM'),
#     (93, 99, 'Category'),
#     (100, 117, 'Disk'),
#     (118, 121, 'Brand')]}),
#  ('Laptop Lenovo 1 TB HDD Ideapad 39.62 cm (15.6 inch)  64 bit Windows 10 Intel Core i3 Processor (7th Gen) 4 GB DDR4 ',
#   {'entities': [(0, 6, 'Category'),
#     (7, 13, 'Brand'),
#     (14, 22, 'Disk'),
#     (23, 30, 'Model'),
#     (31, 52, 'Dim'),
#     (53, 70, 'OS'),
#     (71, 104, 'Processor'),
#     (105, 115, 'RAM')]}),
#  ('Intel Core i5 Processor (8th Gen) 1 TB HDD|256 GB SSD Laptop HP 35.56 cm (14 inch)  64 bit Windows 10 Pavilion 8 GB DDR4 ',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 53, 'Disk'),
#     (54, 60, 'Category'),
#     (61, 63, 'Brand'),
#     (64, 83, 'Dim'),
#     (84, 101, 'OS'),
#     (102, 110, 'Model'),
#     (111, 121, 'RAM')]}),
#  ('Laptop Asus ZenBook 64 bit Windows 10 35.56 cm (14 inch)  Intel Core i5 Processor (8th Gen) 8 GB DDR3  256 GB SSD',
#   {'entities': [(0, 6, 'Category'),
#     (7, 11, 'Brand'),
#     (12, 19, 'Model'),
#     (20, 37, 'OS'),
#     (38, 57, 'Dim'),
#     (58, 91, 'Processor'),
#     (92, 102, 'RAM'),
#     (103, 113, 'Disk')]}),
#  ('1 TB HDD D Laptop 39.62 cm (15.6 inch)  Intel Core i5 Processor (8th Gen) 8 GB DDR4  Ideapad Lenovo',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 10, 'OS'),
#     (11, 17, 'Category'),
#     (18, 39, 'Dim'),
#     (40, 73, 'Processor'),
#     (74, 84, 'RAM'),
#     (85, 92, 'Model'),
#     (93, 99, 'Brand')]}),
#  ('64 bit Windows 10 Laptop 39.62 cm (15.6 inch)  Intel Core i5 Processor (8th Gen) 1 TB HDD 4 GB DDR4  ProBook HP',
#   {'entities': [(0, 17, 'OS'),
#     (18, 24, 'Category'),
#     (25, 46, 'Dim'),
#     (47, 80, 'Processor'),
#     (81, 89, 'Disk'),
#     (90, 100, 'RAM'),
#     (101, 108, 'Model'),
#     (109, 111, 'Brand')]}),
#  ('1 TB HDD|128 GB SSD Dell 39.62 cm (15.6 inch)  8 GB DDR4  Laptop G Intel Core i5 Processor (8th Gen) 64 bit Windows 10',
#   {'entities': [(0, 19, 'Disk'),
#     (20, 24, 'Brand'),
#     (25, 46, 'Dim'),
#     (47, 57, 'RAM'),
#     (58, 64, 'Category'),
#     (65, 66, 'Model'),
#     (67, 100, 'Processor'),
#     (101, 118, 'OS')]}),
#  ('33.78 cm (13.3 inch) Touchscreen  8 GB DDR4  64 bit Windows 10 Intel Core i5 Processor (10th Gen) 512 GB SSD Laptop HP Envy',
#   {'entities': [(0, 33, 'Dim'),
#     (34, 44, 'RAM'),
#     (45, 62, 'OS'),
#     (63, 97, 'Processor'),
#     (98, 108, 'Disk'),
#     (109, 115, 'Category'),
#     (116, 118, 'Brand'),
#     (119, 123, 'Model')]}),
#  ('1 TB HDD|256 GB SSD 43.94 cm (17.3 inch)  TravelMate 64 bit Windows 10 Intel Core i7 Processor (9th Gen) Acer Laptop 16 GB DDR4 ',
#   {'entities': [(0, 19, 'Disk'),
#     (20, 41, 'Dim'),
#     (42, 52, 'Model'),
#     (53, 70, 'OS'),
#     (71, 104, 'Processor'),
#     (105, 109, 'Brand'),
#     (110, 116, 'Category'),
#     (117, 128, 'RAM')]}),
#  ('64 bit Windows 10 35.56 cm (14 inch)  Vivo 1 TB HDD|256 GB SSD Laptop Intel Core i5 Processor (8th Gen) 8 GB DDR4  Asus',
#   {'entities': [(0, 17, 'OS'),
#     (18, 37, 'Dim'),
#     (38, 42, 'Model'),
#     (43, 62, 'Disk'),
#     (63, 69, 'Category'),
#     (70, 103, 'Processor'),
#     (104, 114, 'RAM'),
#     (115, 119, 'Brand')]}),
#  ('39.62 cm (15.6 inch)  Laptop 64 bit Windows 10 1 TB HDD Lenovo Intel Core i3 Processor (7th Gen) Ideapad 4 GB DDR4 ',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 28, 'Category'),
#     (29, 46, 'OS'),
#     (47, 55, 'Disk'),
#     (56, 62, 'Brand'),
#     (63, 96, 'Processor'),
#     (97, 104, 'Model'),
#     (105, 115, 'RAM')]}),
#  ('Laptop 39.62 cm (15.6 inch)  16 GB DDR4  64 bit Windows 10 Vivo 512 GB SSD Asus Intel Core i7 Processor (9th Gen)',
#   {'entities': [(0, 6, 'Category'),
#     (7, 28, 'Dim'),
#     (29, 40, 'RAM'),
#     (41, 58, 'OS'),
#     (59, 63, 'Model'),
#     (64, 74, 'Disk'),
#     (75, 79, 'Brand'),
#     (80, 113, 'Processor')]}),
#  ('64 bit Windows 10 Intel Core i3 Processor (7th Gen) 1 TB HDD 4 GB DDR4  HP Laptop Zbook 39.62 cm (15.6 inch) ',
#   {'entities': [(0, 17, 'OS'),
#     (18, 51, 'Processor'),
#     (52, 60, 'Disk'),
#     (61, 71, 'RAM'),
#     (72, 74, 'Brand'),
#     (75, 81, 'Category'),
#     (82, 87, 'Model'),
#     (88, 109, 'Dim')]}),
#  ('Laptop 8 GB DDR4  Intel Core i5 Processor (10th Gen) Lenovo 64 bit Windows 10 512 GB SSD 39.62 cm (15.6 inch)  Ideapad',
#   {'entities': [(0, 6, 'Category'),
#     (7, 17, 'RAM'),
#     (18, 52, 'Processor'),
#     (53, 59, 'Brand'),
#     (60, 77, 'OS'),
#     (78, 88, 'Disk'),
#     (89, 110, 'Dim'),
#     (111, 118, 'Model')]}),
#  ('AMD APU Dual Core A6 Processor 35.56 cm (14 inch)  64 bit Windows 10 Lenovo Ideapad 4 GB DDR4  Laptop 1 TB HDD',
#   {'entities': [(0, 30, 'Processor'),
#     (31, 50, 'Dim'),
#     (51, 68, 'OS'),
#     (69, 75, 'Brand'),
#     (76, 83, 'Model'),
#     (84, 94, 'RAM'),
#     (95, 101, 'Category'),
#     (102, 110, 'Disk')]}),
#  ('Laptop HP 39.62 cm (15.6 inch)  64 bit Windows 10 8 GB DDR4  Pavilion Intel Core i5 Processor (8th Gen) 1 TB HDD',
#   {'entities': [(0, 6, 'Category'),
#     (7, 9, 'Brand'),
#     (10, 31, 'Dim'),
#     (32, 49, 'OS'),
#     (50, 60, 'RAM'),
#     (61, 69, 'Model'),
#     (70, 103, 'Processor'),
#     (104, 112, 'Disk')]}),
#  ('4 GB DDR4  AMD APU Dual Core A6 Processor 1 TB HDD Laptop HP Zbook 35.56 cm (14 inch)  D',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 41, 'Processor'),
#     (42, 50, 'Disk'),
#     (51, 57, 'Category'),
#     (58, 60, 'Brand'),
#     (61, 66, 'Model'),
#     (67, 86, 'Dim'),
#     (87, 88, 'OS')]}),
#  ('Intel Core i5 Processor (7th Gen) Liber 35.56 cm (14 inch)  8 GB DDR3  256 GB SSD 64 bit Windows 10 Avita Laptop',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 39, 'Model'),
#     (40, 59, 'Dim'),
#     (60, 70, 'RAM'),
#     (71, 81, 'Disk'),
#     (82, 99, 'OS'),
#     (100, 105, 'Brand'),
#     (106, 112, 'Category')]}),
#  ('Laptop 8 GB DDR4  1 TB HDD 64 bit Windows 10 39.62 cm (15.6 inch)  Acer AMD Ryzen 5 Quad Core Processor Nitro',
#   {'entities': [(0, 6, 'Category'),
#     (7, 17, 'RAM'),
#     (18, 26, 'Disk'),
#     (27, 44, 'OS'),
#     (45, 66, 'Dim'),
#     (67, 71, 'Brand'),
#     (72, 103, 'Processor'),
#     (104, 109, 'Model')]}),
#  ('8 GB DDR4  Laptop Lenovo 39.62 cm (15.6 inch)  64 bit Windows 10 Ideapad 512 GB SSD AMD Ryzen 5 Quad Core Processor',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 17, 'Category'),
#     (18, 24, 'Brand'),
#     (25, 46, 'Dim'),
#     (47, 64, 'OS'),
#     (65, 72, 'Model'),
#     (73, 83, 'Disk'),
#     (84, 115, 'Processor')]}),
#  ('Intel Core i7 Processor (9th Gen) 1 TB HDD|256 GB SSD 64 bit Windows 10 Acer 16 GB DDR4  39.62 cm (15.6 inch)  Laptop Predator',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 53, 'Disk'),
#     (54, 71, 'OS'),
#     (72, 76, 'Brand'),
#     (77, 88, 'RAM'),
#     (89, 110, 'Dim'),
#     (111, 117, 'Category'),
#     (118, 126, 'Model')]}),
#  ('16 GB DDR4  Acer 64 bit Windows 10 Intel Core i7 Processor (9th Gen) Aspire 2 TB HDD|256 GB SSD 43.94 cm (17.3 inch)  Laptop',
#   {'entities': [(0, 11, 'RAM'),
#     (12, 16, 'Brand'),
#     (17, 34, 'OS'),
#     (35, 68, 'Processor'),
#     (69, 75, 'Model'),
#     (76, 95, 'Disk'),
#     (96, 117, 'Dim'),
#     (118, 124, 'Category')]}),
#  ('Vivo Laptop 8 GB DDR4  512 GB SSD Asus 35.56 cm (14 inch)  64 bit Windows 10 AMD APU Quad Core A12 Processor',
#   {'entities': [(0, 4, 'Model'),
#     (5, 11, 'Category'),
#     (12, 22, 'RAM'),
#     (23, 33, 'Disk'),
#     (34, 38, 'Brand'),
#     (39, 58, 'Dim'),
#     (59, 76, 'OS'),
#     (77, 108, 'Processor')]}),
#  ('35.56 cm (14 inch)  8 GB DDR4  Asus Vivo 64 bit Windows 10 512 GB SSD Laptop AMD Ryzen 5 Quad Core Processor (2nd Gen)',
#   {'entities': [(0, 19, 'Dim'),
#     (20, 30, 'RAM'),
#     (31, 35, 'Brand'),
#     (36, 40, 'Model'),
#     (41, 58, 'OS'),
#     (59, 69, 'Disk'),
#     (70, 76, 'Category'),
#     (77, 118, 'Processor')]}),
#  ('Asus 256 GB SSD Laptop Intel Core i3 Processor (7th Gen) 4 GB DDR4  35.56 cm (14 inch)  64 bit Windows 10 Vivo',
#   {'entities': [(0, 4, 'Brand'),
#     (5, 15, 'Disk'),
#     (16, 22, 'Category'),
#     (23, 56, 'Processor'),
#     (57, 67, 'RAM'),
#     (68, 87, 'Dim'),
#     (88, 105, 'OS'),
#     (106, 110, 'Model')]}),
#  ('8 GB DDR4  Asus 35.56 cm (14 inch)  512 GB SSD 64 bit Windows 10 Intel Core i5 Processor (8th Gen) Laptop Vivo',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 15, 'Brand'),
#     (16, 35, 'Dim'),
#     (36, 46, 'Disk'),
#     (47, 64, 'OS'),
#     (65, 98, 'Processor'),
#     (99, 105, 'Category'),
#     (106, 110, 'Model')]}),
#  ('Laptop Pavilion 8 GB DDR4  39.62 cm (15.6 inch)  64 bit Windows 10 HP 1 TB HDD|256 GB SSD Intel Core i5 Processor (9th Gen)',
#   {'entities': [(0, 6, 'Category'),
#     (7, 15, 'Model'),
#     (16, 26, 'RAM'),
#     (27, 48, 'Dim'),
#     (49, 66, 'OS'),
#     (67, 69, 'Brand'),
#     (70, 89, 'Disk'),
#     (90, 123, 'Processor')]}),
#  ('Laptop Intel Core i7 Processor (9th Gen) 512 GB SSD 64 bit Windows 10 39.62 cm (15.6 inch)  16 GB DDR4  Inspiron Dell',
#   {'entities': [(0, 6, 'Category'),
#     (7, 40, 'Processor'),
#     (41, 51, 'Disk'),
#     (52, 69, 'OS'),
#     (70, 91, 'Dim'),
#     (92, 103, 'RAM'),
#     (104, 112, 'Model'),
#     (113, 117, 'Brand')]}),
#  ('Ideapad 4 GB DDR4  Lenovo 64 bit Windows 10 Intel Core i3 Processor (8th Gen) Laptop 1 TB HDD 39.62 cm (15.6 inch) ',
#   {'entities': [(0, 7, 'Model'),
#     (8, 18, 'RAM'),
#     (19, 25, 'Brand'),
#     (26, 43, 'OS'),
#     (44, 77, 'Processor'),
#     (78, 84, 'Category'),
#     (85, 93, 'Disk'),
#     (94, 115, 'Dim')]}),
#  ('256 GB SSD Apple Mac MacBook Pro Intel Core i5 Processor (8th Gen) 33.78 cm (13.3 inch)  8 GB DDR3  Laptop',
#   {'entities': [(0, 10, 'Disk'),
#     (11, 16, 'Brand'),
#     (17, 20, 'OS'),
#     (21, 32, 'Model'),
#     (33, 66, 'Processor'),
#     (67, 88, 'Dim'),
#     (89, 99, 'RAM'),
#     (100, 106, 'Category')]}),
#  ('8 GB DDR3  256 GB SSD Intel Core i5 Processor (8th Gen) Asus 33.78 cm (13.3 inch)  Laptop ZenBook 64 bit Windows 10',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 21, 'Disk'),
#     (22, 55, 'Processor'),
#     (56, 60, 'Brand'),
#     (61, 82, 'Dim'),
#     (83, 89, 'Category'),
#     (90, 97, 'Model'),
#     (98, 115, 'OS')]}),
#  ('4 GB DDR4  1 TB HDD Laptop Lenovo Intel Core i5 Processor (8th Gen) Ideapad 39.62 cm (15.6 inch)  64 bit Windows 10',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 19, 'Disk'),
#     (20, 26, 'Category'),
#     (27, 33, 'Brand'),
#     (34, 67, 'Processor'),
#     (68, 75, 'Model'),
#     (76, 97, 'Dim'),
#     (98, 115, 'OS')]}),
#  ('Zbook Laptop 1 TB HDD HP Intel Core i3 Processor (7th Gen) D 4 GB DDR4  35.56 cm (14 inch) ',
#   {'entities': [(0, 5, 'Model'),
#     (6, 12, 'Category'),
#     (13, 21, 'Disk'),
#     (22, 24, 'Brand'),
#     (25, 58, 'Processor'),
#     (59, 60, 'OS'),
#     (61, 71, 'RAM'),
#     (72, 91, 'Dim')]}),
#  ('256 GB SSD HP Envy 33.78 cm (13.3 inch) Touchscreen  Laptop 8 GB DDR4  Intel Core i5 Processor (10th Gen) 64 bit Windows 10',
#   {'entities': [(0, 10, 'Disk'),
#     (11, 13, 'Brand'),
#     (14, 18, 'Model'),
#     (19, 52, 'Dim'),
#     (53, 59, 'Category'),
#     (60, 70, 'RAM'),
#     (71, 105, 'Processor'),
#     (106, 123, 'OS')]}),
#  ('8 GB DDR4  64 bit Windows 10 512 GB SSD 35.56 cm (14 inch)  Laptop HP Intel Core i5 Processor (10th Gen) Pavilion',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 28, 'OS'),
#     (29, 39, 'Disk'),
#     (40, 59, 'Dim'),
#     (60, 66, 'Category'),
#     (67, 69, 'Brand'),
#     (70, 104, 'Processor'),
#     (105, 113, 'Model')]}),
#  ('Asus ZenBook 39.62 cm (15.6 inch) Touchscreen  32 GB DDR4  64 bit Windows 10 Intel Core i9 Processor (9th Gen) Laptop 1 TB SSD',
#   {'entities': [(0, 4, 'Brand'),
#     (5, 12, 'Model'),
#     (13, 46, 'Dim'),
#     (47, 58, 'RAM'),
#     (59, 76, 'OS'),
#     (77, 110, 'Processor'),
#     (111, 117, 'Category'),
#     (118, 126, 'Disk')]}),
#  ('1 TB HDD|8 GB SSD Intel Core i5 Processor (8th Gen) 64 bit Windows 10 8 GB DDR4  HP 35.56 cm (14 inch) Touchscreen  Pavilion Laptop',
#   {'entities': [(0, 17, 'Disk'),
#     (18, 51, 'Processor'),
#     (52, 69, 'OS'),
#     (70, 80, 'RAM'),
#     (81, 83, 'Brand'),
#     (84, 115, 'Dim'),
#     (116, 124, 'Model'),
#     (125, 131, 'Category')]}),
#  ('Nitro 1 TB HDD|256 GB SSD 39.62 cm (15.6 inch)  8 GB DDR4  Laptop 64 bit Windows 10 Intel Core i5 Processor (9th Gen) Acer',
#   {'entities': [(0, 5, 'Model'),
#     (6, 25, 'Disk'),
#     (26, 47, 'Dim'),
#     (48, 58, 'RAM'),
#     (59, 65, 'Category'),
#     (66, 83, 'OS'),
#     (84, 117, 'Processor'),
#     (118, 122, 'Brand')]}),
#  ('1 TB HDD D 4 GB DDR4  Laptop Lenovo 39.62 cm (15.6 inch)  Intel Core i3 Processor (7th Gen) Ideapad',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 10, 'OS'),
#     (11, 21, 'RAM'),
#     (22, 28, 'Category'),
#     (29, 35, 'Brand'),
#     (36, 57, 'Dim'),
#     (58, 91, 'Processor'),
#     (92, 99, 'Model')]}),
#  ('Laptop Intel Core i3 Processor (7th Gen) 4 GB DDR4  35.56 cm (14 inch)  1 TB HDD 64 bit Windows 10 HP EliteBook',
#   {'entities': [(0, 6, 'Category'),
#     (7, 40, 'Processor'),
#     (41, 51, 'RAM'),
#     (52, 71, 'Dim'),
#     (72, 80, 'Disk'),
#     (81, 98, 'OS'),
#     (99, 101, 'Brand'),
#     (102, 111, 'Model')]}),
#  ('TUF Gaming 1 TB HDD 39.62 cm (15.6 inch)  Asus 4 GB DDR4  AMD Ryzen 5 Quad Core Processor Laptop 64 bit Windows 10',
#   {'entities': [(0, 10, 'Model'),
#     (11, 19, 'Disk'),
#     (20, 41, 'Dim'),
#     (42, 46, 'Brand'),
#     (47, 57, 'RAM'),
#     (58, 89, 'Processor'),
#     (90, 96, 'Category'),
#     (97, 114, 'OS')]}),
#  ('Pavilion Laptop 8 GB DDR4  39.62 cm (15.6 inch)  64 bit Windows 10 1 TB HDD HP Intel Core i3 Processor (8th Gen)',
#   {'entities': [(0, 8, 'Model'),
#     (9, 15, 'Category'),
#     (16, 26, 'RAM'),
#     (27, 48, 'Dim'),
#     (49, 66, 'OS'),
#     (67, 75, 'Disk'),
#     (76, 78, 'Brand'),
#     (79, 112, 'Processor')]}),
#  ('1 TB HDD|256 GB SSD Vivo 64 bit Windows 10 35.56 cm (14 inch)  Laptop Asus Intel Core i5 Processor (8th Gen) 8 GB DDR4 ',
#   {'entities': [(0, 19, 'Disk'),
#     (20, 24, 'Model'),
#     (25, 42, 'OS'),
#     (43, 62, 'Dim'),
#     (63, 69, 'Category'),
#     (70, 74, 'Brand'),
#     (75, 108, 'Processor'),
#     (109, 119, 'RAM')]}),
#  ('Mac 8 GB DDR3  Intel Core i5 Processor (8th Gen) 512 GB SSD Apple 33.78 cm (13.3 inch)  Laptop MacBook Pro',
#   {'entities': [(0, 3, 'OS'),
#     (4, 14, 'RAM'),
#     (15, 48, 'Processor'),
#     (49, 59, 'Disk'),
#     (60, 65, 'Brand'),
#     (66, 87, 'Dim'),
#     (88, 94, 'Category'),
#     (95, 106, 'Model')]}),
#  ('Laptop Vivo 512 GB SSD 8 GB DDR4  64 bit Windows 10 35.56 cm (14 inch)  Asus Intel Core i5 Processor (8th Gen)',
#   {'entities': [(0, 6, 'Category'),
#     (7, 11, 'Model'),
#     (12, 22, 'Disk'),
#     (23, 33, 'RAM'),
#     (34, 51, 'OS'),
#     (52, 71, 'Dim'),
#     (72, 76, 'Brand'),
#     (77, 110, 'Processor')]}),
#  ('Lenovo Ideapad 64 bit Windows 10 Laptop 1 TB HDD 35.56 cm (14 inch)  4 GB DDR4  Intel Core i3 Processor (10th Gen)',
#   {'entities': [(0, 6, 'Brand'),
#     (7, 14, 'Model'),
#     (15, 32, 'OS'),
#     (33, 39, 'Category'),
#     (40, 48, 'Disk'),
#     (49, 68, 'Dim'),
#     (69, 79, 'RAM'),
#     (80, 114, 'Processor')]}),
#  ('39.62 cm (15.6 inch)  4 GB DDR4  ProBook 500 GB HDD 64 bit Windows 10 AMD APU Dual Core A9 Processor HP Laptop',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 32, 'RAM'),
#     (33, 40, 'Model'),
#     (41, 51, 'Disk'),
#     (52, 69, 'OS'),
#     (70, 100, 'Processor'),
#     (101, 103, 'Brand'),
#     (104, 110, 'Category')]}),
#  ('Intel Core i3 Processor (8th Gen) 4 GB DDR4  256 GB SSD Laptop 64 bit Windows 10 HP Pavilion 35.56 cm (14 inch) Touchscreen ',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 44, 'RAM'),
#     (45, 55, 'Disk'),
#     (56, 62, 'Category'),
#     (63, 80, 'OS'),
#     (81, 83, 'Brand'),
#     (84, 92, 'Model'),
#     (93, 124, 'Dim')]}),
#  ('64 bit Windows 10 256 GB SSD 35.56 cm (14 inch)  8 GB DDR4  Laptop Liber Intel Core i5 Processor (8th Gen) Avita',
#   {'entities': [(0, 17, 'OS'),
#     (18, 28, 'Disk'),
#     (29, 48, 'Dim'),
#     (49, 59, 'RAM'),
#     (60, 66, 'Category'),
#     (67, 72, 'Model'),
#     (73, 106, 'Processor'),
#     (107, 112, 'Brand')]}),
#  ('1 TB HDD|128 GB SSD 8 GB DDR4  39.62 cm (15.6 inch)  Laptop AMD Ryzen 7 Quad Core Processor HP Pavilion 64 bit Windows 10',
#   {'entities': [(0, 19, 'Disk'),
#     (20, 30, 'RAM'),
#     (31, 52, 'Dim'),
#     (53, 59, 'Category'),
#     (60, 91, 'Processor'),
#     (92, 94, 'Brand'),
#     (95, 103, 'Model'),
#     (104, 121, 'OS')]}),
#  ('34.29 cm (13.5 inch) Touchscreen  64 bit Windows 10 Laptop Intel Core i7 Processor (7th Gen) Surface 256 GB SSD 8 GB DDR3  Microsoft',
#   {'entities': [(0, 33, 'Dim'),
#     (34, 51, 'OS'),
#     (52, 58, 'Category'),
#     (59, 92, 'Processor'),
#     (93, 100, 'Model'),
#     (101, 111, 'Disk'),
#     (112, 122, 'RAM'),
#     (123, 132, 'Brand')]}),
#  ('256 GB SSD Asus Laptop ZenBook 8 GB DDR3  35.56 cm (14 inch)  Intel Core i5 Processor (8th Gen) 64 bit Windows 10',
#   {'entities': [(0, 10, 'Disk'),
#     (11, 15, 'Brand'),
#     (16, 22, 'Category'),
#     (23, 30, 'Model'),
#     (31, 41, 'RAM'),
#     (42, 61, 'Dim'),
#     (62, 95, 'Processor'),
#     (96, 113, 'OS')]}),
#  ('MSI Intel Core i7 Processor (9th Gen) 64 bit Windows 10 1 TB SSD Gaming Laptop 32 GB DDR4  39.62 cm (15.6 inch) ',
#   {'entities': [(0, 3, 'Brand'),
#     (4, 37, 'Processor'),
#     (38, 55, 'OS'),
#     (56, 64, 'Disk'),
#     (65, 71, 'Model'),
#     (72, 78, 'Category'),
#     (79, 90, 'RAM'),
#     (91, 112, 'Dim')]}),
#  ('256 GB SSD Avita 64 bit Windows 10 35.56 cm (14 inch)  Laptop 8 GB DDR4  Liber Intel Core i5 Processor (8th Gen)',
#   {'entities': [(0, 10, 'Disk'),
#     (11, 16, 'Brand'),
#     (17, 34, 'OS'),
#     (35, 54, 'Dim'),
#     (55, 61, 'Category'),
#     (62, 72, 'RAM'),
#     (73, 78, 'Model'),
#     (79, 112, 'Processor')]}),
#  ('Acer Intel Core i7 Processor (8th Gen) 64 bit Windows 10 Nitro 1 TB HDD 8 GB DDR4  Laptop 39.62 cm (15.6 inch) ',
#   {'entities': [(0, 4, 'Brand'),
#     (5, 38, 'Processor'),
#     (39, 56, 'OS'),
#     (57, 62, 'Model'),
#     (63, 71, 'Disk'),
#     (72, 82, 'RAM'),
#     (83, 89, 'Category'),
#     (90, 111, 'Dim')]}),
#  ('64 bit Windows 10 8 GB DDR4  Intel Core i5 Processor (8th Gen) Vivo 35.56 cm (14 inch)  Asus Laptop 1 TB HDD|256 GB SSD',
#   {'entities': [(0, 17, 'OS'),
#     (18, 28, 'RAM'),
#     (29, 62, 'Processor'),
#     (63, 67, 'Model'),
#     (68, 87, 'Dim'),
#     (88, 92, 'Brand'),
#     (93, 99, 'Category'),
#     (100, 119, 'Disk')]}),
#  ('Vivo 256 GB SSD Asus 64 bit Windows 10 4 GB DDR4  Laptop Intel Core i3 Processor (7th Gen) 35.56 cm (14 inch) ',
#   {'entities': [(0, 4, 'Model'),
#     (5, 15, 'Disk'),
#     (16, 20, 'Brand'),
#     (21, 38, 'OS'),
#     (39, 49, 'RAM'),
#     (50, 56, 'Category'),
#     (57, 90, 'Processor'),
#     (91, 110, 'Dim')]}),
#  ('Laptop 64 bit Windows 10 Legion 8 GB DDR4  39.62 cm (15.6 inch)  Lenovo Intel Core i7 Processor (8th Gen) 1 TB HDD|128 GB SSD',
#   {'entities': [(0, 6, 'Category'),
#     (7, 24, 'OS'),
#     (25, 31, 'Model'),
#     (32, 42, 'RAM'),
#     (43, 64, 'Dim'),
#     (65, 71, 'Brand'),
#     (72, 105, 'Processor'),
#     (106, 125, 'Disk')]}),
#  ('512 GB SSD 33.78 cm (13.3 inch) Touchscreen  Yoga Intel Core i5 Processor (8th Gen) Laptop 64 bit Windows 10 8 GB DDR4  Lenovo',
#   {'entities': [(0, 10, 'Disk'),
#     (11, 44, 'Dim'),
#     (45, 49, 'Model'),
#     (50, 83, 'Processor'),
#     (84, 90, 'Category'),
#     (91, 108, 'OS'),
#     (109, 119, 'RAM'),
#     (120, 126, 'Brand')]}),
#  ('1 TB HDD|256 GB SSD Pavilion Laptop 64 bit Windows 10 HP Intel Core i7 Processor (9th Gen) 8 GB DDR4  39.62 cm (15.6 inch) ',
#   {'entities': [(0, 19, 'Disk'),
#     (20, 28, 'Model'),
#     (29, 35, 'Category'),
#     (36, 53, 'OS'),
#     (54, 56, 'Brand'),
#     (57, 90, 'Processor'),
#     (91, 101, 'RAM'),
#     (102, 123, 'Dim')]}),
#  ('35.56 cm (14 inch) Touchscreen  Pavilion 64 bit Windows 10 Intel Core i3 Processor (10th Gen) 256 GB SSD HP 4 GB DDR4  Laptop',
#   {'entities': [(0, 31, 'Dim'),
#     (32, 40, 'Model'),
#     (41, 58, 'OS'),
#     (59, 93, 'Processor'),
#     (94, 104, 'Disk'),
#     (105, 107, 'Brand'),
#     (108, 118, 'RAM'),
#     (119, 125, 'Category')]}),
#  ('HP 4 GB DDR4  Pavilion 1 TB HDD 39.62 cm (15.6 inch)  Intel Core i3 Processor (7th Gen) Laptop 64 bit D',
#   {'entities': [(0, 2, 'Brand'),
#     (3, 13, 'RAM'),
#     (14, 22, 'Model'),
#     (23, 31, 'Disk'),
#     (32, 53, 'Dim'),
#     (54, 87, 'Processor'),
#     (88, 94, 'Category'),
#     (95, 103, 'OS')]}),
#  ('1 TB HDD|512 GB SSD Laptop 64 bit Windows 10 Dell Inspiron Intel Core i5 Processor (8th Gen) 8 GB DDR4  39.62 cm (15.6 inch) ',
#   {'entities': [(0, 19, 'Disk'),
#     (20, 26, 'Category'),
#     (27, 44, 'OS'),
#     (45, 49, 'Brand'),
#     (50, 58, 'Model'),
#     (59, 92, 'Processor'),
#     (93, 103, 'RAM'),
#     (104, 125, 'Dim')]}),
#  ('8 GB DDR3  Intel Core i5 Processor (8th Gen) 128 GB SSD 33.78 cm (13.3 inch)  Apple Mac Laptop MacBook Air',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 44, 'Processor'),
#     (45, 55, 'Disk'),
#     (56, 77, 'Dim'),
#     (78, 83, 'Brand'),
#     (84, 87, 'OS'),
#     (88, 94, 'Category'),
#     (95, 106, 'Model')]}),
#  ('64 bit Mac Intel Core i5 Processor (7th Gen) 33.78 cm (13.3 inch)  Apple 128 GB SSD MacBook Pro Laptop 8 GB DDR3 ',
#   {'entities': [(0, 10, 'OS'),
#     (11, 44, 'Processor'),
#     (45, 66, 'Dim'),
#     (67, 72, 'Brand'),
#     (73, 83, 'Disk'),
#     (84, 95, 'Model'),
#     (96, 102, 'Category'),
#     (103, 113, 'RAM')]}),
#  ('Intel Core i5 Processor (8th Gen) 8 GB DDR4  Liber Avita 256 GB SSD 64 bit Windows 10 Laptop 35.56 cm (14 inch) ',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 44, 'RAM'),
#     (45, 50, 'Model'),
#     (51, 56, 'Brand'),
#     (57, 67, 'Disk'),
#     (68, 85, 'OS'),
#     (86, 92, 'Category'),
#     (93, 112, 'Dim')]}),
#  ('64 bit Windows 10 31.24 cm (12.3 inch) Touchscreen  Laptop Intel Core i5 Processor (8th Gen) SurfacePro 8 GB DDR3  256 GB SSD Microsoft',
#   {'entities': [(0, 17, 'OS'),
#     (18, 51, 'Dim'),
#     (52, 58, 'Category'),
#     (59, 92, 'Processor'),
#     (93, 103, 'Model'),
#     (104, 114, 'RAM'),
#     (115, 125, 'Disk'),
#     (126, 135, 'Brand')]}),
#  ('Predator Intel Core i7 Processor (7th Gen) Laptop 2 TB HDD|256 GB SSD 43.94 cm (17.3 inch)  Acer 16 GB DDR4  64 bit Windows 10',
#   {'entities': [(0, 8, 'Model'),
#     (9, 42, 'Processor'),
#     (43, 49, 'Category'),
#     (50, 69, 'Disk'),
#     (70, 91, 'Dim'),
#     (92, 96, 'Brand'),
#     (97, 108, 'RAM'),
#     (109, 126, 'OS')]}),
#  ('Ideapad 39.62 cm (15.6 inch)  Laptop 64 bit Windows 10 Lenovo 1 TB HDD Intel Core i3 Processor (7th Gen) 4 GB DDR4 ',
#   {'entities': [(0, 7, 'Model'),
#     (8, 29, 'Dim'),
#     (30, 36, 'Category'),
#     (37, 54, 'OS'),
#     (55, 61, 'Brand'),
#     (62, 70, 'Disk'),
#     (71, 104, 'Processor'),
#     (105, 115, 'RAM')]}),
#  ('512 GB SSD Modern 8 GB DDR4  Intel Core i7 Processor (10th Gen) 35.56 cm (14 inch)  64 bit Windows 10 MSI Laptop',
#   {'entities': [(0, 10, 'Disk'),
#     (11, 17, 'Model'),
#     (18, 28, 'RAM'),
#     (29, 63, 'Processor'),
#     (64, 83, 'Dim'),
#     (84, 101, 'OS'),
#     (102, 105, 'Brand'),
#     (106, 112, 'Category')]}),
#  ('Laptop 512 GB SSD Lenovo 35.56 cm (14 inch) Touchscreen  Intel Core i5 Processor (8th Gen) Yoga 8 GB DDR4  64 bit Windows 10',
#   {'entities': [(0, 6, 'Category'),
#     (7, 17, 'Disk'),
#     (18, 24, 'Brand'),
#     (25, 56, 'Dim'),
#     (57, 90, 'Processor'),
#     (91, 95, 'Model'),
#     (96, 106, 'RAM'),
#     (107, 124, 'OS')]}),
#  ('4 GB DDR4  Asus 1 TB HDD 64 bit Endl 39.62 cm (15.6 inch)  Laptop Intel Core i3 Processor (7th Gen) TUF Gaming',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 15, 'Brand'),
#     (16, 24, 'Disk'),
#     (25, 36, 'OS'),
#     (37, 58, 'Dim'),
#     (59, 65, 'Category'),
#     (66, 99, 'Processor'),
#     (100, 110, 'Model')]}),
#  ('33.78 cm (13.3 inch)  256 GB SSD Aspire 8 GB DDR4  Acer Intel Core i5 Processor (8th Gen) 64 bit Windows 10 Laptop',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 32, 'Disk'),
#     (33, 39, 'Model'),
#     (40, 50, 'RAM'),
#     (51, 55, 'Brand'),
#     (56, 89, 'Processor'),
#     (90, 107, 'OS'),
#     (108, 114, 'Category')]}),
#  ('39.62 cm (15.6 inch)  4 GB DDR4  1 TB HDD Laptop HP Intel Core i3 Processor (8th Gen) 64 bit Windows 10 EliteBook',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 32, 'RAM'),
#     (33, 41, 'Disk'),
#     (42, 48, 'Category'),
#     (49, 51, 'Brand'),
#     (52, 85, 'Processor'),
#     (86, 103, 'OS'),
#     (104, 113, 'Model')]}),
#  ('Lenovo 8 GB DDR4  512 GB SSD Intel Core i7 Processor (8th Gen) Ideapad Laptop 33.78 cm (13.3 inch)  64 bit Windows 10',
#   {'entities': [(0, 6, 'Brand'),
#     (7, 17, 'RAM'),
#     (18, 28, 'Disk'),
#     (29, 62, 'Processor'),
#     (63, 70, 'Model'),
#     (71, 77, 'Category'),
#     (78, 99, 'Dim'),
#     (100, 117, 'OS')]}),
#  ('8 GB DDR3  MacBook Pro Laptop Apple Intel Core i5 Processor (8th Gen) 128 GB SSD Mac 33.78 cm (13.3 inch) ',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 22, 'Model'),
#     (23, 29, 'Category'),
#     (30, 35, 'Brand'),
#     (36, 69, 'Processor'),
#     (70, 80, 'Disk'),
#     (81, 84, 'OS'),
#     (85, 106, 'Dim')]}),
#  ('Intel Core i7 Processor (9th Gen) Asus 64 bit Windows 10 32 GB DDR4  39.62 cm (15.6 inch) Touchscreen  ZenBook 1 TB SSD Laptop',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 38, 'Brand'),
#     (39, 56, 'OS'),
#     (57, 68, 'RAM'),
#     (69, 102, 'Dim'),
#     (103, 110, 'Model'),
#     (111, 119, 'Disk'),
#     (120, 126, 'Category')]}),
# ...
#     (92, 94, 'Brand'),
#     (95, 99, 'Model'),
#     (100, 106, 'Category'),
#     (107, 124, 'OS')]}),
#  ('Intel Core i5 Processor (7th Gen) XPS 256 GB SSD 64 bit Windows 10 8 GB DDR3  Dell Laptop 33.78 cm (13.3 inch) ',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 37, 'Model'),
#     (38, 48, 'Disk'),
#     (49, 66, 'OS'),
#     (67, 77, 'RAM'),
#     (78, 82, 'Brand'),
#     (83, 89, 'Category'),
#     (90, 111, 'Dim')]}),
#  ('Ideapad Intel Core i3 Processor (7th Gen) 64 bit Windows 10 Lenovo Laptop 39.62 cm (15.6 inch)  4 GB DDR4  1 TB HDD',
#   {'entities': [(0, 7, 'Model'),
#     (8, 41, 'Processor'),
#     (42, 59, 'OS'),
#     (60, 66, 'Brand'),
#     (67, 73, 'Category'),
#     (74, 95, 'Dim'),
#     (96, 106, 'RAM'),
#     (107, 115, 'Disk')]}),
#  ('64 bit Windows 10 Laptop Intel Core i5 Processor (8th Gen) 1 TB HDD 39.62 cm (15.6 inch)  Vivo Asus 8 GB DDR4 ',
#   {'entities': [(0, 17, 'OS'),
#     (18, 24, 'Category'),
#     (25, 58, 'Processor'),
#     (59, 67, 'Disk'),
#     (68, 89, 'Dim'),
#     (90, 94, 'Model'),
#     (95, 99, 'Brand'),
#     (100, 110, 'RAM')]}),
#  ('Apple Intel Core i5 Processor (5th Gen) MacBook Air 128 GB SSD 33.78 cm (13.3 inch)  8 GB  Mac Laptop',
#   {'entities': [(0, 5, 'Brand'),
#     (6, 39, 'Processor'),
#     (40, 51, 'Model'),
#     (52, 62, 'Disk'),
#     (63, 84, 'Dim'),
#     (85, 90, 'RAM'),
#     (91, 94, 'OS'),
#     (95, 101, 'Category')]}),
#  ('Laptop 64 bit Windows 10 Dell AMD Ryzen 3 Quad Core Processor Inspiron 39.62 cm (15.6 inch)  1 TB HDD 4 GB DDR4 ',
#   {'entities': [(0, 6, 'Category'),
#     (7, 24, 'OS'),
#     (25, 29, 'Brand'),
#     (30, 61, 'Processor'),
#     (62, 70, 'Model'),
#     (71, 92, 'Dim'),
#     (93, 101, 'Disk'),
#     (102, 112, 'RAM')]}),
#  ('Lenovo D 39.62 cm (15.6 inch)  Ideapad Laptop Intel Core i5 Processor (8th Gen) 1 TB HDD 8 GB DDR4 ',
#   {'entities': [(0, 6, 'Brand'),
#     (7, 8, 'OS'),
#     (9, 30, 'Dim'),
#     (31, 38, 'Model'),
#     (39, 45, 'Category'),
#     (46, 79, 'Processor'),
#     (80, 88, 'Disk'),
#     (89, 99, 'RAM')]}),
#  ('39.62 cm (15.6 inch)  1 TB HDD|512 GB SSD Intel Core i7 Processor (9th Gen) 12 GB DDR4  HP 64 bit Windows 10 Laptop Pavilion',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 41, 'Disk'),
#     (42, 75, 'Processor'),
#     (76, 87, 'RAM'),
#     (88, 90, 'Brand'),
#     (91, 108, 'OS'),
#     (109, 115, 'Category'),
#     (116, 124, 'Model')]}),
#  ('Ideapad 8 GB DDR4  Intel Core i5 Processor (8th Gen) Lenovo Laptop 1 TB HDD 64 bit Windows 10 39.62 cm (15.6 inch) ',
#   {'entities': [(0, 7, 'Model'),
#     (8, 18, 'RAM'),
#     (19, 52, 'Processor'),
#     (53, 59, 'Brand'),
#     (60, 66, 'Category'),
#     (67, 75, 'Disk'),
#     (76, 93, 'OS'),
#     (94, 115, 'Dim')]}),
#  ('39.62 cm (15.6 inch)  Inspiron 8 GB DDR4  Dell 64 bit Windows 10 Intel Core i5 Processor (8th Gen) Laptop 2 TB HDD',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 30, 'Model'),
#     (31, 41, 'RAM'),
#     (42, 46, 'Brand'),
#     (47, 64, 'OS'),
#     (65, 98, 'Processor'),
#     (99, 105, 'Category'),
#     (106, 114, 'Disk')]}),
#  ('Laptop 12 GB DDR4  1 TB HDD|512 GB SSD HP Pavilion 64 bit Windows 10 Intel Core i7 Processor (9th Gen) 39.62 cm (15.6 inch) ',
#   {'entities': [(0, 6, 'Category'),
#     (7, 18, 'RAM'),
#     (19, 38, 'Disk'),
#     (39, 41, 'Brand'),
#     (42, 50, 'Model'),
#     (51, 68, 'OS'),
#     (69, 102, 'Processor'),
#     (103, 124, 'Dim')]}),
#  ('Ideapad 64 bit Windows 10 4 GB DDR4  Lenovo Intel Core i3 Processor (7th Gen) 39.62 cm (15.6 inch)  Laptop 1 TB HDD',
#   {'entities': [(0, 7, 'Model'),
#     (8, 25, 'OS'),
#     (26, 36, 'RAM'),
#     (37, 43, 'Brand'),
#     (44, 77, 'Processor'),
#     (78, 99, 'Dim'),
#     (100, 106, 'Category'),
#     (107, 115, 'Disk')]}),
#  ('Dell 1 TB HDD Inspiron 4 GB DDR4  39.62 cm (15.6 inch)  Intel Core i3 Processor (8th Gen) 64 bit Windows 10 Laptop',
#   {'entities': [(0, 4, 'Brand'),
#     (5, 13, 'Disk'),
#     (14, 22, 'Model'),
#     (23, 33, 'RAM'),
#     (34, 55, 'Dim'),
#     (56, 89, 'Processor'),
#     (90, 107, 'OS'),
#     (108, 114, 'Category')]}),
#  ('64 bit Windows 10 8 GB DDR4  35.56 cm (14 inch)  512 GB SSD Pavilion Intel Core i7 Processor (8th Gen) HP Laptop',
#   {'entities': [(0, 17, 'OS'),
#     (18, 28, 'RAM'),
#     (29, 48, 'Dim'),
#     (49, 59, 'Disk'),
#     (60, 68, 'Model'),
#     (69, 102, 'Processor'),
#     (103, 105, 'Brand'),
#     (106, 112, 'Category')]}),
#  ('Laptop Acer 39.62 cm (15.6 inch)  1 TB HDD Intel Core i5 Processor (7th Gen) 64 bit Windows 10 Aspire 8 GB DDR4 ',
#   {'entities': [(0, 6, 'Category'),
#     (7, 11, 'Brand'),
#     (12, 33, 'Dim'),
#     (34, 42, 'Disk'),
#     (43, 76, 'Processor'),
#     (77, 94, 'OS'),
#     (95, 101, 'Model'),
#     (102, 112, 'RAM')]}),
#  ('39.62 cm (15.6 inch)  64 bit Windows 10 Dell Inspiron Intel Core i7 Processor (8th Gen) 8 GB DDR4  Laptop 2 TB HDD|128 GB SSD',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 39, 'OS'),
#     (40, 44, 'Brand'),
#     (45, 53, 'Model'),
#     (54, 87, 'Processor'),
#     (88, 98, 'RAM'),
#     (99, 105, 'Category'),
#     (106, 125, 'Disk')]}),
#  ('33.78 cm (13.3 inch)  ZenBook Asus 512 GB SSD Intel Core i5 Processor (8th Gen) Laptop 64 bit Windows 10 8 GB DDR3 ',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 29, 'Model'),
#     (30, 34, 'Brand'),
#     (35, 45, 'Disk'),
#     (46, 79, 'Processor'),
#     (80, 86, 'Category'),
#     (87, 104, 'OS'),
#     (105, 115, 'RAM')]}),
#  ('8 GB DDR4  39.62 cm (15.6 inch)  64 bit Windows 10 Pavilion 1 TB HDD|256 GB SSD Laptop HP Intel Core i5 Processor (8th Gen)',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 32, 'Dim'),
#     (33, 50, 'OS'),
#     (51, 59, 'Model'),
#     (60, 79, 'Disk'),
#     (80, 86, 'Category'),
#     (87, 89, 'Brand'),
#     (90, 123, 'Processor')]}),
#  ('64 bit Windows 10 1 TB HDD 39.62 cm (15.6 inch)  Pavilion 8 GB DDR4  Laptop Intel Core i3 Processor (7th Gen) HP',
#   {'entities': [(0, 17, 'OS'),
#     (18, 26, 'Disk'),
#     (27, 48, 'Dim'),
#     (49, 57, 'Model'),
#     (58, 68, 'RAM'),
#     (69, 75, 'Category'),
#     (76, 109, 'Processor'),
#     (110, 112, 'Brand')]}),
#  ('1 TB HDD 4 GB DDR3  Lenovo D Ideapad 39.62 cm (15.6 inch)  Laptop Intel Pentium Quad Core Processor',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 19, 'RAM'),
#     (20, 26, 'Brand'),
#     (27, 28, 'OS'),
#     (29, 36, 'Model'),
#     (37, 58, 'Dim'),
#     (59, 65, 'Category'),
#     (66, 99, 'Processor')]}),
#  ('1 TB HDD Envy Intel Core i3 Processor (7th Gen) 39.62 cm (15.6 inch)  4 GB DDR4  D HP Laptop',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 13, 'Model'),
#     (14, 47, 'Processor'),
#     (48, 69, 'Dim'),
#     (70, 80, 'RAM'),
#     (81, 82, 'OS'),
#     (83, 85, 'Brand'),
#     (86, 92, 'Category')]}),
#  ('8 GB DDR4  Laptop Lenovo 39.62 cm (15.6 inch)  Ideapad Intel Core i5 Processor (8th Gen) 64 bit Windows 10 2 TB HDD',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 17, 'Category'),
#     (18, 24, 'Brand'),
#     (25, 46, 'Dim'),
#     (47, 54, 'Model'),
#     (55, 88, 'Processor'),
#     (89, 106, 'OS'),
#     (107, 115, 'Disk')]}),
#  ('35.56 cm (14 inch)  Intel Core i3 Processor (7th Gen) Laptop Lenovo 4 GB DDR4  64 bit Windows 10 500 GB HDD ThinkPad X Series',
#   {'entities': [(0, 19, 'Dim'),
#     (20, 53, 'Processor'),
#     (54, 60, 'Category'),
#     (61, 67, 'Brand'),
#     (68, 78, 'RAM'),
#     (79, 96, 'OS'),
#     (97, 107, 'Disk'),
#     (108, 125, 'Model')]}),
#  ('8 GB DDR4  35.56 cm (14 inch)  AGB Laptop Intel Core i7 Processor (7th Gen) 1 TB HDD|512 GB SSD 64 bit Windows 10 Orion',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 30, 'Dim'),
#     (31, 34, 'Brand'),
#     (35, 41, 'Category'),
#     (42, 75, 'Processor'),
#     (76, 95, 'Disk'),
#     (96, 113, 'OS'),
#     (114, 119, 'Model')]}),
#  ('Lenovo 1 TB HDD Intel Core i3 Processor (7th Gen) 35.56 cm (14 inch)  Laptop 64 bit Windows 10 4 GB DDR4  Ideapad',
#   {'entities': [(0, 6, 'Brand'),
#     (7, 15, 'Disk'),
#     (16, 49, 'Processor'),
#     (50, 69, 'Dim'),
#     (70, 76, 'Category'),
#     (77, 94, 'OS'),
#     (95, 105, 'RAM'),
#     (106, 113, 'Model')]}),
#  ('Pavilion 4 GB DDR4  1 TB HDD HP Intel Core i5 Processor (7th Gen) Laptop D 39.62 cm (15.6 inch) ',
#   {'entities': [(0, 8, 'Model'),
#     (9, 19, 'RAM'),
#     (20, 28, 'Disk'),
#     (29, 31, 'Brand'),
#     (32, 65, 'Processor'),
#     (66, 72, 'Category'),
#     (73, 74, 'OS'),
#     (75, 96, 'Dim')]}),
#  ('Intel Core i5 Processor (7th Gen) Laptop 39.62 cm (15.6 inch)  4 GB DDR4  64 bit Windows 10 HP Zbook 1 TB HDD',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 40, 'Category'),
#     (41, 62, 'Dim'),
#     (63, 73, 'RAM'),
#     (74, 91, 'OS'),
#     (92, 94, 'Brand'),
#     (95, 100, 'Model'),
#     (101, 109, 'Disk')]}),
#  ('HP Envy 1 TB HDD 4 GB DDR4  Intel Core i3 Processor (7th Gen) Laptop 35.56 cm (14 inch)  64 bit Windows 10',
#   {'entities': [(0, 2, 'Brand'),
#     (3, 7, 'Model'),
#     (8, 16, 'Disk'),
#     (17, 27, 'RAM'),
#     (28, 61, 'Processor'),
#     (62, 68, 'Category'),
#     (69, 88, 'Dim'),
#     (89, 106, 'OS')]}),
#  ('64 bit Windows 10 Laptop 8 GB DDR4  Intel Core i5 Processor (8th Gen) 39.62 cm (15.6 inch)  Ideapad Lenovo 1 TB HDD',
#   {'entities': [(0, 17, 'OS'),
#     (18, 24, 'Category'),
#     (25, 35, 'RAM'),
#     (36, 69, 'Processor'),
#     (70, 91, 'Dim'),
#     (92, 99, 'Model'),
#     (100, 106, 'Brand'),
#     (107, 115, 'Disk')]}),
#  ('Intel Core i5 Processor (8th Gen) 39.62 cm (15.6 inch)  2 TB HDD 64 bit Windows 10 Laptop 4 GB DDR4  Dell Inspiron',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 55, 'Dim'),
#     (56, 64, 'Disk'),
#     (65, 82, 'OS'),
#     (83, 89, 'Category'),
#     (90, 100, 'RAM'),
#     (101, 105, 'Brand'),
#     (106, 114, 'Model')]}),
#  ('64 bit Windows 10 Laptop Pavilion 4 GB DDR4  35.56 cm (14 inch) Touchscreen  1 TB HDD|8 GB SSD Intel Core i3 Processor (8th Gen) HP',
#   {'entities': [(0, 17, 'OS'),
#     (18, 24, 'Category'),
#     (25, 33, 'Model'),
#     (34, 44, 'RAM'),
#     (45, 76, 'Dim'),
#     (77, 94, 'Disk'),
#     (95, 128, 'Processor'),
#     (129, 131, 'Brand')]}),
#  ('Asus 1 TB SSD 35.56 cm (14 inch)  64 bit Windows 10 16 GB DDR3  ZenBook Intel Core i7 Processor (10th Gen) Laptop',
#   {'entities': [(0, 4, 'Brand'),
#     (5, 13, 'Disk'),
#     (14, 33, 'Dim'),
#     (34, 51, 'OS'),
#     (52, 63, 'RAM'),
#     (64, 71, 'Model'),
#     (72, 106, 'Processor'),
#     (107, 113, 'Category')]}),
#  ('8 GB DDR4  64 bit Windows 10 Pavilion 39.62 cm (15.6 inch)  HP 1 TB HDD Intel Core i5 Processor (8th Gen) Laptop',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 28, 'OS'),
#     (29, 37, 'Model'),
#     (38, 59, 'Dim'),
#     (60, 62, 'Brand'),
#     (63, 71, 'Disk'),
#     (72, 105, 'Processor'),
#     (106, 112, 'Category')]}),
#  ('Intel Core i3 Processor (7th Gen) 39.62 cm (15.6 inch)  1 TB HDD 64 bit Windows 10 Laptop Vivo 8 GB DDR4  Asus',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 55, 'Dim'),
#     (56, 64, 'Disk'),
#     (65, 82, 'OS'),
#     (83, 89, 'Category'),
#     (90, 94, 'Model'),
#     (95, 105, 'RAM'),
#     (106, 110, 'Brand')]}),
#  ('1 TB HDD 4 GB DDR4  35.56 cm (14 inch)  Laptop 64 bit Windows 10 Intel Core i3 Processor (7th Gen) Envy HP',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 19, 'RAM'),
#     (20, 39, 'Dim'),
#     (40, 46, 'Category'),
#     (47, 64, 'OS'),
#     (65, 98, 'Processor'),
#     (99, 103, 'Model'),
#     (104, 106, 'Brand')]}),
#  ('1 TB HDD Laptop D Pavilion 8 GB DDR4  HP Intel Core i5 Processor (8th Gen) 39.62 cm (15.6 inch) ',
#   {'entities': [(0, 8, 'Disk'),
#     (9, 15, 'Category'),
#     (16, 17, 'OS'),
#     (18, 26, 'Model'),
#     (27, 37, 'RAM'),
#     (38, 40, 'Brand'),
#     (41, 74, 'Processor'),
#     (75, 96, 'Dim')]}),
#  ('128 GB SSD Microsoft Laptop 8 GB DDR3  Intel Core i5 Processor (8th Gen) 31.24 cm (12.3 inch) Touchscreen  64 bit Windows 10 SurfacePro',
#   {'entities': [(0, 10, 'Disk'),
#     (11, 20, 'Brand'),
#     (21, 27, 'Category'),
#     (28, 38, 'RAM'),
#     (39, 72, 'Processor'),
#     (73, 106, 'Dim'),
#     (107, 124, 'OS'),
#     (125, 135, 'Model')]}),
#  ('4 GB DDR4  1 TB HDD 64 bit Windows 10 39.62 cm (15.6 inch)  Laptop Asus Vivo Intel Core i3 Processor (7th Gen)',
#   {'entities': [(0, 10, 'RAM'),
#     (11, 19, 'Disk'),
#     (20, 37, 'OS'),
#     (38, 59, 'Dim'),
#     (60, 66, 'Category'),
#     (67, 71, 'Brand'),
#     (72, 76, 'Model'),
#     (77, 110, 'Processor')]}),
#  ('64 bit Windows 10 Dell 33.02 cm (13 inch)  8 GB DDR3  Intel Core i5 Processor (8th Gen) XPS 256 GB SSD Laptop',
#   {'entities': [(0, 17, 'OS'),
#     (18, 22, 'Brand'),
#     (23, 42, 'Dim'),
#     (43, 53, 'RAM'),
#     (54, 87, 'Processor'),
#     (88, 91, 'Model'),
#     (92, 102, 'Disk'),
#     (103, 109, 'Category')]}),
#  ('39.62 cm (15.6 inch)  Asus ZenBook Intel Core i5 Processor (8th Gen) 1 TB HDD 8 GB DDR4  Laptop 64 bit Windows 10',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 26, 'Brand'),
#     (27, 34, 'Model'),
#     (35, 68, 'Processor'),
#     (69, 77, 'Disk'),
#     (78, 88, 'RAM'),
#     (89, 95, 'Category'),
#     (96, 113, 'OS')]}),
#  ('39.62 cm (15.6 inch)  AMD Ryzen 5 Quad Core Processor 64 bit Windows 10 Laptop 8 GB DDR4  1 TB HDD Asus Vivo',
#   {'entities': [(0, 21, 'Dim'),
#     (22, 53, 'Processor'),
#     (54, 71, 'OS'),
#     (72, 78, 'Category'),
#     (79, 89, 'RAM'),
#     (90, 98, 'Disk'),
#     (99, 103, 'Brand'),
#     (104, 108, 'Model')]}),
#  ('Ideapad 512 GB SSD 39.62 cm (15.6 inch)  Intel Core i5 Processor (8th Gen) Lenovo 64 bit Windows 10 8 GB DDR4  Laptop',
#   {'entities': [(0, 7, 'Model'),
#     (8, 18, 'Disk'),
#     (19, 40, 'Dim'),
#     (41, 74, 'Processor'),
#     (75, 81, 'Brand'),
#     (82, 99, 'OS'),
#     (100, 110, 'RAM'),
#     (111, 117, 'Category')]}),
#  ('Lenovo Laptop 64 bit Windows 10 Ideapad Intel Core i3 Processor (7th Gen) 4 GB DDR4  39.62 cm (15.6 inch)  1 TB HDD',
#   {'entities': [(0, 6, 'Brand'),
#     (7, 13, 'Category'),
#     (14, 31, 'OS'),
#     (32, 39, 'Model'),
#     (40, 73, 'Processor'),
#     (74, 84, 'RAM'),
#     (85, 106, 'Dim'),
#     (107, 115, 'Disk')]}),
#  ('39.62 cm (15.6 inch) Touchscreen  Intel Core i7 Processor (10th Gen) 64 bit Windows 10 16 GB DDR4  EliteBook HP Laptop 512 GB SSD',
#   {'entities': [(0, 33, 'Dim'),
#     (34, 68, 'Processor'),
#     (69, 86, 'OS'),
#     (87, 98, 'RAM'),
#     (99, 108, 'Model'),
#     (109, 111, 'Brand'),
#     (112, 118, 'Category'),
#     (119, 129, 'Disk')]}),
#  ('Intel Core i3 Processor (8th Gen) 35.56 cm (14 inch)  64 bit Linux/Ubuntu 1 TB HDD XPS 8 GB DDR4  Laptop Dell',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 53, 'Dim'),
#     (54, 73, 'OS'),
#     (74, 82, 'Disk'),
#     (83, 86, 'Model'),
#     (87, 97, 'RAM'),
#     (98, 104, 'Category'),
#     (105, 109, 'Brand')]}),
#  ('16 GB DDR4  Laptop 512 GB SSD 33.78 cm (13.3 inch) Touchscreen  HP EliteBook Intel Core i7 Processor (8th Gen) 64 bit Windows 10',
#   {'entities': [(0, 11, 'RAM'),
#     (12, 18, 'Category'),
#     (19, 29, 'Disk'),
#     (30, 63, 'Dim'),
#     (64, 66, 'Brand'),
#     (67, 76, 'Model'),
#     (77, 110, 'Processor'),
#     (111, 128, 'OS')]}),
#  ('Lenovo 64 bit D Intel Core i3 Processor (7th Gen) 1 TB HDD 4 GB DDR4  Ideapad 35.56 cm (14 inch)  Laptop',
#   {'entities': [(0, 6, 'Brand'),
#     (7, 15, 'OS'),
#     (16, 49, 'Processor'),
#     (50, 58, 'Disk'),
#     (59, 69, 'RAM'),
#     (70, 77, 'Model'),
#     (78, 97, 'Dim'),
#     (98, 104, 'Category')]}),
#  ('HP Intel Core i5 Processor (8th Gen) 8 GB DDR4  256 GB SSD Laptop ProBook 64 bit Windows 10 33.78 cm (13.3 inch) Touchscreen ',
#   {'entities': [(0, 2, 'Brand'),
#     (3, 36, 'Processor'),
#     (37, 47, 'RAM'),
#     (48, 58, 'Disk'),
#     (59, 65, 'Category'),
#     (66, 73, 'Model'),
#     (74, 91, 'OS'),
#     (92, 125, 'Dim')]}),
#  ('AMD APU Dual Core A4 Processor Acer Aspire 1 TB HDD 64 bit Windows 10 39.62 cm (15.6 inch)  4 GB DDR4  Laptop',
#   {'entities': [(0, 30, 'Processor'),
#     (31, 35, 'Brand'),
#     (36, 42, 'Model'),
#     (43, 51, 'Disk'),
#     (52, 69, 'OS'),
#     (70, 91, 'Dim'),
#     (92, 102, 'RAM'),
#     (103, 109, 'Category')]}),
#  ('Intel Core i3 Processor (8th Gen) Dell Vostro 64 bit Windows 10 4 GB DDR4  1 TB HDD 35.56 cm (14 inch)  Laptop',
#   {'entities': [(0, 33, 'Processor'),
#     (34, 38, 'Brand'),
#     (39, 45, 'Model'),
#     (46, 63, 'OS'),
#     (64, 74, 'RAM'),
#     (75, 83, 'Disk'),
#     (84, 103, 'Dim'),
#     (104, 110, 'Category')]}),
#  ('AMD APU Dual Core A4 Processor (7th Gen) Laptop 39.62 cm (15.6 inch)  Acer Aspire 4 GB DDR4  64 bit Windows 10 1 TB HDD',
#   {'entities': [(0, 40, 'Processor'),
#     (41, 47, 'Category'),
#     (48, 69, 'Dim'),
#     (70, 74, 'Brand'),
#     (75, 81, 'Model'),
#     (82, 92, 'RAM'),
#     (93, 110, 'OS'),
#     (111, 119, 'Disk')]})]

# %% [markdown]
# ### 3. Training NER model

# %%
def train_spacy(data,iterations):
    
    TRAIN_DATA = data
    nlp = spacy.blank('en')  # create blank Language class
    
    # create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
    if 'ner' not in nlp.pipe_names:
        ner = nlp.create_pipe('ner')
        nlp.add_pipe(ner, last=True)
       

    # add labels
    for _, annotations in TRAIN_DATA:
         for ent in annotations.get('entities'):
                ner.add_label(ent[2])

    # get names of other pipes to disable them during training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
    
    with nlp.disable_pipes(*other_pipes):  # only train NER
        optimizer = nlp.begin_training()
        for itn in range(iterations):
            print("Starting iteration " + str(itn))
            random.shuffle(TRAIN_DATA)
            losses = {}
            for text, annotations in TRAIN_DATA:
                #print(text, annotations)
                nlp.update(
                    [text],  # batch of texts
                    [annotations],  # batch of annotations
                    drop=0.2,  # dropout - make it harder to memorise data
                    sgd=optimizer,  # callable to update weights
                    losses=losses)
                
                if (losses <100):
                    break
            print(losses)
    return nlp

# %%
# can plot losses and choose best model

# %%
# %%time
prdnlp = train_spacy(train_data,10)
# Out:
# Starting iteration 0
# {'ner': 1973.4669107749435}
# Starting iteration 1
# {'ner': 426.8618686048913}
# Starting iteration 2
# {'ner': 379.4073549236349}
# Starting iteration 3
# {'ner': 333.3488322236765}
# Starting iteration 4
# {'ner': 154.84842001685763}
# Starting iteration 5
# {'ner': 340.11241003607614}
# Starting iteration 6
# {'ner': 316.0971494102368}
# Starting iteration 7
# {'ner': 108.69856905705248}
# Starting iteration 8
# {'ner': 187.32028293791328}
# Starting iteration 9
# {'ner': 112.57227631507551}
# CPU times: user 2min 57s, sys: 692 ms, total: 2min 57s
# Wall time: 2min 58s

# %%
prdnlp_1 = train_spacy(train_data,20)
# Out:
# Starting iteration 0
# {'ner': 2075.323239810802}
# Starting iteration 1
# {'ner': 210.35872319320842}
# Starting iteration 2
# {'ner': 160.28514150741734}
# Starting iteration 3
# {'ner': 263.17171813443895}
# Starting iteration 4
# {'ner': 446.17392687042405}
# Starting iteration 5
# {'ner': 583.7702890509131}
# Starting iteration 6
# {'ner': 311.69052782090375}
# Starting iteration 7
# {'ner': 328.0147173392929}
# Starting iteration 8
# {'ner': 424.0727626126882}
# Starting iteration 9
# {'ner': 404.5050261430823}
# Starting iteration 10
# {'ner': 423.78265992964145}
# Starting iteration 11
# {'ner': 226.66804519802028}
# Starting iteration 12
# {'ner': 346.1391590602029}
# Starting iteration 13
# {'ner': 483.48646824623137}
# Starting iteration 14
# {'ner': 369.323711042288}
# Starting iteration 15
# {'ner': 486.0551578276055}
# Starting iteration 16
# {'ner': 742.163702002263}
# Starting iteration 17
# {'ner': 528.1660210407974}
# Starting iteration 18
# {'ner': 587.0425977933282}
# Starting iteration 19
# {'ner': 447.530279200851}

# %% [markdown]
# ### 4. Testing the model

# %%
test_text = input("Enter your testing text: ")
doc = prdnlp(test_text)

for ent in doc.ents:

    print('Entity: ',ent.text)
    print('Details: ',ent.start_char, ent.end_char, ent.label_)
# Out:
# Enter your testing text: I have a HP Pavillion Laptop with 1 TB HDD.
# Entity:  I
# Details:  0 1 Model
# Entity:  have
# Details:  2 6 Brand
# Entity:  a
# Details:  7 8 OS
# Entity:  HP
# Details:  9 11 Brand
# Entity:  Pavillion
# Details:  12 21 Model
# Entity:  Laptop
# Details:  22 28 Category
# Entity:  with
# Details:  29 33 Model
# Entity:  1 TB HDD
# Details:  34 42 Disk
# Entity:  .
# Details:  42 43 Model

# %%
test_text = input("Enter your testing text: ")
doc = prdnlp(test_text)

for ent in doc.ents:

    print('Entity: ',ent.text)
    print('Details: ',ent.start_char, ent.end_char, ent.label_)
# Out:
# Enter your testing text: What is the price of Intel Core i3 Processor (7th Gen) Dell Vostro and Lenovo Legion laptop?
# Entity:  What
# Details:  0 4 Model
# Entity:  is the
# Details:  5 11 OS
# Entity:  price
# Details:  12 17 Brand
# Entity:  of
# Details:  18 20 Model
# Entity:  Intel Core i3 Processor (7th Gen)
# Details:  21 54 Processor
# Entity:  Dell
# Details:  55 59 Brand
# Entity:  Vostro
# Details:  60 66 Model
# Entity:  Lenovo
# Details:  71 77 Brand
# Entity:  Legion
# Details:  78 84 Model
# Entity:  laptop
# Details:  85 91 Category
